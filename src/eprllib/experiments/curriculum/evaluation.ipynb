# %%
import os
os.environ['RAY_DEDUP_LOGS'] = '0'

import numpy as np
import shap
import matplotlib.pyplot as plt
import json

from tempfile import TemporaryDirectory
from typing import List, Dict

import ray
from ray.tune import register_env
from ray.rllib.algorithms.algorithm import Algorithm
from ray.rllib.policy.policy import Policy

from ray.rllib.models import ModelCatalog
from eprllib.examples.example_central_agent_files.policy_model import CustomTransformerModel
ModelCatalog.register_custom_model("custom_transformer", CustomTransformerModel)

from eprllib.Environment.Environment import Environment
from eprllib.Environment.EnvironmentConfig import EnvironmentConfig
from eprllib.Agents.Filters.DefaultFilter import DefaultFilter
from eprllib.Agents.Triggers.SetpointTriggers import DualSetpointTriggerDiscreteAndAvailabilityTrigger
# from eprllib.Agents.Rewards.EnergyAndAshrae55SimpleModel import EnergyAndASHRAE55SimpleModel
from eprllib.Agents.Rewards.NygardFerguson1990 import NygardFerguson1990
from eprllib.AgentsConnectors.DefaultConnector import DefaultConnector

from eprllib.Agents.AgentSpec import (
    AgentSpec,
    ObservationSpec,
    RewardSpec,
    ActionSpec,
    TriggerSpec,
    FilterSpec
)
from eprllib.examples.example_thermostat_files.curriculum_learning import episode_fn
from eprllib.examples.example_thermostat_files.policy_mapping import policy_map_fn

from eprllib.PostProcess.Evaluation import generate_experience
from eprllib.AgentsConnectors.BaseConnector import BaseConnector

with open("C:/Users/grhen/Documents/GitHub2/eprllib/src/eprllib/examples/example_thermostat_files/curriculum_evaluation.json", "r") as f:
    episode_config = json.load(f)
# Out:
# WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
# Task 1
checkpoint_path = "C:/Users/grhen/ray_results/general/20251010085251-task1/PPO-bd718_00000/checkpoint_000074"

#"C:/Users/grhen/ray_results/curriculum/20250915195844-task1/PPO-9f13a_00000/checkpoint_000049"

# Task 2
# checkpoint_path = "C:/Users/grhen/ray_results/curriculum/20250917104923-task1/PPO-359d5_00000/checkpoint_000049"

# %%
"""
Esta configuración debe coincidir con la de entrenamiento.
"""
experiment_name:str = "general"
name:str = "task1"

eprllib_config = EnvironmentConfig()
eprllib_config.generals(
    epjson_path = "C:/Users/grhen/Documents/GitHub2/eprllib/src/eprllib/examples/example_central_agent_files/model.epJSON",
    epw_path = "C:/Users/grhen/Documents/GitHub2/eprllib/src/eprllib/examples/example_central_agent_files/weathers/ESP_PV_San.Sebastian-Igueldo.080270_TMYx.2004-2018.epw",
    output_path = TemporaryDirectory("output","",'C:/Users/grhen/Documents/Resultados_RLforEP').name,
    ep_terminal_output = True,
    timeout = 10,
    evaluation = True,
)

eprllib_config.connector(
    connector_fn = DefaultConnector,
    connector_fn_config = {},
)
eprllib_config.agents(
    agents_config = {
        "HVAC": AgentSpec(
            observation = ObservationSpec(
                variables = [
                    ("Site Outdoor Air Drybulb Temperature", "Environment"),
                    # ("Site Outdoor Air Relative Humidity", "Environment"),
                    ("Zone Mean Air Temperature", "Thermal Zone"),
                    # ("Zone Air Relative Humidity", "Thermal Zone"),
                    ("Zone People Occupant Count", "Thermal Zone"),
                    ("Zone Thermal Comfort Fanger Model PMV", "People")
                ],
                # simulation_parameters = {
                #     'hour': True,
                #     'day_of_week': True,
                #     'minutes': True,
                #     'day_of_year': True,
                #     # 'today_weather_horizontal_ir_at_time': True,
                # },
                meters = [
                    "Electricity:Building",
                    "Heating:DistrictHeatingWater",
                    "Cooling:DistrictCooling",
                ],
                use_actuator_state = True,
                use_one_day_weather_prediction = False,
                weather_prediction_hours = 3,
                prediction_variables = {
                    'outdoor_dry_bulb': True,
                },
                # internal_variables = [
                #     ("Zone Floor Area", "Thermal Zone"),
                # ],
                # history_len=6,
                user_occupation_funtion = False,
                user_type = "Office schedule",
                zone_type = "daytime",
                occupation_schedule = ("Schedule:Constant", "Schedule Value", "occupancy_schedule"),
                user_occupation_forecast = False,
                occupation_prediction_hours = 3,
                summer_months = [11, 12, 1, 2],
                # other_obs = {
                #     "war_north": 0,  # Window-to-wall ratio north
                #     "war_south": 0,  # Window-to-wall ratio south
                #     "war_east": 0,   # Window-to-wall ratio east
                #     "war_west": 0,   # Window-to-wall ratio west
                #     "latitude": 0,  # Latitude
                #     "longitude": 0,  # Longitude
                #     # "elevation": 0,  # Elevation
                #     # "time_zone": 0,  # Time zone
                # }
            ),
            action = ActionSpec(
                actuators = [
                    ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                ],
            ),
            filter= FilterSpec(
                filter_fn = DefaultFilter,
                filter_fn_config = {},
            ),
            trigger= TriggerSpec(
                trigger_fn = DualSetpointTriggerDiscreteAndAvailabilityTrigger,
                trigger_fn_config = {
                    'temperature_range': (17, 28),
                    "band_gap_range_len": 3,
                    "action_space_dim": 10,
                    'actuator_for_cooling': ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    'actuator_for_heating': ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    'availability_actuator': ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                },
            ),
            reward = RewardSpec(
                reward_fn = NygardFerguson1990,
                reward_fn_config = {
                    "thermal_zone": "Thermal Zone",
                    "C2": 6000,
                    'people_name': "People",
                    'cooling_name': "Cooling:DistrictCooling",
                    'heating_name': "Heating:DistrictHeatingWater",
                    'cooling_energy_ref': 0,
                    'heating_energy_ref': 0,
                },
            ),
        ),
    }
)

eprllib_config.episodes(
    episode_fn = episode_fn,
    episode_fn_config = episode_config,
    cut_episode_len = 2
)

assert eprllib_config.agents_config is not None, "Agents configuration is not defined."

number_of_agents = len([keys for keys in eprllib_config.agents_config.keys()])
ray.init(_temp_dir='C:/Users/grhen/ray_results/tmp')
register_env(name="EPEnv", env_creator=lambda args: Environment(args))
env_config = eprllib_config.to_dict()

old_algo = Algorithm.from_checkpoint(checkpoint_path)
# Out:
# 2025-10-10 13:15:29,499	INFO worker.py:1918 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\algorithms\algorithm.py:520: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=28296) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=28296)
# (pid=148) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=148)
# (pid=15200) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=15200)
# (pid=15496) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=15496)
# (pid=27836) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27836)
# (pid=19848) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=19848)
# (pid=14456) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=14456)
# 2025-10-10 13:16:38,803	INFO trainable.py:161 -- Trainable.setup took 60.100 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2025-10-10 13:16:38,806	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
# ray.shutdown()

# %%
single_policy = old_algo.get_policy("single_policy")

# Generate experience
df = generate_experience(
    env = Environment,
    env_config = env_config,
    policies = {
        "HVAC": single_policy,
    },
    num_episodes = 1
)

old_algo.stop()
ray.shutdown()

# %%
feature_names: Dict[str, List[str]] = {agent: [] for agent in env_config["agents_config"].keys()}
feature_names_index: Dict[str, Dict[str, int]] = {agent: {} for agent in env_config["agents_config"].keys()}
connector_fn: BaseConnector = env_config['connector_fn'](env_config["connector_fn_config"])

for agent in env_config["agents_config"].keys():
    connector_fn.get_agent_obs_dim(env_config,agent)
    feature_names_index[agent] = connector_fn.get_agent_obs_indexed(env_config,agent)
    for key in feature_names_index[agent].keys():
        feature_names[agent].append(key)

for agent in feature_names.keys():
    if env_config["agents_config"][agent]["observation"]["history_len"] > 1:
        feature_names_h = feature_names[agent].copy()
        for h in range(env_config["agents_config"][agent]["observation"]["history_len"]):
            feature_names_h_new: List[str] = []
            for value in feature_names_h:
                feature_names_h_new.append(f"h{h}_{value}")
            feature_names[agent].extend(feature_names_h_new)

# %%
feature_names
# Out:
# {'HVAC': ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#   'HVAC: Zone Mean Air Temperature: Thermal Zone',
#   'HVAC: Zone People Occupant Count: Thermal Zone',
#   'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#   'HVAC: Electricity:Building',
#   'HVAC: Heating:DistrictHeatingWater',
#   'HVAC: Cooling:DistrictCooling',
#   'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#   'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#   'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']}

# %%
df
# Out:
# {'experiment': {'episode_1': {'timestep_1': {'HVAC': {'observation': array([11.55, 24.  ,  1.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,
#              0.  ], dtype=float32),
#      'action': None,
#      'reward': 0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_2': {'HVAC': {'observation': array([ 1.1550000e+01,  2.6627615e+01,  1.0000000e+00, -2.1120442e-01,
#              0.0000000e+00,  1.0847919e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-5.723286861492198e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_3': {'HVAC': {'observation': array([ 1.1100000e+01,  2.6900000e+01,  1.0000000e+00, -1.4349267e-01,
#              0.0000000e+00,  7.3533019e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.6307079627543374e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_4': {'HVAC': {'observation': array([ 1.0650000e+01,  2.6900000e+01,  1.0000000e+00, -1.4430735e-01,
#              0.0000000e+00,  1.1133581e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.69265396048747e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_5': {'HVAC': {'observation': array([ 1.0200000e+01,  2.6900000e+01,  1.0000000e+00, -1.4781295e-01,
#              0.0000000e+00,  1.4907602e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.8541119606542026e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_6': {'HVAC': {'observation': array([ 9.7500000e+00,  2.6419891e+01,  1.0000000e+00, -2.2390629e-01,
#              0.0000000e+00,  1.5336200e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.476975642991595e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_7': {'HVAC': {'observation': array([ 9.3000002e+00,  2.5872417e+01,  1.0000000e+00, -3.2362109e-01,
#              0.0000000e+00,  1.5680846e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3761935103835977e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_8': {'HVAC': {'observation': array([ 9.2333336e+00,  2.5814241e+01,  1.0000000e+00, -3.4171510e-01,
#              0.0000000e+00,  1.5942346e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.542408462949693e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_9': {'HVAC': {'observation': array([ 9.1666670e+00,  2.5928633e+01,  1.0000000e+00, -3.2706627e-01,
#              0.0000000e+00,  1.5919798e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.4071567052140691e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_10': {'HVAC': {'observation': array([ 9.1000004e+00,  2.5988804e+01,  1.0000000e+00, -3.1704313e-01,
#              0.0000000e+00,  1.5841900e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3186961798568012e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_11': {'HVAC': {'observation': array([ 9.0333338e+00,  2.6003603e+01,  1.0000000e+00, -3.1556660e-01,
#              0.0000000e+00,  1.5800405e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3059188000701264e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_12': {'HVAC': {'observation': array([ 8.9666662e+00,  2.6023254e+01,  1.0000000e+00, -3.1355077e-01,
#              0.0000000e+00,  1.5788922e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2886280569834997e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_13': {'HVAC': {'observation': array([ 8.8999996e+00,  2.6052423e+01,  1.0000000e+00, -3.1203109e-01,
#              0.0000000e+00,  1.5774301e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2756765513361452e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_14': {'HVAC': {'observation': array([ 8.8500004e+00,  2.6867039e+01,  1.0000000e+00, -1.9027533e-01,
#              0.0000000e+00,  1.1810256e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-4.651673867904771e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_15': {'HVAC': {'observation': array([ 8.8000002e+00,  2.6899899e+01,  1.0000000e+00, -1.7452589e-01,
#              0.0000000e+00,  1.1477039e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.915648536128307e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_16': {'HVAC': {'observation': array([ 8.7500000e+00,  2.6454369e+01,  1.0000000e+00, -2.4034166e-01,
#              0.0000000e+00,  1.5303230e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.470642803834592e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_17': {'HVAC': {'observation': array([ 8.6999998e+00,  2.6286253e+01,  1.0000000e+00, -2.7300546e-01,
#              0.0000000e+00,  1.5564985e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.684017735991458e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_18': {'HVAC': {'observation': array([ 8.6499996e+00,  2.6209202e+01,  1.0000000e+00, -2.8439307e-01,
#              0.0000000e+00,  1.5596858e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0531033008134577e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_19': {'HVAC': {'observation': array([ 8.6000004e+00,  2.6487972e+01,  1.0000000e+00, -2.4495070e-01,
#              0.0000000e+00,  1.5646434e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.766396057611135e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_20': {'HVAC': {'observation': array([ 8.5666666e+00,  2.6427814e+01,  1.0000000e+00, -2.5149137e-01,
#              0.0000000e+00,  1.5462424e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.191051676911165e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_21': {'HVAC': {'observation': array([ 8.5333338e+00,  2.6448017e+01,  1.0000000e+00, -2.4940194e-01,
#              0.0000000e+00,  1.5501186e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.053872380204585e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_22': {'HVAC': {'observation': array([ 8.5000000e+00,  2.6621338e+01,  1.0000000e+00, -2.2337383e-01,
#              0.0000000e+00,  1.5487006e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.44737006561512e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_23': {'HVAC': {'observation': array([ 8.4666662e+00,  2.6770540e+01,  1.0000000e+00, -1.9919433e-01,
#              0.0000000e+00,  1.5372150e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-5.127534321053089e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_24': {'HVAC': {'observation': array([ 8.4333334e+00,  2.6882284e+01,  1.0000000e+00, -1.7943220e-01,
#              0.0000000e+00,  1.0199941e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-4.125874289815182e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_25': {'HVAC': {'observation': array([ 8.3999996e+00,  2.6897638e+01,  1.0000000e+00, -1.7413343e-01,
#              0.0000000e+00,  9.8445819e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.884250485214107e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_26': {'HVAC': {'observation': array([ 8.3666668e+00,  2.6899670e+01,  1.0000000e+00, -1.7236115e-01,
#              0.0000000e+00,  1.0556276e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.8122370506788576e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_27': {'HVAC': {'observation': array([ 8.3333330e+00,  2.6899952e+01,  1.0000000e+00, -1.7148538e-01,
#              0.0000000e+00,  1.1177592e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.7792928838998193e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_28': {'HVAC': {'observation': array([ 8.3000002e+00,  2.6899992e+01,  1.0000000e+00, -1.7092660e-01,
#              0.0000000e+00,  1.1780276e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.7601226153801863e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_29': {'HVAC': {'observation': array([ 8.2666664e+00,  2.6900000e+01,  1.0000000e+00, -1.7057580e-01,
#              0.0000000e+00,  1.2361545e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.749891105655351e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_30': {'HVAC': {'observation': array([ 8.2333336e+00,  2.6900000e+01,  1.0000000e+00, -1.7027871e-01,
#              0.0000000e+00,  1.2923491e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.7418334165550666e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_31': {'HVAC': {'observation': array([ 8.1999998e+00,  2.6900000e+01,  1.0000000e+00, -1.7002365e-01,
#              0.0000000e+00,  1.3468906e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.7355026404860033e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_32': {'HVAC': {'observation': array([ 8.1499996e+00,  2.6900000e+01,  1.0000000e+00, -1.6937150e-01,
#              0.0000000e+00,  1.0367959e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.6807918092726407e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_33': {'HVAC': {'observation': array([ 8.1000004e+00,  2.6900000e+01,  1.0000000e+00, -1.6634929e-01,
#              0.0000000e+00,  5.6375556e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.5114307456924596e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_34': {'HVAC': {'observation': array([ 8.050000e+00,  2.690000e+01,  1.000000e+00, -1.658680e-01,
#              0.000000e+00,  9.740446e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.5263370064424856e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_35': {'HVAC': {'observation': array([ 8.0000000e+00,  2.6900000e+01,  1.0000000e+00, -1.6893187e-01,
#              0.0000000e+00,  1.3071362e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.685085875314492e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_36': {'HVAC': {'observation': array([ 7.9499998e+00,  2.6757357e+01,  1.0000000e+00, -1.9539861e-01,
#              0.0000000e+00,  1.5184811e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-4.933712598165268e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_37': {'HVAC': {'observation': array([ 7.9000001e+00,  2.6646479e+01,  1.0000000e+00, -2.1845345e-01,
#              0.0000000e+00,  1.5274639e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.1638027161875164e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_38': {'HVAC': {'observation': array([ 7.8833332e+00,  2.6620733e+01,  1.0000000e+00, -5.0379777e-01,
#              0.0000000e+00,  1.5343782e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.579267307729379e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_39': {'HVAC': {'observation': array([ 7.8666668e+00,  2.6611919e+01,  1.0000000e+00, -5.0793946e-01,
#              0.0000000e+00,  1.5357971e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.646081297521309e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_40': {'HVAC': {'observation': array([ 7.8499999e+00,  2.6592007e+01,  1.0000000e+00, -5.1293302e-01,
#              0.0000000e+00,  1.5361875e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.727730831732377e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_41': {'HVAC': {'observation': array([ 7.8333335e+00,  2.6568731e+01,  1.0000000e+00, -5.1817316e-01,
#              0.0000000e+00,  1.5373580e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.814735376805777e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_42': {'HVAC': {'observation': array([ 7.8166666e+00,  2.6547686e+01,  1.0000000e+00, -5.2282655e-01,
#              0.0000000e+00,  1.5387789e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.8931420801704324e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_43': {'HVAC': {'observation': array([ 7.8000002e+00,  2.6527613e+01,  1.0000000e+00, -5.2562964e-01,
#              0.0000000e+00,  1.5400719e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.9408996525897526e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_44': {'HVAC': {'observation': array([ 7.7833333e+00,  2.6600529e+01,  1.0000000e+00, -5.1555240e-01,
#              0.0000000e+00,  1.5413129e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.77109251517619e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_45': {'HVAC': {'observation': array([ 7.7666669e+00,  2.6847023e+01,  1.0000000e+00, -4.7353095e-01,
#              0.0000000e+00,  1.4924966e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.115213719396444e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_46': {'HVAC': {'observation': array([ 7.7500000e+00,  2.6893005e+01,  1.0000000e+00, -4.6057484e-01,
#              0.0000000e+00,  9.6549775e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.9249031196582004e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_47': {'HVAC': {'observation': array([ 7.7333331e+00,  2.6899137e+01,  1.0000000e+00, -4.5563713e-01,
#              0.0000000e+00,  8.7527075e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.8552533485962604e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_48': {'HVAC': {'observation': array([ 7.7166667e+00,  2.6899853e+01,  1.0000000e+00, -4.5355216e-01,
#              0.0000000e+00,  1.3997101e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.830980753653844e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_49': {'HVAC': {'observation': array([ 7.700000e+00,  2.672121e+01,  1.000000e+00, -4.817561e-01,
#              0.000000e+00,  1.517223e+06,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.237260051118652e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_50': {'HVAC': {'observation': array([ 7.6999998e+00,  2.6701704e+01,  1.0000000e+00, -4.8640999e-01,
#              0.0000000e+00,  1.5289691e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.307658464433827e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_51': {'HVAC': {'observation': array([ 7.6999998e+00,  2.6867016e+01,  1.0000000e+00, -4.5877621e-01,
#              0.0000000e+00,  1.3508072e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.9029942482688548e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_52': {'HVAC': {'observation': array([ 7.6999998e+00,  2.6895390e+01,  1.0000000e+00, -4.5032516e-01,
#              0.0000000e+00,  1.0459469e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.7837892239285474e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_53': {'HVAC': {'observation': array([ 7.6999998e+00,  2.6899538e+01,  1.0000000e+00, -4.4588009e-01,
#              0.0000000e+00,  6.6535194e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.720424263014065e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_54': {'HVAC': {'observation': array([ 7.6999998e+00,  2.6899944e+01,  1.0000000e+00, -4.3841174e-01,
#              0.0000000e+00,  8.5506775e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.6229378742436623e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_55': {'HVAC': {'observation': array([ 7.6999998e+00,  2.6899992e+01,  1.0000000e+00, -4.3499377e-01,
#              0.0000000e+00,  1.1815599e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.5811473059758362e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_56': {'HVAC': {'observation': array([ 7.9499998e+00,  2.6801596e+01,  1.0000000e+00, -4.4837329e-01,
#              0.0000000e+00,  1.5176571e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.7613364283930937e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_57': {'HVAC': {'observation': array([ 8.1999998e+00,  2.6730396e+01,  1.0000000e+00, -4.5851678e-01,
#              0.0000000e+00,  1.5240334e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.9008536161947065e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_58': {'HVAC': {'observation': array([ 8.4499998e+00,  2.6653515e+01,  1.0000000e+00, -4.6825463e-01,
#              0.0000000e+00,  1.5286620e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.0389654084189473e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_59': {'HVAC': {'observation': array([ 8.6999998e+00,  2.6545156e+01,  1.0000000e+00, -4.8066810e-01,
#              0.0000000e+00,  1.5337234e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-3.221110790385136e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_60': {'HVAC': {'observation': array([ 8.9499998e+00,  2.6712809e+01,  1.0000000e+00, -4.5049006e-01,
#              0.0000000e+00,  1.5408932e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.790278238439869e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_61': {'HVAC': {'observation': array([ 9.1999998e+00,  2.6867388e+01,  1.0000000e+00, -4.1723022e-01,
#              0.0000000e+00,  1.4881484e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.359707541067463e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_62': {'HVAC': {'observation': array([ 9.5833330e+00,  2.6894678e+01,  1.0000000e+00, -4.0362543e-01,
#              0.0000000e+00,  1.3460626e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.1953562271290106e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_63': {'HVAC': {'observation': array([ 9.9666662e+00,  2.6899658e+01,  1.0000000e+00, -3.9245996e-01,
#              0.0000000e+00,  3.8509162e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-2.0585714404944382e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_64': {'HVAC': {'observation': array([ 1.0350000e+01,  2.6899946e+01,  1.0000000e+00, -3.8339293e-01,
#              0.0000000e+00,  1.2863291e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.9653679987186973e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_65': {'HVAC': {'observation': array([ 1.0733334e+01,  2.6899992e+01,  1.0000000e+00, -3.7616283e-01,
#              0.0000000e+00,  1.3589350e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.8876929013166922e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_66': {'HVAC': {'observation': array([ 1.1116667e+01,  2.6899998e+01,  1.0000000e+00, -3.6879024e-01,
#              0.0000000e+00,  1.3944855e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.8101195275328187e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_67': {'HVAC': {'observation': array([ 1.1500000e+01,  2.6900000e+01,  1.0000000e+00, -3.6114326e-01,
#              0.0000000e+00,  1.3417334e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.73095798818202e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_68': {'HVAC': {'observation': array([ 1.1800000e+01,  2.6900000e+01,  1.0000000e+00, -3.5373703e-01,
#              0.0000000e+00,  1.2706738e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.656093280994313e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_69': {'HVAC': {'observation': array([ 1.2100000e+01,  2.6900000e+01,  1.0000000e+00, -3.4669247e-01,
#              0.0000000e+00,  1.0995441e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.5857765632798122e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_70': {'HVAC': {'observation': array([ 1.2400000e+01,  2.6900000e+01,  1.0000000e+00, -3.3831131e-01,
#              0.0000000e+00,  4.1222444e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.5002049441081271e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_71': {'HVAC': {'observation': array([ 1.2700000e+01,  2.6900000e+01,  1.0000000e+00, -3.2963556e-01,
#              0.0000000e+00,  1.0847324e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.426004687504136e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_72': {'HVAC': {'observation': array([ 1.3000000e+01,  2.6900000e+01,  1.0000000e+00, -3.2187009e-01,
#              0.0000000e+00,  1.1855825e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3574335639481627e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_73': {'HVAC': {'observation': array([ 1.3300000e+01,  2.6900000e+01,  1.0000000e+00, -3.1039348e-01,
#              0.0000000e+00,  1.2031375e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2586069164832708e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_74': {'HVAC': {'observation': array([ 1.3666667e+01,  2.6900000e+01,  1.0000000e+00, -3.0260479e-01,
#              0.0000000e+00,  1.1745139e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.1936284553475591e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_75': {'HVAC': {'observation': array([ 1.4033334e+01,  2.6900000e+01,  1.0000000e+00, -2.9514319e-01,
#              0.0000000e+00,  1.1458938e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.1331891121113712e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_76': {'HVAC': {'observation': array([ 1.4400000e+01,  2.6900000e+01,  1.0000000e+00, -2.8807223e-01,
#              0.0000000e+00,  1.1170812e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0775240929082871e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_77': {'HVAC': {'observation': array([ 1.4766666e+01,  2.6900000e+01,  1.0000000e+00, -2.8456807e-01,
#              0.0000000e+00,  1.0905108e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0504134790312937e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_78': {'HVAC': {'observation': array([ 1.5133333e+01,  2.6900000e+01,  1.0000000e+00, -2.8118426e-01,
#              0.0000000e+00,  1.0642906e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0245918206373983e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_79': {'HVAC': {'observation': array([ 1.5500000e+01,  2.6900000e+01,  1.0000000e+00, -2.7813891e-01,
#              0.0000000e+00,  1.0380283e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0016330309028842e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_80': {'HVAC': {'observation': array([ 1.5766666e+01,  2.6900000e+01,  1.0000000e+00, -2.7424905e-01,
#              0.0000000e+00,  9.7089506e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.724341499809504e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_81': {'HVAC': {'observation': array([ 1.6033333e+01,  2.6900000e+01,  1.0000000e+00, -2.6948670e-01,
#              0.0000000e+00,  9.0613769e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.374688485462001e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_82': {'HVAC': {'observation': array([ 1.630000e+01,  2.690000e+01,  1.000000e+00, -2.641870e-01,
#              0.000000e+00,  8.437829e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.994490375018917e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_83': {'HVAC': {'observation': array([ 1.6566668e+01,  2.6900000e+01,  1.0000000e+00, -2.6033121e-01,
#              0.0000000e+00,  7.7942625e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.721572721105387e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_84': {'HVAC': {'observation': array([ 1.6833334e+01,  2.6900000e+01,  1.0000000e+00, -2.5640455e-01,
#              0.0000000e+00,  7.1703362e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.448499711965066e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_85': {'HVAC': {'observation': array([ 1.7100000e+01,  2.6900000e+01,  1.0000000e+00, -2.5243464e-01,
#              0.0000000e+00,  6.5896131e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.177533185072316e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_86': {'HVAC': {'observation': array([ 1.7250000e+01,  2.6900000e+01,  1.0000000e+00, -2.4831313e-01,
#              0.0000000e+00,  6.4804538e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.905370543705858e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_87': {'HVAC': {'observation': array([ 1.7400000e+01,  2.6900000e+01,  1.0000000e+00, -2.4604237e-01,
#              0.0000000e+00,  6.3897244e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.75732635559038e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_88': {'HVAC': {'observation': array([ 1.7549999e+01,  2.6900000e+01,  1.0000000e+00, -2.4205671e-01,
#              0.0000000e+00,  6.2895944e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.501617133038722e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_89': {'HVAC': {'observation': array([ 1.7700001e+01,  2.6900000e+01,  1.0000000e+00, -2.3892075e-01,
#              0.0000000e+00,  6.1973512e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.303578515948947e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_90': {'HVAC': {'observation': array([ 1.7850000e+01,  2.6900000e+01,  1.0000000e+00, -2.3575176e-01,
#              0.0000000e+00,  6.1082462e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.106390744755568e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_91': {'HVAC': {'observation': array([ 1.8000000e+01,  2.6900000e+01,  1.0000000e+00, -2.3267570e-01,
#              0.0000000e+00,  6.0215125e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.917786507705004e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_92': {'HVAC': {'observation': array([ 1.8033333e+01,  2.6900000e+01,  1.0000000e+00, -2.3072559e-01,
#              0.0000000e+00,  6.1272525e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.801000249787749e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_93': {'HVAC': {'observation': array([ 1.8066668e+01,  2.6900000e+01,  1.0000000e+00, -2.3015849e-01,
#              0.0000000e+00,  6.2315919e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.767862442260777e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_94': {'HVAC': {'observation': array([ 1.8100000e+01,  2.6900000e+01,  1.0000000e+00, -2.3038925e-01,
#              0.0000000e+00,  6.1665612e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.781150374951638e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_95': {'HVAC': {'observation': array([ 1.8133333e+01,  2.6900000e+01,  1.0000000e+00, -2.3036484e-01,
#              0.0000000e+00,  6.0410031e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.7786028520833145e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_96': {'HVAC': {'observation': array([ 1.8166666e+01,  2.6900000e+01,  1.0000000e+00, -2.3060268e-01,
#              0.0000000e+00,  5.9404781e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.792013240201253e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_97': {'HVAC': {'observation': array([ 1.8200001e+01,  2.6900000e+01,  1.0000000e+00, -2.3107576e-01,
#              0.0000000e+00,  5.8668506e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.819808473376411e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_98': {'HVAC': {'observation': array([ 1.8133333e+01,  2.6900000e+01,  1.0000000e+00, -2.3134959e-01,
#              0.0000000e+00,  4.9169875e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.828160758680104e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_99': {'HVAC': {'observation': array([ 1.8066668e+01,  2.6900000e+01,  1.0000000e+00, -2.3023967e-01,
#              0.0000000e+00,  3.9001612e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.752749461153631e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_100': {'HVAC': {'observation': array([ 1.8000000e+01,  2.6900000e+01,  1.0000000e+00, -2.3180488e-01,
#              0.0000000e+00,  5.8206438e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-6.863361386407956e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_101': {'HVAC': {'observation': array([ 1.7933332e+01,  2.6900000e+01,  1.0000000e+00, -2.3649578e-01,
#              0.0000000e+00,  6.0348112e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.151623025044237e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_102': {'HVAC': {'observation': array([ 1.7866667e+01,  2.6900000e+01,  1.0000000e+00, -2.4156073e-01,
#              0.0000000e+00,  6.2513925e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.469905993002855e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_103': {'HVAC': {'observation': array([ 1.7799999e+01,  2.6900000e+01,  1.0000000e+00, -2.4663931e-01,
#              0.0000000e+00,  6.3622900e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-7.795655060595088e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_104': {'HVAC': {'observation': array([ 1.7616667e+01,  2.6900000e+01,  1.0000000e+00, -2.5088522e-01,
#              0.0000000e+00,  6.4332300e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.073640319734036e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_105': {'HVAC': {'observation': array([ 1.7433332e+01,  2.6900000e+01,  1.0000000e+00, -2.5440311e-01,
#              0.0000000e+00,  6.5050794e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.308096394281726e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_106': {'HVAC': {'observation': array([ 1.725000e+01,  2.690000e+01,  1.000000e+00, -2.573104e-01,
#              0.000000e+00,  6.576811e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.504767424355538e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_107': {'HVAC': {'observation': array([ 1.7066668e+01,  2.6900000e+01,  1.0000000e+00, -2.6052916e-01,
#              0.0000000e+00,  6.6531000e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.7254015123127e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_108': {'HVAC': {'observation': array([ 1.6883333e+01,  2.6900000e+01,  1.0000000e+00, -2.6245335e-01,
#              0.0000000e+00,  6.7200575e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.858984649098646e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_109': {'HVAC': {'observation': array([ 1.6700001e+01,  2.6900000e+01,  1.0000000e+00, -2.6433897e-01,
#              0.0000000e+00,  6.7851231e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.990962528238735e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_110': {'HVAC': {'observation': array([ 1.6450001e+01,  2.6900000e+01,  1.0000000e+00, -2.6623473e-01,
#              0.0000000e+00,  6.9367369e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.125447830071998e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_111': {'HVAC': {'observation': array([ 1.6200001e+01,  2.6900000e+01,  1.0000000e+00, -2.6789132e-01,
#              0.0000000e+00,  7.0906625e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.244047754969185e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_112': {'HVAC': {'observation': array([ 1.5950000e+01,  2.6900000e+01,  1.0000000e+00, -2.6915804e-01,
#              0.0000000e+00,  7.2443988e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.335602806122106e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_113': {'HVAC': {'observation': array([ 1.5700000e+01,  2.6900000e+01,  1.0000000e+00, -2.6864517e-01,
#              0.0000000e+00,  7.3852288e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.300217629308106e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_114': {'HVAC': {'observation': array([ 1.5450000e+01,  2.6900000e+01,  1.0000000e+00, -2.6786876e-01,
#              0.0000000e+00,  7.5222538e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.246143238942147e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_115': {'HVAC': {'observation': array([ 1.5200000e+01,  2.6900000e+01,  1.0000000e+00, -2.6702648e-01,
#              0.0000000e+00,  7.6593012e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.187581448315794e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_116': {'HVAC': {'observation': array([ 1.5100000e+01,  2.6900000e+01,  1.0000000e+00, -2.6648712e-01,
#              0.0000000e+00,  7.7006600e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.14981349592085e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_117': {'HVAC': {'observation': array([ 1.5000000e+01,  2.6900000e+01,  1.0000000e+00, -2.6637501e-01,
#              0.0000000e+00,  7.7415244e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.14224793976049e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_118': {'HVAC': {'observation': array([ 1.4900000e+01,  2.6900000e+01,  1.0000000e+00, -2.6653025e-01,
#              0.0000000e+00,  7.7815331e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
# ...
#      'truncated': False,
#      'info': {}}},
#    'timestep_252': {'HVAC': {'observation': array([ 1.3583333e+01,  2.6900000e+01,  1.0000000e+00, -2.6041389e-01,
#              0.0000000e+00,  7.6210562e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-8.725782227948978e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_253': {'HVAC': {'observation': array([ 1.350000e+01,  2.690000e+01,  1.000000e+00, -2.646432e-01,
#              0.000000e+00,  6.846827e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.01278170728861e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_254': {'HVAC': {'observation': array([ 1.3350000e+01,  2.6900000e+01,  1.0000000e+00, -2.6951224e-01,
#              0.0000000e+00,  7.2074931e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.360622973530177e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_255': {'HVAC': {'observation': array([ 1.3200000e+01,  2.6900000e+01,  1.0000000e+00, -2.7527061e-01,
#              0.0000000e+00,  7.3869544e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-9.779168658927382e-06),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_256': {'HVAC': {'observation': array([ 1.305000e+01,  2.690000e+01,  1.000000e+00, -2.811807e-01,
#              0.000000e+00,  7.567958e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0219297422175055e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_257': {'HVAC': {'observation': array([ 1.2900000e+01,  2.6900000e+01,  1.0000000e+00, -2.8339547e-01,
#              0.0000000e+00,  7.7679406e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.038814114383806e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_258': {'HVAC': {'observation': array([ 1.2750000e+01,  2.6900000e+01,  1.0000000e+00, -2.8553432e-01,
#              0.0000000e+00,  7.9744800e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0552774175454019e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_259': {'HVAC': {'observation': array([ 1.2600000e+01,  2.6900000e+01,  1.0000000e+00, -2.8759992e-01,
#              0.0000000e+00,  8.1806262e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0713151659511606e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_260': {'HVAC': {'observation': array([ 1.250000e+01,  2.690000e+01,  1.000000e+00, -2.897855e-01,
#              0.000000e+00,  8.115696e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.0881887642223677e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_261': {'HVAC': {'observation': array([ 1.2400000e+01,  2.6900000e+01,  1.0000000e+00, -2.9207334e-01,
#              0.0000000e+00,  8.0471494e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.1060112193240994e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_262': {'HVAC': {'observation': array([ 1.230000e+01,  2.690000e+01,  1.000000e+00, -2.944686e-01,
#              0.000000e+00,  7.975223e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.1248489463668054e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_263': {'HVAC': {'observation': array([ 1.220000e+01,  2.690000e+01,  1.000000e+00, -2.968149e-01,
#              0.000000e+00,  7.930843e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.143496939072157e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_264': {'HVAC': {'observation': array([ 1.210000e+01,  2.690000e+01,  1.000000e+00, -2.992155e-01,
#              0.000000e+00,  7.907982e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.1627769254964828e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_265': {'HVAC': {'observation': array([ 1.200000e+01,  2.690000e+01,  1.000000e+00, -3.016223e-01,
#              0.000000e+00,  7.883456e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.1822923712476666e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_266': {'HVAC': {'observation': array([ 1.1883333e+01,  2.6900000e+01,  1.0000000e+00, -3.0371958e-01,
#              0.0000000e+00,  7.8965975e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.1994756561642831e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_267': {'HVAC': {'observation': array([ 1.1766666e+01,  2.6900000e+01,  1.0000000e+00, -3.0543414e-01,
#              0.0000000e+00,  7.9088962e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2136301995582067e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_268': {'HVAC': {'observation': array([ 1.1650000e+01,  2.6900000e+01,  1.0000000e+00, -3.0664778e-01,
#              0.0000000e+00,  7.5415575e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2233837343227063e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_269': {'HVAC': {'observation': array([ 1.1533334e+01,  2.6900000e+01,  1.0000000e+00, -3.0735865e-01,
#              0.0000000e+00,  7.0689738e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2288978793061831e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_270': {'HVAC': {'observation': array([ 1.1416667e+01,  2.6900000e+01,  1.0000000e+00, -3.0762944e-01,
#              0.0000000e+00,  6.5529456e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2307140904800752e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_271': {'HVAC': {'observation': array([ 1.1300000e+01,  2.6900000e+01,  1.0000000e+00, -3.0744883e-01,
#              0.0000000e+00,  5.9809062e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2287186031386477e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_272': {'HVAC': {'observation': array([ 1.1200000e+01,  2.6900000e+01,  1.0000000e+00, -3.0782497e-01,
#              0.0000000e+00,  6.8568206e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2326092072241096e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_273': {'HVAC': {'observation': array([ 1.110000e+01,  2.690000e+01,  1.000000e+00, -3.089032e-01,
#              0.000000e+00,  7.513372e+05,  0.000000e+00,  2.690000e+01,
#              2.790000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2421971554237506e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_274': {'HVAC': {'observation': array([ 1.1000000e+01,  2.6900000e+01,  1.0000000e+00, -3.1003156e-01,
#              0.0000000e+00,  7.3835425e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2515716126450469e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_275': {'HVAC': {'observation': array([ 1.0900000e+01,  2.6900000e+01,  1.0000000e+00, -3.1086469e-01,
#              0.0000000e+00,  7.1817894e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2584302249715743e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_276': {'HVAC': {'observation': array([ 1.0800000e+01,  2.6900000e+01,  1.0000000e+00, -3.1140128e-01,
#              0.0000000e+00,  6.9740656e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.262792739639867e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_277': {'HVAC': {'observation': array([ 1.0700000e+01,  2.6900000e+01,  1.0000000e+00, -3.1170747e-01,
#              0.0000000e+00,  6.7606688e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2652052792248375e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_278': {'HVAC': {'observation': array([ 1.0583333e+01,  2.6900000e+01,  1.0000000e+00, -3.1213760e-01,
#              0.0000000e+00,  7.2504638e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2692740173493175e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_279': {'HVAC': {'observation': array([ 1.0466666e+01,  2.6900000e+01,  1.0000000e+00, -3.1277505e-01,
#              0.0000000e+00,  7.7705925e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2751417213040583e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_280': {'HVAC': {'observation': array([ 1.0350000e+01,  2.6900000e+01,  1.0000000e+00, -3.1344014e-01,
#              0.0000000e+00,  8.0545938e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2810542208511843e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_281': {'HVAC': {'observation': array([ 1.0233334e+01,  2.6900000e+01,  1.0000000e+00, -3.1398192e-01,
#              0.0000000e+00,  8.2368950e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.285840785215996e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_282': {'HVAC': {'observation': array([ 1.0116667e+01,  2.6900000e+01,  1.0000000e+00, -3.1440303e-01,
#              0.0000000e+00,  8.4473850e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2896245141503523e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_283': {'HVAC': {'observation': array([ 1.0000000e+01,  2.6900000e+01,  1.0000000e+00, -3.1474176e-01,
#              0.0000000e+00,  8.6958606e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.2927419143954037e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_284': {'HVAC': {'observation': array([ 9.8999996e+00,  2.6900000e+01,  1.0000000e+00, -3.1577173e-01,
#              0.0000000e+00,  8.8046231e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3016881960345558e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_285': {'HVAC': {'observation': array([ 9.8000002e+00,  2.6900000e+01,  1.0000000e+00, -3.1757516e-01,
#              0.0000000e+00,  8.9136812e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3173661169429704e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_286': {'HVAC': {'observation': array([ 9.6999998e+00,  2.6900000e+01,  1.0000000e+00, -3.1997454e-01,
#              0.0000000e+00,  9.0388888e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3383738342189367e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_287': {'HVAC': {'observation': array([ 9.6000004e+00,  2.6900000e+01,  1.0000000e+00, -3.2278192e-01,
#              0.0000000e+00,  9.2063231e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3632123345302096e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_288': {'HVAC': {'observation': array([ 9.5000000e+00,  2.6900000e+01,  1.0000000e+00, -3.2585621e-01,
#              0.0000000e+00,  9.3738844e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.3906978853513704e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_289': {'HVAC': {'observation': array([ 9.3999996e+00,  2.6900000e+01,  1.0000000e+00, -3.2910386e-01,
#              0.0000000e+00,  9.5416062e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.420068362040377e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_290': {'HVAC': {'observation': array([ 9.3999996e+00,  2.6900000e+01,  1.0000000e+00, -3.2910386e-01,
#              0.0000000e+00,  9.5416062e+05,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-1.420068362040377e-05),
#      'done': True,
#      'truncated': False,
#      'info': {}}}}}}

# %%
# for agent in feature_names_index.keys():
#     energy_total: List[float] = []
#     for timestep in range(1,len(df["experiment"]["episode_1"])):
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]])
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Cooling:DistrictCooling"]])
#     print(sum(energy_total)/3600000)

# %%
from typing import Tuple
for agent in feature_names_index.keys():
    action_list_1: List[float] = []
    action_list_2: List[float] = []
    av_list: List[int] = []
    t_r_list: List[float] = []
    t_c_list: List[float] = []
    t_i_list: List[float] = []
    occ_list: List[float] = []
    t_out_list: List[float] = []
    energy_list: List[float] = []
    pmv_list: List[float] = []
    pmv_hist: List[float] = []
    for timestep in range(1,len(df["experiment"]["episode_1"])):
        t_i_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Mean Air Temperature: Thermal Zone"]])
        t_out_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Site Outdoor Air Drybulb Temperature: Environment"]])
        energy_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]]/3600000)
        occ_t = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone People Occupant Count: Thermal Zone"]]
        if occ_t > 0:
            occ_list.append(occ_t)
            pmv_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
            pmv_hist.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
        else:
            occ_list.append(0)
            pmv_list.append(0)
        
        if df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"] is None:
            pass
        else:
            a1 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][0]
            a2 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][1]
            action_list_1.append(a1)
            action_list_2.append(a2)
            temp_range = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["temperature_range"]
            action_range: int = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["action_space_dim"]
            if a1 > 0:
                t_r_list.append(min(temp_range)+((a2/action_range)*(max(temp_range)-min(temp_range)))+(a1-1)/2 + 1)
                t_c_list.append(min(temp_range)+((a2/action_range)*(max(temp_range)-min(temp_range)))-(a1-1)/2)
                av_list.append(a1)
            else:
                t_r_list.append(0)
                t_c_list.append(0)
                av_list.append(0)
    
    # print(action_list)
    # print(f"Agent: {agent}")
    
    # Create a figure with multiple subplots
    plt.figure(figsize=(14.5, 5))

    # 1. Time series plot
    plt.subplot(1, 2, 1)
    plt.plot(t_r_list, label='Tr', color='lightblue', alpha=0.6)
    plt.plot(t_c_list, label='Tc', color='lightgreen', alpha=0.6)
    plt.plot(av_list, label='Tc', color='red', alpha=0.6)
    plt.plot(t_i_list, label='Ti', color='red', alpha=0.6)
    plt.plot(t_out_list, label='To', color='black', alpha=0.6)
    plt.plot(occ_list, label='Occupancy', color='orange', alpha=0.6)
    plt.plot(pmv_list, label='PMV', color='green', alpha=0.6)
    plt.plot(energy_list, label='Energy', color='purple', alpha=0.6)
    plt.xlabel('Time Step')
    # plt.ylabel('Action Value')
    plt.grid(True, alpha=0.3)

    # 2. Histogram
    plt.subplot(1, 2, 2)
    plt.hist(action_list_2, bins=11, color='skyblue', edgecolor='black')
    plt.hist(action_list_1, bins=11, color='lightgreen', edgecolor='black')
    plt.xlabel('Valor de la action')
    plt.xlim((0, 10))
    plt.ylabel('Frecuencia')
    # plt.ylim((0, 1))
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    # 3. PMV histogram plot    
    plt.figure(figsize=(7, 5))
    plt.hist(pmv_hist, bins=20, color='lightgreen', edgecolor='black')
    plt.xlabel('PMV Value')
    plt.xlim((-3, 3))
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    # Basic statistical analysis
    print(f"\nStatistical Summary ({agent}):")
    print(f"Mean: {np.mean(action_list_1):.2f}")
    print(f"Median: {np.median(action_list_1):.2f}")
    print(f"Std Dev: {np.std(action_list_1):.2f}")
    print(f"Min: {np.min(action_list_1):.2f}")
    print(f"Max: {np.max(action_list_1):.2f}")
    print(f"Mean: {np.mean(action_list_2):.2f}")
    print(f"Median: {np.median(action_list_2):.2f}")
    print(f"Std Dev: {np.std(action_list_2):.2f}")
    print(f"Min: {np.min(action_list_2):.2f}")
    print(f"Max: {np.max(action_list_2):.2f}")
    print(f"Total Energy Consumption (kWh): {sum(energy_list):.2f}")
# Out:
# Statistical Summary (HVAC):
# Mean: 1.00
# Median: 1.00
# Std Dev: 0.00
# Min: 1.00
# Max: 1.00
# Mean: 9.00
# Median: 9.00
# Std Dev: 0.00
# Min: 9.00
# Max: 9.00
# Total Energy Consumption (kWh): 82.61

# %%
obs: List[float|int] = [-3,-2,-1,0,1,2,3]
rew: List[float] = []
for _ in range(len(obs)):
    rew.append(-(np.exp(obs[_]**2) - 1.0)/(np.exp(3**2)-1))
    
print(rew)
# Out:
# [np.float64(-1.0), np.float64(-0.006615353594489847), np.float64(-0.00021207899644323422), np.float64(-0.0), np.float64(-0.00021207899644323422), np.float64(-0.006615353594489847), np.float64(-1.0)]

# %%
norm_energy: List[float] = [1.0,0.75,0.5,0.25,0.0]
c: float = 6000 / (60/6) * (np.exp(3**2)-1)

rew_e: List[float] = []
for _ in range(len(norm_energy)):
    rew_e.append(-norm_energy[_] * (1 / c))
    
print(rew_e)
# Out:
# [np.float64(-2.0570839324364178e-07), np.float64(-1.5428129493273133e-07), np.float64(-1.0285419662182089e-07), np.float64(-5.1427098310910444e-08), np.float64(-0.0)]

# %%
labelsize = 14
time_steps = np.arange(len(action_list_2))
time_steps_1 = np.arange(len(action_list_2)+1)
# --- Creación de la figura y subgráficas ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14.5, 6))
# fig.suptitle('Análisis de Control y Ocupación', fontsize=18, fontweight='bold', y=1.02)

# --- Subgráfica 1: Gráfico de series de tiempo ---
# Determinar y aplicar el color de fondo basado en la ocupación
is_occupied = False
start_occupancy = 0
for i, occ in enumerate(occ_list):
    if occ > 0 and not is_occupied:
        is_occupied = True
        start_occupancy = i
    elif occ == 0 and is_occupied:
        is_occupied = False
        end_occupancy = i
        # Usar axvspan para crear la región sombreada.
        # El color semi-transparente ayuda a ver las líneas del grid.
        ax1.axvspan(start_occupancy, end_occupancy, color='#ADD8E6', alpha=0.3, label='Ocupado' if start_occupancy == 0 else "")

# Dibujar las líneas de las series de tiempo sobre el fondo
ax1.plot(time_steps, t_r_list, label='Temp. Refri.', color='#1f77b4', linewidth=2, linestyle='--')
ax1.plot(time_steps, t_c_list, label='Temp. Calef.', color='#1f77b4', linewidth=2, linestyle=':')
ax1.plot(time_steps_1, t_i_list, label='Temp. Interna', color='#d62728', linestyle='--')
ax1.plot(time_steps_1, t_out_list, label='Temp. Externa', color='#2ca02c', linestyle='--')

# ax1.set_title('Valores de Control y Temperaturas', fontsize=14)
ax1.set_xlabel('Paso de Tiempo', fontsize=labelsize)
ax1.set_ylabel('Valor', fontsize=12)
ax1.tick_params(axis='both', which='major', labelsize=labelsize)
ax1.grid(True, linestyle='--', alpha=0.6)
# ax1.legend(loc='upper right')
ax1.legend(loc='upper left', bbox_to_anchor=(-0.5, 1), fontsize=labelsize)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# --- Subgráfica 2: Histograma normalizado ---
# Para obtener el porcentaje en el eje Y, usamos el argumento 'weights'.
total_actions = len(action_list_2)
weights = np.ones(total_actions) / total_actions * 100

n, bins, patches = ax2.hist(action_list_2, bins=np.arange(-0.5, 11.5, 1), weights=weights, color="#86EE80", edgecolor='black', alpha=0.8)
n, bins, patches = ax2.hist(action_list_1, bins=np.arange(-0.5, 11.5, 1), weights=weights, color='#87CEEB', edgecolor='black', alpha=0.8)
ax2.set_xlabel('Valor de la Acción', fontsize=labelsize)
ax2.set_ylabel('Porcentaje de Frecuencia', fontsize=labelsize)

# Aumentar el tamaño de la fuente para los valores de los ejes
ax2.tick_params(axis='both', which='major', labelsize=labelsize)
ax2.set_xlim(0, 11)
# Establecer los valores discretos en el eje horizontal
ax2.set_xticks(np.arange(0, 11))
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

# Mejorar el diseño del layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15.5, 5))

# # Histogram
# plt.hist(action_list, bins=30, color='skyblue', edgecolor='black')
# plt.title('Distribución de acciones')
# plt.xlabel('Valor de la action')
# plt.ylabel('Frecuencia')
# plt.grid(True, alpha=0.3)

# plt.tight_layout()
# plt.show()

# %%
# # Scatter plot of the variables action_list = df[agent]["actions"] vs cooling_energy = []
# action_list = df[agent]["actions"]
# cooling_energy = []
# for timestep in range(len(df[agent]["infos"])-1):
#     cooling_energy.append(df[agent]["infos"][timestep][f"{agent}: Cooling:DistrictCooling"])

# plt.figure(figsize=(7.5, 5))
# plt.scatter(action_list, cooling_energy, s=1)
# plt.xlabel("Action")
# plt.ylabel("Cooling energy")
# plt.title("Scatter plot of Action vs Cooling energy")
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
# # Analyze transitions between actions
# transitions = np.diff(action_list)
# plt.figure(figsize=(10, 4))
# plt.plot(transitions, label='Action Changes')
# plt.title('Action Transitions Over Time')
# plt.xlabel('Time Step')
# plt.ylabel('Change in Action')
# plt.grid(True, alpha=0.3)
# plt.show()

# # Calculate transition statistics
# print("\nTransition Analysis:")
# print(f"Mean absolute change: {np.mean(np.abs(transitions)):.2f}")
# print(f"Max increase: {np.max(transitions):.2f}")
# print(f"Max decrease: {np.min(transitions):.2f}")

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15, 5))

# # 1. Time series plot
# plt.scatter(action_list, occ_list, color='blue', alpha=0.6)
# plt.title('Action-occupancy distribution')
# plt.xlabel('Action Value')
# plt.ylabel('Occupancy')
# plt.grid(True, alpha=0.3)

# %%
from typing import List, Any, Optional

agent:str = "HVAC"

feature_names_list: List[str] = feature_names[agent]

data_obs_list: List[Any] = []
for timestep in range(1,len(df["experiment"]["episode_1"])):
    data_obs_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"])
        
data_obs = np.array(data_obs_list)

# %%
feature_names_list
# Out:
# ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#  'HVAC: Zone Mean Air Temperature: Thermal Zone',
#  'HVAC: Zone People Occupant Count: Thermal Zone',
#  'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#  'HVAC: Electricity:Building',
#  'HVAC: Heating:DistrictHeatingWater',
#  'HVAC: Cooling:DistrictCooling',
#  'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#  'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#  'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']

# %%
len(feature_names_list)
# Out:
# 10

# %%
print(data_obs.shape)
# Out:
# (289, 10)

# %%
print(data_obs)
# Out:
# [[11.55     24.        1.       ...  0.        0.        0.      ]
#  [11.55     26.627615  1.       ... 26.9      27.9       1.      ]
#  [11.1      26.9       1.       ... 26.9      27.9       1.      ]
#  ...
#  [ 9.6      26.9       1.       ... 26.9      27.9       1.      ]
#  [ 9.5      26.9       1.       ... 26.9      27.9       1.      ]
#  [ 9.4      26.9       1.       ... 26.9      27.9       1.      ]]

# %%
from numpy.typing import NDArray
from numpy import float32
import torch
# Model prediction function (adapted for RLlib)
POLICY: Optional[Policy] = None
def model_predict(
    data: NDArray[float32],
):
    # Transform the lists in tensors.
    obs_tensor = torch.tensor(data, dtype=torch.float32)
    
    # Compute the actions.
    with torch.no_grad():
        assert POLICY is not None, "Policy is not defined."
        predictions = POLICY.compute_actions(
            obs_batch=obs_tensor.numpy(), 
            exploration=False, 
        )[0]
    return predictions

# %%
# Use KernelExplainer
data_obs_sample = shap.sample(data_obs, 1000)

POLICY = single_policy
explainer = shap.KernelExplainer(
    model_predict,
    data=data_obs_sample,
    feature_names=feature_names_list
    )
# Out:
# Using 289 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.

# %%
print(data_obs_sample)
# Out:
# [[11.55     24.        1.       ...  0.        0.        0.      ]
#  [11.55     26.627615  1.       ... 26.9      27.9       1.      ]
#  [11.1      26.9       1.       ... 26.9      27.9       1.      ]
#  ...
#  [ 9.6      26.9       1.       ... 26.9      27.9       1.      ]
#  [ 9.5      26.9       1.       ... 26.9      27.9       1.      ]
#  [ 9.4      26.9       1.       ... 26.9      27.9       1.      ]]

# %%
background_data_np_sample = shap.sample(data_obs, 100)

# %%
shap_values_1 = explainer(background_data_np_sample)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
print(f"Dimensiones del objeto SHAP: {shap_values_1.shape}.")
# Out:
# Dimensiones del objeto SHAP: (100, 10, 2).

# %%
shap_values_accion_0 = shap_values_1[:, :, 0]
shap_values_accion_1 = shap_values_1[:, :, 1]

# %%
shap.plots.waterfall(shap_values_accion_0[0])

# %%
shap.plots.waterfall(shap_values_accion_1[0])

# %%
"""
Global bar plot
================

Passing a matrix of SHAP values to the bar plot function creates a global feature importance 
plot, where the global importance of each feature is taken to be the mean absolute value for 
that feature over all the given samples.

# By default the bar plot only shows a maximum of ten bars, but this can be controlled with the `max_display` parameter.
"""
shap.plots.bar(shap_values_accion_0)
shap.plots.bar(shap_values_accion_1)

# %%
# for _ in range(50):
#     shap.plots.bar(shap_values_1[_], max_display=13)

# %%
"""
beeswarm summary plot
======================

The beeswarm plot is designed to display an information-dense summary of how the top features 
in a dataset impact the model’s output. Each instance the given explanation is represented by 
a single dot on each feature row. The x position of the dot is determined by the SHAP value 
(shap_values.value[instance,feature]) of that feature, and dots “pile up” along each feature row 
to show density. Color is used to display the original value of a feature 
(shap_values.data[instance,feature]).

By default the maximum number of features shown is ten, but this can be adjusted with the max_display parameter.
"""
shap.plots.beeswarm(shap_values_accion_0)
shap.plots.beeswarm(shap_values_accion_1)

# %%
"""
Feature ordering
=================

By default the features are ordered using shap_values.abs.mean(0), which is the mean absolute value 
of the SHAP values for each feature. This order however places more emphasis on broad average impact, 
and less on rare but high magnitude impacts. If we want to find features with high impacts for individual 
people we can instead sort by the max absolute value.
"""
# shap.plots.beeswarm(shap_values_accion_0, order=shap_values_accion_0.abs.max(0))
# shap.plots.beeswarm(shap_values_accion_1, order=shap_values_accion_1.abs.max(0))
# Out:
# '\nFeature ordering\n=================\n\nBy default the features are ordered using shap_values.abs.mean(0), which is the mean absolute value \nof the SHAP values for each feature. This order however places more emphasis on broad average impact, \nand less on rare but high magnitude impacts. If we want to find features with high impacts for individual \npeople we can instead sort by the max absolute value.\n'

# %%
"""
Sometimes it is helpful to transform the SHAP values before we plots them. Below we plot the absolute 
value and fix the color to be red. This creates a richer parallel to the standard shap_values.abs.mean(0) 
bar plot, since the bar plot just plots the mean value of the dots in the beeswarm plot.
"""
shap.plots.beeswarm(shap_values_accion_0.abs, color="shap_red")
shap.plots.beeswarm(shap_values_accion_1.abs, color="shap_red")

# %%
"""
A simple violin summary plot
=============================

The violin summary plot offers a compact representation of the distribution and variability of SHAP 
values for each feature. Individual violin plots are stacked by importance of the particular feature 
on model output (sum of the absolute values of the SHAP values per feature).

Violin plots use “violin-shaped” figures to display the distribution and density of SHAP values for their 
respective feature. The violins can therefore provide insights into the range, variability, skewness, 
symmetry, and multimodality of the SHAP value distribution for a specific feature.

The overall violin summary plot allow for comparisons in feature importance. Wider violins indicate higher 
density and more frequent values, thus providing insights into the relative importance of each feature with 
regard to the model output.
"""
shap.plots.violin(shap_values_accion_0)
shap.plots.violin(shap_values_accion_1)

# %%
"""
Simple dependence scatter plot
===============================

A dependence scatter plot shows the effect a single feature has on the predictions made by the model.

* Each dot is a single prediction (row) from the dataset.
* The x-axis is the value of the feature (from the X matrix, stored in explanation.data).
* The y-axis is the SHAP value for that feature (stored in explanation.values), which represents how much knowing 
that feature’s value changes the output of the model for that sample’s prediction. For this model the units are 
log-odds of making over 50k annually.
* The light grey area at the bottom of the plot is a histogram showing the distribution of data values.
"""

# features = feature_names.copy()

# for feature in features:
#     shap.plots.scatter(
#         shap_values_1[:, feature],
#         # color=shap_values_1[:, "Zone Thermal Comfort Fanger Model PMV"]
#         )
# Out:
# '\nSimple dependence scatter plot\n===============================\n\nA dependence scatter plot shows the effect a single feature has on the predictions made by the model.\n\n* Each dot is a single prediction (row) from the dataset.\n* The x-axis is the value of the feature (from the X matrix, stored in explanation.data).\n* The y-axis is the SHAP value for that feature (stored in explanation.values), which represents how much knowing \nthat feature’s value changes the output of the model for that sample’s prediction. For this model the units are \nlog-odds of making over 50k annually.\n* The light grey area at the bottom of the plot is a histogram showing the distribution of data values.\n'

# %%
# # for feature in features:
# features_copy = features.copy()
# features_copy.remove("Estado del actuador")
# for feature2 in features_copy:
#     shap.plots.scatter(
#         shap_values_1[:, "Estado del actuador"],
#         color=shap_values_1[:, feature2]
#         )

# %%
# shap.plots.scatter(
#     shap_values_1[:, "Energía para enfriamiento"],
#     color=shap_values_1[:, "Temperatura de bulbo seco"]
#     )

# %%
"""
Heatmap
========

Passing a matrix of SHAP values to the heatmap plot function creates a plot with the instances on the x-axis, 
the model inputs on the y-axis, and the SHAP values encoded on a color scale. By default the samples are ordered 
using shap.order.hclust, which orders the samples based on a hierarchical clustering by their explanation 
similarity. This results in samples that have the same model output for the same reason getting grouped together 
(such as people with a high impact from capital gain in the plot below).

The output of the model is shown above the heatmap matrix (centered around the explaination’s .base_value), and 
the global importance of each model input shown as a bar plot on the right hand side of the plot (by default this 
is the shap.order.abs.mean measure of overall importance).
"""
shap.plots.heatmap(shap_values_accion_0)
shap.plots.heatmap(shap_values_accion_1)
# Out:
# <Axes: xlabel='Instances'>

# %%
# for i in range(len(background_data_np_sample)):
#     shap.initjs()
#     shap.force_plot(explainer.expected_value, shap_values[i], background_data_np_sample[i], matplotlib=True, show=True)

# for i in range(14):
#     shap.dependence_plot(i, shap_values, background_data_np_sample)

# %%
# Parameter importance

# import eli5
# from eli5.sklearn import PermutationImportance

# val_X = df["observations"][0:100]
# val_y = df["actions"][0:100]

# perm = PermutationImportance(model_predict, random_state=1).fit(val_X, val_y)
# eli5.show_weights(perm, feature_names = val_X.columns.tolist())
