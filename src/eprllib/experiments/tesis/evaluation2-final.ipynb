# %%
import os
os.environ['RAY_DEDUP_LOGS'] = '0'

import numpy as np
import shap
import matplotlib.pyplot as plt
import json

from tempfile import TemporaryDirectory
from typing import List, Dict

import ray
from ray.tune import register_env
from ray.rllib.algorithms.algorithm import Algorithm
from ray.rllib.policy.policy import Policy

from ray.rllib.models import ModelCatalog
from eprllib.examples.example_central_agent_files.policy_model import CustomTransformerModel
ModelCatalog.register_custom_model("custom_transformer", CustomTransformerModel)

from eprllib.Environment.Environment import Environment
from eprllib.Environment.EnvironmentConfig import EnvironmentConfig
from eprllib.Agents.Filters.DefaultFilter import DefaultFilter
from eprllib.Agents.Triggers.SetpointTriggers import DualSetpointTriggerDiscreteAndAvailabilityTrigger
# from eprllib.Agents.Rewards.EnergyAndAshrae55SimpleModel import EnergyAndASHRAE55SimpleModel
from eprllib.Agents.Rewards.NygardFerguson1990 import NygardFerguson1990
from eprllib.AgentsConnectors.DefaultConnector import DefaultConnector

from eprllib.Agents.AgentSpec import (
    AgentSpec,
    ObservationSpec,
    RewardSpec,
    ActionSpec,
    TriggerSpec,
    FilterSpec
)
from eprllib.examples.example_thermostat_files.curriculum_learning import episode_fn
from eprllib.examples.example_thermostat_files.policy_mapping import policy_map_fn

from eprllib.PostProcess.Evaluation import generate_experience
from eprllib.AgentsConnectors.BaseConnector import BaseConnector

with open("C:/Users/grhen/Documents/GitHub2/eprllib/src/eprllib/examples/example_thermostat_files/curriculum_evaluation.json", "r") as f:
    episode_config = json.load(f)
# Out:
# WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
checkpoint_path = "C:/Users/grhen/ray_results/tesis/20251112165548-task2/PPO-95c04_00000/checkpoint_000049"

# %%
"""
Esta configuración debe coincidir con la de entrenamiento.
"""
experiment_name:str = "tesis"
name:str = "task2"

eprllib_config = EnvironmentConfig()
eprllib_config.generals(
    epjson_path = "src/eprllib/examples/example_central_agent_files/model.epJSON",
    epw_path = "src/eprllib/examples/example_central_agent_files/weathers/ESP_PV_San.Sebastian-Igueldo.080270_TMYx.2004-2018.epw",
    output_path = TemporaryDirectory("output","",'C:/Users/grhen/Documents/Resultados_RLforEP').name,
    ep_terminal_output = False,
    timeout = 10,
    evaluation = False,
)
eprllib_config.connector(
    connector_fn = DefaultConnector,
    connector_fn_config = {},
)
eprllib_config.agents(
    agents_config = {
        "HVAC": AgentSpec(
            observation = ObservationSpec(
                variables = [
                    ("Site Outdoor Air Drybulb Temperature", "Environment"),
                    # ("Site Outdoor Air Relative Humidity", "Environment"),
                    ("Zone Mean Air Temperature", "Thermal Zone"),
                    # ("Zone Air Relative Humidity", "Thermal Zone"),
                    ("Zone People Occupant Count", "Thermal Zone"),
                    ("Zone Thermal Comfort Fanger Model PMV", "People")
                ],
                # simulation_parameters = {
                #     'hour': True,
                #     'day_of_week': True,
                #     'minutes': True,
                #     'day_of_year': True,
                #     # 'today_weather_horizontal_ir_at_time': True,
                # },
                meters = [
                    "Electricity:Building",
                    "Heating:DistrictHeatingWater",
                    "Cooling:DistrictCooling",
                ],
                use_actuator_state = True,
                use_one_day_weather_prediction = False,
                weather_prediction_hours = 3,
                prediction_variables = {
                    'outdoor_dry_bulb': True,
                },
                # internal_variables = [
                #     ("Zone Floor Area", "Thermal Zone"),
                # ],
                # history_len=6,
                user_occupation_funtion = False,
                user_type = "Office schedule",
                zone_type = "daytime",
                occupation_schedule = ("Schedule:Constant", "Schedule Value", "occupancy_schedule"),
                user_occupation_forecast = False,
                occupation_prediction_hours = 3,
                summer_months = [11, 12, 1, 2],
                # other_obs = {
                #     "war_north": 0,  # Window-to-wall ratio north
                #     "war_south": 0,  # Window-to-wall ratio south
                #     "war_east": 0,   # Window-to-wall ratio east
                #     "war_west": 0,   # Window-to-wall ratio west
                #     "latitude": 0,  # Latitude
                #     "longitude": 0,  # Longitude
                #     # "elevation": 0,  # Elevation
                #     # "time_zone": 0,  # Time zone
                # }
            ),
            action = ActionSpec(
                actuators = [
                    ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                ],
            ),
            filter= FilterSpec(
                filter_fn = DefaultFilter,
                filter_fn_config = {},
            ),
            trigger= TriggerSpec(
                trigger_fn = DualSetpointTriggerDiscreteAndAvailabilityTrigger,
                trigger_fn_config = {
                    'temperature_range': (17, 28),
                    # "band_gap_range_len": 3,
                    "action_space_dim": 11,
                    'actuator_for_cooling': ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    'actuator_for_heating': ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    'availability_actuator': ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                },
            ),
            reward = RewardSpec(
                reward_fn = NygardFerguson1990,
                reward_fn_config = {
                    "thermal_zone": "Thermal Zone",
                    "C2": 6000,
                    'people_name': "People",
                    'cooling_name': "Cooling:DistrictCooling",
                    'heating_name': "Heating:DistrictHeatingWater",
                    'cooling_energy_ref': 0,
                    'heating_energy_ref': 0,
                },
            ),
        ),
    }
)

eprllib_config.episodes(
    episode_fn = episode_fn,
    episode_fn_config = episode_config,
    # cut_episode_len = 2
)

assert eprllib_config.agents_config is not None, "Agents configuration is not defined."

number_of_agents = len([keys for keys in eprllib_config.agents_config.keys()])
ray.init(_temp_dir='C:/Users/grhen/ray_results/tmp')
register_env(name="EPEnv", env_creator=lambda args: Environment(args))
env_config = eprllib_config.to_dict()

old_algo = Algorithm.from_checkpoint(checkpoint_path)
# Out:
# 2025-11-13 11:03:33,463	INFO worker.py:1918 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\algorithms\algorithm.py:520: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=24572) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=24572)
# (pid=8036) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=8036)
# (pid=13884) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=13884)
# (pid=22032) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=22032)
# (pid=6052) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=6052)
# (pid=6664) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=6664)
# (pid=5812) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=5812)
# 2025-11-13 11:04:29,787	INFO trainable.py:161 -- Trainable.setup took 51.509 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2025-11-13 11:04:29,790	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
# ray.shutdown()

# %%
single_policy = old_algo.get_policy("single_policy")

# Generate experience
df = generate_experience(
    env = Environment,
    env_config = env_config,
    policies = {
        "HVAC": single_policy,
    },
    num_episodes = 1
)

old_algo.stop()
ray.shutdown()

# %%
feature_names: Dict[str, List[str]] = {agent: [] for agent in env_config["agents_config"].keys()}
feature_names_index: Dict[str, Dict[str, int]] = {agent: {} for agent in env_config["agents_config"].keys()}
connector_fn: BaseConnector = env_config['connector_fn'](env_config["connector_fn_config"])

for agent in env_config["agents_config"].keys():
    connector_fn.get_agent_obs_dim(env_config,agent)
    feature_names_index[agent] = connector_fn.get_agent_obs_indexed(env_config,agent)
    for key in feature_names_index[agent].keys():
        feature_names[agent].append(key)

for agent in feature_names.keys():
    if env_config["agents_config"][agent]["observation"]["history_len"] > 1:
        feature_names_h = feature_names[agent].copy()
        for h in range(env_config["agents_config"][agent]["observation"]["history_len"]):
            feature_names_h_new: List[str] = []
            for value in feature_names_h:
                feature_names_h_new.append(f"h{h}_{value}")
            feature_names[agent].extend(feature_names_h_new)

# %%
feature_names
# Out:
# {'HVAC': ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#   'HVAC: Zone Mean Air Temperature: Thermal Zone',
#   'HVAC: Zone People Occupant Count: Thermal Zone',
#   'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#   'HVAC: Electricity:Building',
#   'HVAC: Heating:DistrictHeatingWater',
#   'HVAC: Cooling:DistrictCooling',
#   'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#   'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#   'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']}

# %%
df
# Out:
# {'experiment': {'episode_1': {'timestep_1': {'HVAC': {'observation': array([11.55, 24.  ,  1.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,
#              0.  ], dtype=float32),
#      'action': None,
#      'reward': 0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_2': {'HVAC': {'observation': array([11.55     , 21.350407 ,  1.       , -1.0007743,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.00021259913475499075),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_3': {'HVAC': {'observation': array([11.1      , 21.14073  ,  1.       , -1.0697167,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.00026415710395092317),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_4': {'HVAC': {'observation': array([10.65     , 20.504345 ,  1.       , -1.1780581,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0003710293761322632),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_5': {'HVAC': {'observation': array([10.2      , 19.451466 ,  1.       , -1.3857963,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0007188152709043395),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_6': {'HVAC': {'observation': array([ 9.7500000e+00,  1.8902485e+01,  1.0000000e+00, -1.5109793e+00,
#              0.0000000e+00,  2.9126125e+04,  0.0000000e+00,  1.8833334e+01,
#              2.6500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.001086958462993467),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_7': {'HVAC': {'observation': array([ 9.3000002e+00,  2.2227516e+01,  1.0000000e+00, -9.6476656e-01,
#              0.0000000e+00,  1.1539069e+06,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00018964596780279375),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_8': {'HVAC': {'observation': array([ 9.2333336e+00,  2.2500000e+01,  1.0000000e+00, -8.9754415e-01,
#              0.0000000e+00,  7.6798769e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00015280546581191134),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_9': {'HVAC': {'observation': array([ 9.1666670e+00,  2.2500000e+01,  1.0000000e+00, -9.0076125e-01,
#              0.0000000e+00,  1.0037871e+06,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00015440948129288423),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_10': {'HVAC': {'observation': array([ 9.1000004e+00,  2.2500000e+01,  1.0000000e+00, -9.0394258e-01,
#              0.0000000e+00,  9.5469875e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00015600890326958984),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_11': {'HVAC': {'observation': array([ 9.0333338e+00,  2.2500000e+01,  1.0000000e+00, -9.0726507e-01,
#              0.0000000e+00,  9.4503262e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.000157695392309389),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_12': {'HVAC': {'observation': array([ 8.9666662e+00,  2.2500000e+01,  1.0000000e+00, -9.1068631e-01,
#              0.0000000e+00,  9.4064906e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00015944924074267526),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_13': {'HVAC': {'observation': array([ 8.8999996e+00,  2.2500000e+01,  1.0000000e+00, -9.1336423e-01,
#              0.0000000e+00,  9.3594406e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00016083428142820498),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_14': {'HVAC': {'observation': array([ 8.8500004e+00,  2.2500000e+01,  1.0000000e+00, -9.1413581e-01,
#              0.0000000e+00,  4.6496512e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001612327163161557),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_15': {'HVAC': {'observation': array([ 8.8000002e+00,  2.2500000e+01,  1.0000000e+00, -9.1441584e-01,
#              0.0000000e+00,  4.9611659e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00016137863437204868),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_16': {'HVAC': {'observation': array([ 8.7500000e+00,  2.2500000e+01,  1.0000000e+00, -9.1639656e-01,
#              0.0000000e+00,  8.6559200e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001624153782942043),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_17': {'HVAC': {'observation': array([ 8.6999998e+00,  2.2500000e+01,  1.0000000e+00, -9.1882706e-01,
#              0.0000000e+00,  8.7797944e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001636932620962126),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_18': {'HVAC': {'observation': array([ 8.6499996e+00,  2.2500000e+01,  1.0000000e+00, -9.2112935e-01,
#              0.0000000e+00,  9.1072600e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00016491225845443098),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_19': {'HVAC': {'observation': array([ 8.600000e+00,  2.250000e+01,  1.000000e+00, -9.228535e-01,
#              0.000000e+00,  8.275868e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001658299254793214),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_20': {'HVAC': {'observation': array([ 8.566667e+00,  2.250000e+01,  1.000000e+00, -9.247019e-01,
#              0.000000e+00,  8.786316e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00016681967589696322),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_21': {'HVAC': {'observation': array([ 8.5333338e+00,  2.2500000e+01,  1.0000000e+00, -9.2670786e-01,
#              0.0000000e+00,  8.4864812e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001678994047237965),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_22': {'HVAC': {'observation': array([ 8.5000000e+00,  2.2500000e+01,  1.0000000e+00, -9.2872894e-01,
#              0.0000000e+00,  8.1059075e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001689936853659276),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_23': {'HVAC': {'observation': array([ 8.466666e+00,  2.250000e+01,  1.000000e+00, -9.307715e-01,
#              0.000000e+00,  7.857104e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001701062842944479),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_24': {'HVAC': {'observation': array([ 8.4333334e+00,  2.2500000e+01,  1.0000000e+00, -9.3128151e-01,
#              0.0000000e+00,  3.7587266e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001703828963872404),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_25': {'HVAC': {'observation': array([ 8.3999996e+00,  2.2500000e+01,  1.0000000e+00, -9.3132806e-01,
#              0.0000000e+00,  3.5634534e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017040826830265395),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_26': {'HVAC': {'observation': array([ 8.3666668e+00,  2.2500000e+01,  1.0000000e+00, -9.3186027e-01,
#              0.0000000e+00,  4.0931550e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017070005663990956),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_27': {'HVAC': {'observation': array([ 8.3333330e+00,  2.2500000e+01,  1.0000000e+00, -9.3292922e-01,
#              0.0000000e+00,  4.5958062e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017128721539593002),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_28': {'HVAC': {'observation': array([ 8.3000002e+00,  2.2500000e+01,  1.0000000e+00, -9.3437868e-01,
#              0.0000000e+00,  5.0768744e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017208620491098407),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_29': {'HVAC': {'observation': array([ 8.266666e+00,  2.250000e+01,  1.000000e+00, -9.359437e-01,
#              0.000000e+00,  5.540176e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017295268878609834),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_30': {'HVAC': {'observation': array([ 8.2333336e+00,  2.2500000e+01,  1.0000000e+00, -9.3748957e-01,
#              0.0000000e+00,  5.9885238e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001738125130271982),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_31': {'HVAC': {'observation': array([ 8.200000e+00,  2.250000e+01,  1.000000e+00, -9.389609e-01,
#              0.000000e+00,  6.424070e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017463448643020122),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_32': {'HVAC': {'observation': array([ 8.1499996e+00,  2.2500000e+01,  1.0000000e+00, -9.3992043e-01,
#              0.0000000e+00,  4.0653866e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017517103395464707),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_33': {'HVAC': {'observation': array([ 8.1000004e+00,  2.2500000e+01,  1.0000000e+00, -9.3801016e-01,
#              0.0000000e+00,  4.5152977e+04,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001740998553601246),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_34': {'HVAC': {'observation': array([ 8.0500002e+00,  2.2500000e+01,  1.0000000e+00, -9.3893021e-01,
#              0.0000000e+00,  3.6065997e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001746157837723256),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_35': {'HVAC': {'observation': array([ 8.0000000e+00,  2.2500000e+01,  1.0000000e+00, -9.4426894e-01,
#              0.0000000e+00,  6.1766569e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00017762869542476006),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_36': {'HVAC': {'observation': array([ 7.950000e+00,  2.250000e+01,  1.000000e+00, -9.517192e-01,
#              0.000000e+00,  8.223767e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0001819124991112442),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_37': {'HVAC': {'observation': array([ 7.900000e+00,  2.250000e+01,  1.000000e+00, -9.584538e-01,
#              0.000000e+00,  8.404827e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00018586581051693648),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_38': {'HVAC': {'observation': array([ 7.8833332e+00,  2.2500000e+01,  1.0000000e+00, -1.3092225e+00,
#              0.0000000e+00,  8.4608494e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005617702945128828),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_39': {'HVAC': {'observation': array([ 7.8666668e+00,  2.2500000e+01,  1.0000000e+00, -1.3123385e+00,
#              0.0000000e+00,  8.5169862e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005673904895102686),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_40': {'HVAC': {'observation': array([ 7.8499999e+00,  2.2500000e+01,  1.0000000e+00, -1.3146093e+00,
#              0.0000000e+00,  8.5731112e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005715236882957094),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_41': {'HVAC': {'observation': array([ 7.8333335e+00,  2.2500000e+01,  1.0000000e+00, -1.3165270e+00,
#              0.0000000e+00,  8.6292131e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005750391003224366),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_42': {'HVAC': {'observation': array([ 7.8166666e+00,  2.2500000e+01,  1.0000000e+00, -1.3182832e+00,
#              0.0000000e+00,  8.6852956e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005782785475528347),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_43': {'HVAC': {'observation': array([ 7.8000002e+00,  2.2500000e+01,  1.0000000e+00, -1.3199452e+00,
#              0.0000000e+00,  8.7413494e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005813620914158281),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_44': {'HVAC': {'observation': array([ 7.7833333e+00,  2.2500000e+01,  1.0000000e+00, -1.3208207e+00,
#              0.0000000e+00,  8.5276381e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005829932789947856),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_45': {'HVAC': {'observation': array([ 7.7666669e+00,  2.2500000e+01,  1.0000000e+00, -1.3208306e+00,
#              0.0000000e+00,  7.5856019e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005830111981637896),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_46': {'HVAC': {'observation': array([ 7.750000e+00,  2.250000e+01,  1.000000e+00, -1.319316e+00,
#              0.000000e+00,  3.745466e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005801900790293318),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_47': {'HVAC': {'observation': array([ 7.7333331e+00,  2.2500000e+01,  1.0000000e+00, -1.3170264e+00,
#              0.0000000e+00,  2.9728316e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005759552091026006),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_48': {'HVAC': {'observation': array([ 7.7166667e+00,  2.2500000e+01,  1.0000000e+00, -1.3166841e+00,
#              0.0000000e+00,  7.0489638e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005753273248320867),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_49': {'HVAC': {'observation': array([ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3174660e+00,
#              0.0000000e+00,  8.4872606e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005767686379805281),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_50': {'HVAC': {'observation': array([ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3184066e+00,
#              0.0000000e+00,  8.3604694e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005785066959589751),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_51': {'HVAC': {'observation': array([ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3187406e+00,
#              0.0000000e+00,  6.6133731e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005791243290590509),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_52': {'HVAC': {'observation': array([ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3181452e+00,
#              0.0000000e+00,  4.4268334e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005780209682565361),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_53': {'HVAC': {'observation': array([ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3157133e+00,
#              0.0000000e+00,  1.4179459e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005735408003635939),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_54': {'HVAC': {'observation': array([ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3091475e+00,
#              0.0000000e+00,  2.8986634e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005616327796575929),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_55': {'HVAC': {'observation': array([ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3071365e+00,
#              0.0000000e+00,  5.4294512e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005580393887610111),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_56': {'HVAC': {'observation': array([ 7.9499998e+00,  2.2500000e+01,  1.0000000e+00, -1.3063488e+00,
#              0.0000000e+00,  8.2794362e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005566394145457537),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_57': {'HVAC': {'observation': array([ 8.1999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3051456e+00,
#              0.0000000e+00,  8.3546356e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005545061395803288),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_58': {'HVAC': {'observation': array([ 8.450000e+00,  2.250000e+01,  1.000000e+00, -1.302381e+00,
#              0.000000e+00,  8.536898e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005496368801621475),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_59': {'HVAC': {'observation': array([ 8.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.2979640e+00,
#              0.0000000e+00,  8.7710175e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005419506258174488),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_60': {'HVAC': {'observation': array([ 8.9499998e+00,  2.2500000e+01,  1.0000000e+00, -1.2928467e+00,
#              0.0000000e+00,  8.1905031e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005331871281802964),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_61': {'HVAC': {'observation': array([ 9.1999998e+00,  2.2500000e+01,  1.0000000e+00, -1.2871909e+00,
#              0.0000000e+00,  7.6473956e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005236752020120634),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_62': {'HVAC': {'observation': array([ 9.5833330e+00,  2.2500000e+01,  1.0000000e+00, -1.2804775e+00,
#              0.0000000e+00,  6.5768381e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005126158482843332),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_63': {'HVAC': {'observation': array([ 9.966666 , 22.844627 ,  1.       , -1.2153622,  0.       ,
#              0.       ,  0.       , 22.5      , 23.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0004172071806639002),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_64': {'HVAC': {'observation': array([ 1.0350000e+01,  1.9844683e+01,  1.0000000e+00, -1.7687422e+00,
#              0.0000000e+00,  6.9732820e+04,  0.0000000e+00,  1.8833334e+01,
#              2.6500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.002695421501717236),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_65': {'HVAC': {'observation': array([ 1.0733334e+01,  2.2355658e+01,  1.0000000e+00, -1.3240988e+00,
#              0.0000000e+00,  8.1213788e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005891455781231665),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_66': {'HVAC': {'observation': array([ 1.1116667e+01,  2.2500000e+01,  1.0000000e+00, -1.2544851e+00,
#              0.0000000e+00,  4.6635578e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00047205758261838877),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_67': {'HVAC': {'observation': array([ 1.150000e+01,  2.250000e+01,  1.000000e+00, -1.245645e+00,
#              0.000000e+00,  6.689850e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0004590425245814518),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_68': {'HVAC': {'observation': array([ 1.1800000e+01,  2.2500000e+01,  1.0000000e+00, -1.2387289e+00,
#              0.0000000e+00,  5.7779438e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00044911933129414955),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_69': {'HVAC': {'observation': array([ 1.2100000e+01,  2.2500000e+01,  1.0000000e+00, -1.2324078e+00,
#              0.0000000e+00,  4.5013047e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0004402447971725656),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_70': {'HVAC': {'observation': array([12.4      , 22.679993 ,  1.       , -1.1946908,  0.       ,
#              0.       ,  0.       , 22.5      , 23.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0003909332663518315),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_71': {'HVAC': {'observation': array([12.7      , 20.50574  ,  1.       , -1.5935735,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0014407447234951072),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_72': {'HVAC': {'observation': array([13.       , 20.133152 ,  1.       , -1.6966237,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.002072076937326215),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_73': {'HVAC': {'observation': array([13.3      , 20.107136 ,  1.       , -1.6896216,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0020206315551500906),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_74': {'HVAC': {'observation': array([13.666667 , 20.154055 ,  1.       , -1.6774626,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0019346259010869205),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_75': {'HVAC': {'observation': array([14.033334 , 20.245115 ,  1.       , -1.6553352,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0017883136248839984),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_76': {'HVAC': {'observation': array([14.4      , 20.36089  ,  1.       , -1.6280175,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.001624308530990091),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_77': {'HVAC': {'observation': array([14.766666 , 20.472578 ,  1.       , -1.6041418,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0014945083506844304),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_78': {'HVAC': {'observation': array([15.133333 , 20.579344 ,  1.       , -1.5809149,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0013791353171052371),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_79': {'HVAC': {'observation': array([15.5      , 20.688513 ,  1.       , -1.5572864,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0012717495468853046),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_80': {'HVAC': {'observation': array([15.766666 , 20.85147  ,  1.       , -1.5218198,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0011274136937347626),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_81': {'HVAC': {'observation': array([16.033333 , 21.03947  ,  1.       , -1.4794736,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0009781277783458317),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_82': {'HVAC': {'observation': array([16.3      , 21.224533 ,  1.       , -1.4367992,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0008492264108820492),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_83': {'HVAC': {'observation': array([16.566668 , 21.40876  ,  1.       , -1.3954487,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0007417320556900591),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_84': {'HVAC': {'observation': array([16.833334 , 21.596045 ,  1.       , -1.3536187,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0006477517918009572),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_85': {'HVAC': {'observation': array([17.1      , 21.782879 ,  1.       , -1.3118155,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0005664385975790503),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_86': {'HVAC': {'observation': array([17.25     , 21.874752 ,  1.       , -1.2883484,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0005256027616971474),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_87': {'HVAC': {'observation': array([17.4      , 21.90418  ,  1.       , -1.2795027,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0005110267152528994),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_88': {'HVAC': {'observation': array([17.55    , 21.933598,  1.      , -1.269634,  0.      ,  0.      ,
#              0.      , 18.833334, 26.5     ,  1.      ], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0004952650621625255),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_89': {'HVAC': {'observation': array([17.7      , 21.974482 ,  1.       , -1.2584287,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.000477984867365359),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_90': {'HVAC': {'observation': array([17.85     , 22.016626 ,  1.       , -1.2469064,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.00046087205232999854),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_91': {'HVAC': {'observation': array([18.       , 22.054972 ,  1.       , -1.2362453,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0004456068297216336),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_92': {'HVAC': {'observation': array([18.033333 , 22.045876 ,  1.       , -1.2360665,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0004453552892497775),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_93': {'HVAC': {'observation': array([18.066668 , 22.009586 ,  1.       , -1.2432564,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0004555854061050525),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_94': {'HVAC': {'observation': array([18.1      , 22.003803 ,  1.       , -1.2457968,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0004592581677209114),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_95': {'HVAC': {'observation': array([18.133333 , 22.033993 ,  1.       , -1.2409626,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.00045229542858581323),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_96': {'HVAC': {'observation': array([18.166666 , 22.069025 ,  1.       , -1.2349927,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0004438482240034463),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_97': {'HVAC': {'observation': array([18.2      , 22.091995 ,  1.       , -1.2314214,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.00043887326667390274),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_98': {'HVAC': {'observation': array([18.133333 , 22.273815 ,  1.       , -1.2012879,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.00039912804765769144),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_99': {'HVAC': {'observation': array([18.066668 , 22.596884 ,  1.       , -1.1462922,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0003358365158592214),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_100': {'HVAC': {'observation': array([18.       , 22.310202 ,  1.       , -1.1918644,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0003874753205343523),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_101': {'HVAC': {'observation': array([17.933332 , 22.05294  ,  1.       , -1.2434607,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.00045587961546836764),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_102': {'HVAC': {'observation': array([17.866667 , 21.914293 ,  1.       , -1.2788181,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0005099165001239583),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_103': {'HVAC': {'observation': array([17.8      , 21.856194 ,  1.       , -1.2971433,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0005405302232460874),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_104': {'HVAC': {'observation': array([17.616667 , 21.81296  ,  1.       , -1.3113441,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0005655860437008782),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_105': {'HVAC': {'observation': array([17.433332 , 21.759466 ,  1.       , -1.3263248,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0005933567238716846),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_106': {'HVAC': {'observation': array([17.25     , 21.70135  ,  1.       , -1.3415712,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0006231134790923871),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_107': {'HVAC': {'observation': array([17.066668 , 21.643944 ,  1.       , -1.3570743,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0006550092699821609),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_108': {'HVAC': {'observation': array([16.883333, 21.591051,  1.      , -1.370605,  0.      ,  0.      ,
#              0.      , 18.833334, 26.5     ,  1.      ], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0006842760097679842),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_109': {'HVAC': {'observation': array([16.7     , 21.54092 ,  1.      , -1.383675,  0.      ,  0.      ,
#              0.      , 18.833334, 26.5     ,  1.      ], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0007138816876861003),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_110': {'HVAC': {'observation': array([16.45     , 21.469093 ,  1.       , -1.4010078,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0007552865794459574),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_111': {'HVAC': {'observation': array([16.2      , 21.384037 ,  1.       , -1.4210283,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0008063615956442177),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_112': {'HVAC': {'observation': array([15.95     , 21.29979  ,  1.       , -1.4406956,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0008601932576453016),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_113': {'HVAC': {'observation': array([15.7      , 21.221891 ,  1.       , -1.4575363,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0009093929613505287),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_114': {'HVAC': {'observation': array([15.45     , 21.147734 ,  1.       , -1.4732913,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0009582014648881311),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_115': {'HVAC': {'observation': array([15.2     , 21.073805,  1.      , -1.48907 ,  0.      ,  0.      ,
#              0.      , 18.833334, 26.5     ,  1.      ], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0010099595953252387),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_116': {'HVAC': {'observation': array([15.1      , 21.0293   ,  1.       , -1.4994073,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0010455189666625023),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_117': {'HVAC': {'observation': array([15.       , 21.001556 ,  1.       , -1.5069611,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.001072368940436089),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_118': {'HVAC': {'observation': array([14.9      , 20.973925 ,  1.       , -1.5145723,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0011001877628871897),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_119': {'HVAC': {'observation': array([14.8      , 20.943169 ,  1.       , -1.5230863,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0011322465195155152),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_120': {'HVAC': {'observation': array([14.7      , 20.91219  ,  1.       , -1.5316322,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0011654578658960237),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_121': {'HVAC': {'observation': array([14.6      , 20.882181 ,  1.       , -1.5401192,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0011995008142576568),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_122': {'HVAC': {'observation': array([14.483334 , 20.746405 ,  1.       , -1.5698528,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0013276673351300505),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_123': {'HVAC': {'observation': array([14.366667 , 20.554438 ,  1.       , -1.6122363,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0015371841868733313),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_124': {'HVAC': {'observation': array([14.25     , 20.3689   ,  1.       , -1.6545205,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0017831661675256738),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_125': {'HVAC': {'observation': array([14.133333 , 20.197199 ,  1.       , -1.6944761,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0020561461977183764),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_126': {'HVAC': {'observation': array([14.016666, 20.027235,  1.      , -1.734105,  0.      ,  0.      ,
#              0.      , 18.833334, 26.5     ,  1.      ], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0023733473253608724),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_127': {'HVAC': {'observation': array([13.9      , 19.85509  ,  1.       , -1.7743201,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.002751683969856649),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_128': {'HVAC': {'observation': array([13.8     , 19.796299,  1.      , -1.792004,  0.      ,  0.      ,
#              0.      , 18.833334, 26.5     ,  1.      ], dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.002938846089108601),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_129': {'HVAC': {'observation': array([13.7      , 19.79051  ,  1.       , -1.7976983,  0.       ,
#              0.       ,  0.       , 18.833334 , 26.5      ,  1.       ],
#            dtype=float32),
#      'action': np.int32(7),
#      'reward': np.float64(-0.0030020855060058477),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_130': {'HVAC': {'observation': array([13.6      , 19.77824  ,  1.       , -1.8039948,  0.       ,
# ...
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005560333987992898),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_251': {'HVAC': {'observation': array([ 1.3666667e+01,  2.2500000e+01,  1.0000000e+00, -1.3105115e+00,
#              0.0000000e+00,  3.4965084e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005640864692853067),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_252': {'HVAC': {'observation': array([ 1.3583333e+01,  2.2500000e+01,  1.0000000e+00, -1.3149878e+00,
#              0.0000000e+00,  3.0659031e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.000572213721065185),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_253': {'HVAC': {'observation': array([ 1.3500000e+01,  2.2500000e+01,  1.0000000e+00, -1.3197219e+00,
#              0.0000000e+00,  2.5593044e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.000580944284356476),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_254': {'HVAC': {'observation': array([ 1.3350000e+01,  2.2500000e+01,  1.0000000e+00, -1.3253275e+00,
#              0.0000000e+00,  2.8195247e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0005914659067486005),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_255': {'HVAC': {'observation': array([ 1.3200000e+01,  2.2500000e+01,  1.0000000e+00, -1.3317845e+00,
#              0.0000000e+00,  2.9605675e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00060383719956951),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_256': {'HVAC': {'observation': array([ 1.3050000e+01,  2.2500000e+01,  1.0000000e+00, -1.3384689e+00,
#              0.0000000e+00,  3.1041828e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006169347461606034),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_257': {'HVAC': {'observation': array([ 1.2900000e+01,  2.2500000e+01,  1.0000000e+00, -1.3413335e+00,
#              0.0000000e+00,  3.2596747e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006226400467294309),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_258': {'HVAC': {'observation': array([ 1.2750000e+01,  2.2500000e+01,  1.0000000e+00, -1.3440675e+00,
#              0.0000000e+00,  3.4208084e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006281377724705179),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_259': {'HVAC': {'observation': array([ 1.2600000e+01,  2.2500000e+01,  1.0000000e+00, -1.3467231e+00,
#              0.0000000e+00,  3.5827988e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006335275000720572),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_260': {'HVAC': {'observation': array([ 1.2500000e+01,  2.2500000e+01,  1.0000000e+00, -1.3494936e+00,
#              0.0000000e+00,  3.5509988e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006392030040474771),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_261': {'HVAC': {'observation': array([ 1.2400000e+01,  2.2500000e+01,  1.0000000e+00, -1.3523731e+00,
#              0.0000000e+00,  3.5163188e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006451594151470495),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_262': {'HVAC': {'observation': array([ 1.2300000e+01,  2.2500000e+01,  1.0000000e+00, -1.3553598e+00,
#              0.0000000e+00,  3.4788275e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006514001469668564),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_263': {'HVAC': {'observation': array([ 1.2200000e+01,  2.2500000e+01,  1.0000000e+00, -1.3582830e+00,
#              0.0000000e+00,  3.4602978e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006575709752729954),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_264': {'HVAC': {'observation': array([ 1.2100000e+01,  2.2500000e+01,  1.0000000e+00, -1.3612456e+00,
#              0.0000000e+00,  3.4565781e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006638886546758377),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_265': {'HVAC': {'observation': array([ 1.2000000e+01,  2.2500000e+01,  1.0000000e+00, -1.3642001e+00,
#              0.0000000e+00,  3.4514466e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.000670253946064369),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_266': {'HVAC': {'observation': array([ 1.1883333e+01,  2.2500000e+01,  1.0000000e+00, -1.3667911e+00,
#              0.0000000e+00,  3.4744028e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006758899988719252),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_267': {'HVAC': {'observation': array([ 1.1766666e+01,  2.2500000e+01,  1.0000000e+00, -1.3689287e+00,
#              0.0000000e+00,  3.4966212e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006805776836964043),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_268': {'HVAC': {'observation': array([ 1.165000e+01,  2.250000e+01,  1.000000e+00, -1.370502e+00,
#              0.000000e+00,  3.248048e+05,  0.000000e+00,  2.250000e+01,
#              2.350000e+01,  1.000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.000684050323826965),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_269': {'HVAC': {'observation': array([ 1.1533334e+01,  2.2500000e+01,  1.0000000e+00, -1.3715270e+00,
#              0.0000000e+00,  2.9224053e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006863226534286967),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_270': {'HVAC': {'observation': array([ 1.1416667e+01,  2.2500000e+01,  1.0000000e+00, -1.3720851e+00,
#              0.0000000e+00,  2.5633545e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006875632604486789),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_271': {'HVAC': {'observation': array([ 1.1300000e+01,  2.2500000e+01,  1.0000000e+00, -1.3721721e+00,
#              0.0000000e+00,  2.1616444e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006877566606365767),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_272': {'HVAC': {'observation': array([ 1.1200000e+01,  2.2500000e+01,  1.0000000e+00, -1.3729141e+00,
#              0.0000000e+00,  2.8007725e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006894109234472468),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_273': {'HVAC': {'observation': array([ 1.1100000e+01,  2.2500000e+01,  1.0000000e+00, -1.3745290e+00,
#              0.0000000e+00,  3.2843475e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0006930257855743459),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_274': {'HVAC': {'observation': array([ 1.1000000e+01,  2.2500000e+01,  1.0000000e+00, -1.3762612e+00,
#              0.0000000e+00,  3.2001931e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.00069692523800726),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_275': {'HVAC': {'observation': array([ 1.0900000e+01,  2.2500000e+01,  1.0000000e+00, -1.3776487e+00,
#              0.0000000e+00,  3.0632153e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007000656803961778),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_276': {'HVAC': {'observation': array([ 1.0800000e+01,  2.2500000e+01,  1.0000000e+00, -1.3786596e+00,
#              0.0000000e+00,  2.9210691e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007023633957114729),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_277': {'HVAC': {'observation': array([ 1.0700000e+01,  2.2500000e+01,  1.0000000e+00, -1.3793852e+00,
#              0.0000000e+00,  2.7739688e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007040176037134856),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_278': {'HVAC': {'observation': array([ 1.0583333e+01,  2.2500000e+01,  1.0000000e+00, -1.3802464e+00,
#              0.0000000e+00,  3.1417244e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007059864774791161),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_279': {'HVAC': {'observation': array([ 1.0466666e+01,  2.2500000e+01,  1.0000000e+00, -1.3813682e+00,
#              0.0000000e+00,  3.5334841e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007085601427042727),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_280': {'HVAC': {'observation': array([ 1.0350000e+01,  2.2500000e+01,  1.0000000e+00, -1.3825479e+00,
#              0.0000000e+00,  3.7533644e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.000711277534360757),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_281': {'HVAC': {'observation': array([ 1.0233334e+01,  2.2500000e+01,  1.0000000e+00, -1.3835917e+00,
#              0.0000000e+00,  3.8991516e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007136910165099237),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_282': {'HVAC': {'observation': array([ 1.0116667e+01,  2.2500000e+01,  1.0000000e+00, -1.3844887e+00,
#              0.0000000e+00,  4.0662894e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.000715772340687224),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_283': {'HVAC': {'observation': array([ 1.0000000e+01,  2.2500000e+01,  1.0000000e+00, -1.3852885e+00,
#              0.0000000e+00,  4.2621947e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007176333919097267),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_284': {'HVAC': {'observation': array([ 9.8999996e+00,  2.2500000e+01,  1.0000000e+00, -1.3868723e+00,
#              0.0000000e+00,  4.3535538e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007213343225964061),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_285': {'HVAC': {'observation': array([ 9.8000002e+00,  2.2500000e+01,  1.0000000e+00, -1.3893650e+00,
#              0.0000000e+00,  4.4453194e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007272005962545346),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_286': {'HVAC': {'observation': array([ 9.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3925409e+00,
#              0.0000000e+00,  4.5493256e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007347493846925275),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_287': {'HVAC': {'observation': array([ 9.6000004e+00,  2.2500000e+01,  1.0000000e+00, -1.3961385e+00,
#              0.0000000e+00,  4.6851294e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007434025212168893),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_288': {'HVAC': {'observation': array([ 9.5000000e+00,  2.2500000e+01,  1.0000000e+00, -1.3999680e+00,
#              0.0000000e+00,  4.8213956e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007527340631079046),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_289': {'HVAC': {'observation': array([ 9.3999996e+00,  2.2500000e+01,  1.0000000e+00, -1.4039183e+00,
#              0.0000000e+00,  4.9581441e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007624923522105537),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_290': {'HVAC': {'observation': array([ 9.3999996e+00,  2.2500000e+01,  1.0000000e+00, -1.4039183e+00,
#              0.0000000e+00,  4.9581441e+05,  0.0000000e+00,  2.2500000e+01,
#              2.3500000e+01,  1.0000000e+00], dtype=float32),
#      'action': np.int32(1),
#      'reward': np.float64(-0.0007624923522105537),
#      'done': True,
#      'truncated': False,
#      'info': {}}}}}}

# %%
# for agent in feature_names_index.keys():
#     energy_total: List[float] = []
#     for timestep in range(1,len(df["experiment"]["episode_1"])):
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]])
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Cooling:DistrictCooling"]])
#     print(sum(energy_total)/3600000)

# %%
for agent in feature_names_index.keys():
    action_list_1: List[float] = []
    # action_list_2: List[float] = []
    av_list: List[int] = []
    t_r_list: List[float] = []
    t_c_list: List[float] = []
    t_i_list: List[float] = []
    occ_list: List[float] = []
    t_out_list: List[float] = []
    energy_list: List[float] = []
    pmv_list: List[float] = []
    pmv_hist: List[float] = []
    
    temp_range = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["temperature_range"]
    temp_avg = (min(temp_range)+max(temp_range))/2
    
    for timestep in range(1,len(df["experiment"]["episode_1"])):
        if env_config["agents_config"][agent]["observation"]["history_len"] > 1:
            t_i_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Mean Air Temperature: Thermal Zone"]])
            t_out_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Site Outdoor Air Drybulb Temperature: Environment"]])
            energy_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]]/3600000)
            occ_t = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone People Occupant Count: Thermal Zone"]]
            if occ_t > 0:
                occ_list.append(occ_t)
                pmv_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
                pmv_hist.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
            else:
                occ_list.append(0)
                pmv_list.append(0)
        
        else:
            t_i_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Mean Air Temperature: Thermal Zone"]])
            t_out_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Site Outdoor Air Drybulb Temperature: Environment"]])
            energy_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]]/3600000)
            occ_t = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone People Occupant Count: Thermal Zone"]]
            if occ_t > 0:
                occ_list.append(occ_t)
                pmv_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
                pmv_hist.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
            else:
                occ_list.append(0)
                pmv_list.append(0)
        
        
        if df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"] is None:
            pass
        else:
            action = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"]
            # a1 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][0]
            # a2 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][1]
            action_list_1.append(action)
            # action_list_2.append(a2)
            
            action_range: int = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["action_space_dim"]
            if action > 0:
                t_r_list.append(temp_avg + (((action-1)/9)*(max(temp_range)-1-temp_avg)) + 1)
                t_c_list.append(temp_avg - (((action-1)/9)*(temp_avg-min(temp_range))))
                av_list.append(action)
            else:
                t_r_list.append(0)
                t_c_list.append(0)
                av_list.append(0)

# %%
# t_c_list
for agent in feature_names_index.keys():
    # 2. Histogram
    plt.figure(figsize=(7, 5))
    # plt.hist(action_list_2, bins=11, color='skyblue', edgecolor='black')
    plt.hist(t_c_list, bins=100, color='lightgreen', edgecolor='black')
    plt.xlabel('Temperatura')
    # plt.xlim((0, 10))
    plt.ylabel('Frecuencia')
    # plt.xticks(np.arange(0, 11))
    # plt.ylim((0, 1))
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
for agent in feature_names_index.keys():
    # 1. Time series plot
    plt.figure(figsize=(7, 5))
    plt.subplot(2, 1, 1)
    plt.plot(t_r_list, label='Tr', color='blue', alpha=0.6)
    plt.plot(t_c_list, label='Tc', color='red', alpha=0.6)
    plt.plot(t_i_list, label='Ti', color='green', alpha=0.6)
    plt.plot(t_out_list, label='To', color='black', alpha=0.6)
    plt.ylabel('Temperatura, °C')
    plt.grid(True, alpha=0.3)
    plt.legend(loc='upper left', bbox_to_anchor=(-0.37, 1), fontsize=9)
    
    plt.subplot(2, 1, 2)
    # plt.plot(av_list, label='Acción', color='red', alpha=0.6)
    plt.plot(occ_list, label='Ocupación', color='blue', alpha=0.6)
    plt.plot(pmv_list, label='PMV', color='green', alpha=0.6)
    plt.plot(energy_list, label='Energía', color='purple', alpha=0.6)
    plt.legend(loc='upper left', bbox_to_anchor=(-0.37, 1), fontsize=9)
    plt.xlabel('Paso de tiempo')
    plt.ylabel('Energía, kWh | adim')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
for agent in feature_names_index.keys():
    # 2. Histogram
    plt.figure(figsize=(7, 5))
    # plt.hist(action_list_2, bins=11, color='skyblue', edgecolor='black')
    plt.hist(action_list_1, bins=np.arange(-0.5, 11.5, 1), color='lightgreen', edgecolor='black')
    plt.xlabel('Valor de la action')
    plt.xlim((0, 10))
    plt.ylabel('Frecuencia')
    plt.xticks(np.arange(0, 11))
    # plt.ylim((0, 1))
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
for agent in feature_names_index.keys():
    # 3. PMV histogram plot    
    plt.figure(figsize=(7, 5))
    plt.hist(pmv_hist, bins=100, color='lightgreen')#, edgecolor='black')
    plt.xlabel('PMV Value')
    plt.xlim((-3, 3))
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# Basic statistical analysis
for agent in feature_names_index.keys():
    print(f"\nStatistical Summary ({agent}):")
    print(f"Mean: {np.mean(action_list_1):.2f}")
    print(f"Median: {np.median(action_list_1):.2f}")
    print(f"Std Dev: {np.std(action_list_1):.2f}")
    print(f"Min: {np.min(action_list_1):.2f}")
    print(f"Max: {np.max(action_list_1):.2f}")
    # print(f"Mean: {np.mean(action_list_2):.2f}")
    # print(f"Median: {np.median(action_list_2):.2f}")
    # print(f"Std Dev: {np.std(action_list_2):.2f}")
    # print(f"Min: {np.min(action_list_2):.2f}")
    # print(f"Max: {np.max(action_list_2):.2f}")
    print(f"Total Energy Consumption (kWh): {sum(energy_list):.2f}")
# Out:
# Statistical Summary (HVAC):
# Mean: 3.04
# Median: 1.00
# Std Dev: 2.84
# Min: 1.00
# Max: 7.00
# Total Energy Consumption (kWh): 29.27

# %%
obs: List[float|int] = [-3,-2,-1,0,1,2,3]
rew: List[float] = []
for _ in range(len(obs)):
    rew.append(-(np.exp(obs[_]**2) - 1.0)/(np.exp(3**2)-1))
    
print(rew)
# Out:
# [np.float64(-1.0), np.float64(-0.006615353594489847), np.float64(-0.00021207899644323422), np.float64(-0.0), np.float64(-0.00021207899644323422), np.float64(-0.006615353594489847), np.float64(-1.0)]

# %%
norm_energy: List[float] = [1.0,0.75,0.5,0.25,0.0]
c: float = 6000 / (60/6) * (np.exp(3**2)-1)

rew_e: List[float] = []
for _ in range(len(norm_energy)):
    rew_e.append(-norm_energy[_] * (1 / c))
    
print(rew_e)
# Out:
# [np.float64(-2.0570839324364178e-07), np.float64(-1.5428129493273133e-07), np.float64(-1.0285419662182089e-07), np.float64(-5.1427098310910444e-08), np.float64(-0.0)]

# %%
labelsize = 14
time_steps = np.arange(len(action_list_1))
time_steps_1 = np.arange(len(action_list_1)+1)
# --- Creación de la figura y subgráficas ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14.5, 6))
# fig.suptitle('Análisis de Control y Ocupación', fontsize=18, fontweight='bold', y=1.02)

# --- Subgráfica 1: Gráfico de series de tiempo ---
# Determinar y aplicar el color de fondo basado en la ocupación
is_occupied = False
start_occupancy = 0
for i, occ in enumerate(occ_list):
    if occ > 0 and not is_occupied:
        is_occupied = True
        start_occupancy = i
    elif occ == 0 and is_occupied:
        is_occupied = False
        end_occupancy = i
        # Usar axvspan para crear la región sombreada.
        # El color semi-transparente ayuda a ver las líneas del grid.
        ax1.axvspan(start_occupancy, end_occupancy, color='#ADD8E6', alpha=0.3, label='Ocupado' if start_occupancy == 0 else "")

# Dibujar las líneas de las series de tiempo sobre el fondo
ax1.plot(time_steps, t_r_list, label='Temp. Refri.', color='#1f77b4', linewidth=2, linestyle='--')
ax1.plot(time_steps, t_c_list, label='Temp. Calef.', color='#1f77b4', linewidth=2, linestyle=':')
ax1.plot(time_steps_1, t_i_list, label='Temp. Interna', color='#d62728', linestyle='--')
ax1.plot(time_steps_1, t_out_list, label='Temp. Externa', color='#2ca02c', linestyle='--')

# ax1.set_title('Valores de Control y Temperaturas', fontsize=14)
ax1.set_xlabel('Paso de Tiempo', fontsize=labelsize)
ax1.set_ylabel('Valor', fontsize=12)
ax1.tick_params(axis='both', which='major', labelsize=labelsize)
ax1.grid(True, linestyle='--', alpha=0.6)
# ax1.legend(loc='upper right')
ax1.legend(loc='upper left', bbox_to_anchor=(-0.5, 1), fontsize=labelsize)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# --- Subgráfica 2: Histograma normalizado ---
# Para obtener el porcentaje en el eje Y, usamos el argumento 'weights'.
total_actions = len(action_list_1)
weights = np.ones(total_actions) / total_actions * 100

# n, bins, patches = ax2.hist(action_list_2, bins=np.arange(-0.5, 11.5, 1), weights=weights, color="#86EE80", edgecolor='black', alpha=0.8)
n, bins, patches = ax2.hist(action_list_1, bins=np.arange(-0.5, 11.5, 1), weights=weights, color='#87CEEB', edgecolor='black', alpha=0.8)
ax2.set_xlabel('Valor de la Acción', fontsize=labelsize)
ax2.set_ylabel('Porcentaje de Frecuencia', fontsize=labelsize)

# Aumentar el tamaño de la fuente para los valores de los ejes
ax2.tick_params(axis='both', which='major', labelsize=labelsize)
ax2.set_xlim(0, 11)
# Establecer los valores discretos en el eje horizontal
ax2.set_xticks(np.arange(0, 11))
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

# Mejorar el diseño del layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15.5, 5))

# # Histogram
# plt.hist(action_list, bins=30, color='skyblue', edgecolor='black')
# plt.title('Distribución de acciones')
# plt.xlabel('Valor de la action')
# plt.ylabel('Frecuencia')
# plt.grid(True, alpha=0.3)

# plt.tight_layout()
# plt.show()

# %%
# # Scatter plot of the variables action_list = df[agent]["actions"] vs cooling_energy = []
# action_list = df[agent]["actions"]
# cooling_energy = []
# for timestep in range(len(df[agent]["infos"])-1):
#     cooling_energy.append(df[agent]["infos"][timestep][f"{agent}: Cooling:DistrictCooling"])

# plt.figure(figsize=(7.5, 5))
# plt.scatter(action_list, cooling_energy, s=1)
# plt.xlabel("Action")
# plt.ylabel("Cooling energy")
# plt.title("Scatter plot of Action vs Cooling energy")
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
# # Analyze transitions between actions
# transitions = np.diff(action_list)
# plt.figure(figsize=(10, 4))
# plt.plot(transitions, label='Action Changes')
# plt.title('Action Transitions Over Time')
# plt.xlabel('Time Step')
# plt.ylabel('Change in Action')
# plt.grid(True, alpha=0.3)
# plt.show()

# # Calculate transition statistics
# print("\nTransition Analysis:")
# print(f"Mean absolute change: {np.mean(np.abs(transitions)):.2f}")
# print(f"Max increase: {np.max(transitions):.2f}")
# print(f"Max decrease: {np.min(transitions):.2f}")

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15, 5))

# # 1. Time series plot
# plt.scatter(action_list, occ_list, color='blue', alpha=0.6)
# plt.title('Action-occupancy distribution')
# plt.xlabel('Action Value')
# plt.ylabel('Occupancy')
# plt.grid(True, alpha=0.3)

# %%
from typing import List, Any, Optional

agent:str = "HVAC"

feature_names_list: List[str] = feature_names[agent]

data_obs_list: List[Any] = []
for timestep in range(1,len(df["experiment"]["episode_1"])):
    data_obs_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"])
        
data_obs = np.array(data_obs_list)

# %%
feature_names_list
# Out:
# ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#  'HVAC: Zone Mean Air Temperature: Thermal Zone',
#  'HVAC: Zone People Occupant Count: Thermal Zone',
#  'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#  'HVAC: Electricity:Building',
#  'HVAC: Heating:DistrictHeatingWater',
#  'HVAC: Cooling:DistrictCooling',
#  'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#  'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#  'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']

# %%
print(data_obs.shape)
# Out:
# (289, 10)

# %%
from numpy.typing import NDArray
from numpy import float32
import torch
# Model prediction function (adapted for RLlib)
POLICY: Optional[Policy] = None
def model_predict(
    data: NDArray[float32],
):
    # Transform the lists in tensors.
    obs_tensor = torch.tensor(data, dtype=torch.float32)
    
    # Compute the actions.
    with torch.no_grad():
        predictions = POLICY.compute_actions(
            obs_batch=obs_tensor.numpy(), 
            exploration=False, 
        )[0]
    return predictions

# %%
# Use KernelExplainer
data_obs_sample = shap.sample(data_obs, 1000)

POLICY = single_policy
explainer = shap.KernelExplainer(
    model_predict,
    data=data_obs_sample,
    feature_names=feature_names_list
    )
# Out:
# Using 289 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.

# %%
background_data_np_sample = shap.sample(data_obs, 100)

# %%
shap_values_1 = explainer(background_data_np_sample)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
shap_values_1
# Out:
# .values =
# array([[ 3.43425606e-01,  2.93483276e-01,  0.00000000e+00,
#          3.18627451e-01,  0.00000000e+00, -1.56510957e+00,
#          0.00000000e+00,  2.64475202e-01,  3.18050750e-01,
#          3.35005767e-01],
#        [-8.18833416e-02, -1.24847586e-01,  0.00000000e+00,
#         -1.03278959e-01,  0.00000000e+00, -1.95760422e+00,
#          0.00000000e+00, -1.44801450e-01, -1.46531554e-01,
#         -1.33094414e-01],
#        [-1.29535344e-01, -2.61328061e-02,  0.00000000e+00,
#         -4.11270391e-02,  0.00000000e+00,  3.58938046e+00,
#          0.00000000e+00, -3.70324600e-02, -1.53484923e-02,
#         -3.22458395e-02],
#        [ 2.47322458e-02,  2.98072170e-02,  0.00000000e+00,
#          1.91959137e-02,  0.00000000e+00, -1.84591366e+00,
#          0.00000000e+00,  6.83802933e-04,  5.55280936e-02,
#          2.39248641e-02],
#        [ 3.83012028e-02,  4.78167738e-02,  0.00000000e+00,
#          2.18075465e-02,  0.00000000e+00, -1.83793870e+00,
#          0.00000000e+00, -4.08634042e-03, -9.04597133e-03,
#          5.11039710e-02],
#        [ 5.37320811e-02,  2.85879058e-02,  0.00000000e+00,
#          1.26132806e-02,  0.00000000e+00, -1.83029329e+00,
#          0.00000000e+00, -1.38573076e-02,  7.82666008e-03,
#          4.93491514e-02],
#        [ 5.89965398e-02,  9.12341407e-02,  0.00000000e+00,
#          8.65051903e-02,  0.00000000e+00,  3.72450980e+00,
#          0.00000000e+00,  1.26585928e-01,  1.09919262e-01,
#          1.10207612e-01],
#        [-4.35821387e-03,  4.59301368e-02,  0.00000000e+00,
#          4.33926512e-02,  0.00000000e+00, -1.80603065e+00,
#          0.00000000e+00,  5.67638820e-03,  6.36842972e-03,
#          1.69797331e-02],
#        [ 3.01969023e-01,  3.23710661e-01,  0.00000000e+00,
#          3.30112045e-01,  0.00000000e+00, -1.56925358e+00,
#          0.00000000e+00,  2.79420003e-01,  3.24921733e-01,
#          3.17078596e-01],
#        [-1.04910199e-01, -1.15233152e-01,  0.00000000e+00,
#         -1.16501895e-01,  0.00000000e+00, -1.98616741e+00,
#          0.00000000e+00, -1.19385401e-01, -1.56121272e-01,
#         -9.37221948e-02],
#        [ 4.16707860e-02,  1.63536003e-02,  0.00000000e+00,
#          4.15554457e-02,  0.00000000e+00, -1.83722195e+00,
#          0.00000000e+00,  4.21898171e-02, -6.25308947e-03,
#          9.66386555e-03],
#        [ 3.61921239e-02,  1.86604053e-02,  0.00000000e+00,
#          4.86488713e-02,  0.00000000e+00, -1.83560718e+00,
#          0.00000000e+00,  1.02982369e-02,  6.37666831e-03,
#          2.33893557e-02],
#        [-9.73224584e-02, -1.13354754e-01,  0.00000000e+00,
#         -1.46284396e-01,  0.00000000e+00, -1.96941012e+00,
#          0.00000000e+00, -1.12201351e-01, -1.35961443e-01,
#         -1.17507003e-01],
#        [-1.01202834e-01, -4.82616576e-02,  0.00000000e+00,
#         -2.91151755e-02,  0.00000000e+00,  3.58259186e+00,
#          0.00000000e+00, -3.74196738e-02, -3.00378975e-02,
#         -2.85961443e-02],
#        [-9.87147800e-02, -1.32740155e-01,  0.00000000e+00,
#         -1.06038886e-01,  0.00000000e+00, -1.99571593e+00,
#          0.00000000e+00, -1.12959301e-01, -1.17226891e-01,
#         -1.28645576e-01],
#        [ 2.20876586e-02,  5.45559400e-02,  0.00000000e+00,
#          1.67820069e-02,  0.00000000e+00, -1.85859285e+00,
#          0.00000000e+00,  7.26643599e-03,  3.74279123e-02,
#          2.84313725e-02],
#        [-1.40715110e-01, -1.15570934e-01,  0.00000000e+00,
#         -1.00922722e-01,  0.00000000e+00, -1.94867359e+00,
#          0.00000000e+00, -1.23356401e-01, -1.15282584e-01,
#         -1.47520185e-01],
#        [-1.04078102e-01, -1.33720547e-01,  0.00000000e+00,
#         -1.13305322e-01,  0.00000000e+00, -1.96809194e+00,
#          0.00000000e+00, -1.12267260e-01, -1.44504861e-01,
#         -1.16073488e-01],
#        [-1.14911847e-01, -1.16007580e-01,  0.00000000e+00,
#         -1.08741144e-01,  0.00000000e+00, -1.96295106e+00,
#          0.00000000e+00, -1.56838029e-01, -1.07530071e-01,
#         -1.25061789e-01],
#        [-4.15966387e-02, -8.69253584e-02,  0.00000000e+00,
#         -3.56566156e-02,  0.00000000e+00,  3.59156368e+00,
#          0.00000000e+00, -2.59680343e-02, -4.54028670e-02,
#         -4.80556929e-02],
#        [-3.21552150e-02, -7.37930466e-02,  0.00000000e+00,
#         -5.47042346e-02,  0.00000000e+00,  3.60492668e+00,
#          0.00000000e+00, -3.14055034e-02, -3.78645576e-02,
#         -6.70456418e-02],
#        [ 3.86389850e-03,  1.58592849e-02,  0.00000000e+00,
#          5.05767013e-02,  0.00000000e+00, -1.83171857e+00,
#          0.00000000e+00,  4.06574394e-02, -1.81084198e-02,
#          4.68281430e-02],
#        [ 1.92371066e-02,  9.69764376e-02,  0.00000000e+00,
#          1.10701928e-01,  0.00000000e+00,  3.74495798e+00,
#          0.00000000e+00,  1.23043335e-01,  1.26907233e-01,
#          8.61344538e-02],
#        [ 5.26281101e-02,  2.50041193e-02,  0.00000000e+00,
#          2.12555610e-02,  0.00000000e+00, -1.82545724e+00,
#          0.00000000e+00, -1.98550008e-03,  2.37353765e-02,
#          1.27780524e-02],
#        [-7.67259845e-02, -4.52957654e-02,  0.00000000e+00,
#         -5.97709672e-02,  0.00000000e+00,  3.57483111e+00,
#          0.00000000e+00, -2.54572417e-02, -2.71296754e-02,
#         -3.24929972e-02],
#        [ 3.50329544e-01,  3.86431043e-01,  0.00000000e+00,
#          3.57942000e-01,  0.00000000e+00,  4.00136761e+00,
#          0.00000000e+00,  4.01828967e-01,  4.04308782e-01,
#          4.05750536e-01],
#        [-1.38284726e-01, -1.27269731e-01,  0.00000000e+00,
#         -1.05701104e-01,  0.00000000e+00, -1.93816939e+00,
#          0.00000000e+00, -1.42494645e-01, -1.10372384e-01,
#         -1.29749547e-01],
#        [-1.24155545e-01, -8.34404350e-02,  0.00000000e+00,
#         -8.52858791e-02,  0.00000000e+00, -1.97899984e+00,
#          0.00000000e+00, -1.27269731e-01, -1.69945625e-01,
#         -1.22944472e-01],
#        [-5.62860438e-02, -8.32756632e-02,  0.00000000e+00,
#         -4.56170704e-02,  0.00000000e+00,  3.59653979e+00,
#          0.00000000e+00, -2.98154556e-02, -3.13725490e-02,
#         -4.22145329e-02],
#        [ 3.52644587e-01,  3.24270885e-01,  0.00000000e+00,
#          3.26404680e-01,  0.00000000e+00, -1.54873950e+00,
#          0.00000000e+00,  2.77788763e-01,  2.96589224e-01,
#          2.78999835e-01],
#        [-1.13824353e-01, -1.19937387e-01,  0.00000000e+00,
#         -1.04424123e-01,  0.00000000e+00, -1.96509310e+00,
#          0.00000000e+00, -1.55750536e-01, -1.28703246e-01,
#         -1.04308782e-01],
#        [ 3.59202505e-02,  2.02916461e-02,  0.00000000e+00,
#          4.14565826e-02,  0.00000000e+00, -1.83772450e+00,
#          0.00000000e+00,  1.55050255e-02,  1.24485088e-02,
#          2.00609656e-02],
#        [ 2.63058164e-02,  3.79551821e-02,  0.00000000e+00,
#          3.18998188e-02,  0.00000000e+00, -1.87334816e+00,
#          0.00000000e+00,  4.27994727e-02,  3.22458395e-02,
#          1.01005108e-02],
#        [-1.00494315e-01, -1.05511616e-01,  0.00000000e+00,
#         -1.10471247e-01,  0.00000000e+00, -1.98849893e+00,
#          0.00000000e+00, -1.33423958e-01, -1.31578514e-01,
#         -1.22062943e-01],
#        [-1.14063272e-01, -4.37633877e-02,  0.00000000e+00,
#         -3.57472401e-02,  0.00000000e+00,  3.56794365e+00,
#          0.00000000e+00, -1.56780359e-02, -1.06030648e-02,
#         -4.01301697e-02],
#        [-1.30523974e-01, -1.03534355e-01,  0.00000000e+00,
#         -1.05379799e-01,  0.00000000e+00, -1.97250783e+00,
#          0.00000000e+00, -1.56129511e-01, -1.12934586e-01,
#         -1.11031471e-01],
#        [-1.14590542e-01, -3.57554787e-02,  0.00000000e+00,
#         -1.07266436e-02,  0.00000000e+00,  3.55622837e+00,
#          0.00000000e+00, -2.83737024e-02, -5.36332180e-03,
#         -5.34602076e-02],
#        [-1.11122096e-01, -2.72697314e-02,  0.00000000e+00,
#         -3.72466634e-02,  0.00000000e+00,  3.59164607e+00,
#          0.00000000e+00, -1.81001812e-02, -3.17680013e-02,
#         -5.81809194e-02],
#        [-1.20893063e-01, -1.25795024e-01,  0.00000000e+00,
#         -1.03822706e-01,  0.00000000e+00, -1.98721371e+00,
#          0.00000000e+00, -1.30466304e-01, -1.28851541e-01,
#         -9.49991761e-02],
#        [ 3.95699456e-02,  3.39182732e-02,  0.00000000e+00,
#          1.75399572e-02,  0.00000000e+00, -1.83690064e+00,
#          0.00000000e+00,  4.39116823e-03,  2.79782501e-02,
#          2.14615258e-02],
#        [-6.18223760e-02, -5.64590542e-02,  0.00000000e+00,
#         -5.18454441e-02,  0.00000000e+00,  3.58852364e+00,
#          0.00000000e+00, -2.43944637e-02, -3.95040369e-02,
#         -4.65397924e-02],
#        [-1.89240402e-02, -7.31339595e-02,  0.00000000e+00,
#         -5.77360356e-02,  0.00000000e+00,  3.58188334e+00,
#          0.00000000e+00, -1.66749053e-02, -4.94892074e-02,
#         -5.79667161e-02],
#        [-1.24938211e-01, -1.40624485e-01,  0.00000000e+00,
#         -1.33992420e-01,  0.00000000e+00, -1.94881364e+00,
#          0.00000000e+00, -1.16979733e-01, -1.18652167e-01,
#         -1.08040863e-01],
#        [-1.23916625e-01, -9.65233152e-02,  0.00000000e+00,
#         -1.06500247e-01,  0.00000000e+00, -1.98083704e+00,
#          0.00000000e+00, -1.46869336e-01, -1.20687098e-01,
#         -1.16707860e-01],
#        [ 4.33102653e-02,  2.33564014e-02,  0.00000000e+00,
#          4.74625144e-02,  0.00000000e+00, -1.85963091e+00,
#          0.00000000e+00, -1.24567474e-02,  5.47866205e-03,
#          6.04382930e-02],
#        [ 3.74534520e-01,  3.87798649e-01,  0.00000000e+00,
#          3.86472236e-01,  0.00000000e+00,  3.99714121e+00,
#          0.00000000e+00,  3.99967046e-01,  3.95641786e-01,
#          3.66403032e-01],
#        [-1.21436810e-02, -6.72763223e-02,  0.00000000e+00,
#         -8.20975449e-02,  0.00000000e+00,  3.57995551e+00,
#          0.00000000e+00, -4.12753337e-03, -4.40352612e-02,
#         -6.23166914e-02],
#        [-1.28942165e-01, -1.14870654e-01,  0.00000000e+00,
#         -1.31537321e-01,  0.00000000e+00, -2.00201022e+00,
#          0.00000000e+00, -1.09680343e-01, -1.32575383e-01,
#         -7.24254408e-02],
#        [-7.29691877e-02, -5.29576536e-02,  0.00000000e+00,
#         -7.09507332e-02,  0.00000000e+00,  3.56665019e+00,
#          0.00000000e+00, -2.64293953e-02,  3.04003955e-03,
#         -3.84247817e-02],
#        [-9.66221783e-02, -1.35030483e-01,  0.00000000e+00,
#         -1.06368430e-01,  0.00000000e+00, -1.94293129e+00,
#          0.00000000e+00, -1.43681002e-01, -1.56829791e-01,
#         -1.10578349e-01],
#        [ 3.89767672e-02,  2.35211732e-02,  0.00000000e+00,
#          1.88498929e-02,  0.00000000e+00, -1.84787444e+00,
#          0.00000000e+00,  4.66304169e-03,  5.07414731e-02,
#          1.90805734e-02],
#        [-1.03015324e-01, -1.06014170e-01,  0.00000000e+00,
#         -1.31677377e-01,  0.00000000e+00, -1.99984347e+00,
#          0.00000000e+00, -1.25795024e-01, -1.19912671e-01,
#         -1.05783490e-01],
#        [ 1.22013511e-02,  4.68034273e-02,  0.00000000e+00,
#          4.97446037e-02,  0.00000000e+00, -1.84316197e+00,
#          0.00000000e+00, -5.96473884e-03,  1.47388367e-02,
#          3.35969682e-02],
#        [-1.48665348e-01, -9.58971824e-02,  0.00000000e+00,
#         -1.33094414e-01,  0.00000000e+00, -1.95973801e+00,
#          0.00000000e+00, -1.08988301e-01, -1.25885648e-01,
#         -1.19772615e-01],
#        [-7.16922063e-02, -7.29032790e-02,  0.00000000e+00,
#         -3.57060471e-02,  0.00000000e+00,  3.59318669e+00,
#          0.00000000e+00, -4.96786950e-03, -4.62020102e-02,
#         -5.37567968e-02],
#        [-2.73274015e-02, -7.03493162e-02,  0.00000000e+00,
#         -6.57357060e-02,  0.00000000e+00,  3.59083869e+00,
#          0.00000000e+00, -1.27945296e-02, -3.69006426e-02,
#         -6.97726149e-02],
#        [-1.12802768e-01, -1.16897347e-01,  0.00000000e+00,
#         -9.72895040e-02,  0.00000000e+00, -1.97797001e+00,
#          0.00000000e+00, -1.42041522e-01, -1.30046136e-01,
#         -1.14994233e-01],
#        [ 1.74987642e-02,  3.53188334e-02,  0.00000000e+00,
#          1.08666996e-02,  0.00000000e+00, -1.80695337e+00,
#          0.00000000e+00,  2.73026858e-02,  3.32427088e-02,
#         -9.31784478e-03],
#        [-1.34783325e-01, -1.00065909e-01,  0.00000000e+00,
#         -9.70670621e-02,  0.00000000e+00, -1.96725161e+00,
#          0.00000000e+00, -1.49200857e-01, -1.20077443e-01,
#         -1.23595320e-01],
#        [-1.31397265e-01, -9.76602406e-02,  0.00000000e+00,
#         -1.15884001e-01,  0.00000000e+00, -2.01738342e+00,
#          0.00000000e+00, -1.11328061e-01, -1.12827484e-01,
#         -1.05561048e-01],
#        [-1.14862416e-01, -1.27780524e-01,  0.00000000e+00,
#         -1.09556764e-01,  0.00000000e+00, -1.96734223e+00,
#          0.00000000e+00, -1.42544076e-01, -1.07884330e-01,
#         -1.22071181e-01],
#        [ 2.43038392e-02,  3.22623167e-02,  0.00000000e+00,
#          3.10512440e-02,  0.00000000e+00, -1.80262811e+00,
#          0.00000000e+00,  2.55396276e-04,  1.12127204e-02,
#          1.15010710e-02],
#        [ 5.25622014e-03,  1.86356896e-02,  0.00000000e+00,
#          5.88894381e-02,  0.00000000e+00, -1.81925358e+00,
#          0.00000000e+00,  2.14615258e-02, -6.26132806e-04,
#          2.35953205e-02],
#        [-1.28571429e-01, -9.45460537e-02,  0.00000000e+00,
#         -1.45814797e-01,  0.00000000e+00, -1.95083210e+00,
#          0.00000000e+00, -1.34684462e-01, -1.26668314e-01,
#         -1.10924370e-01],
#        [ 3.19171198e-01,  2.96506838e-01,  0.00000000e+00,
#          3.58559895e-01,  0.00000000e+00, -1.54830285e+00,
#          0.00000000e+00,  3.10232328e-01,  2.89990114e-01,
#          2.81800956e-01],
#        [-1.88910858e-02, -8.26742462e-02,  0.00000000e+00,
#         -8.14631735e-02,  0.00000000e+00,  3.57661064e+00,
#          0.00000000e+00, -4.53122425e-03, -2.25819740e-02,
#         -5.85104630e-02],
#        [ 3.05239743e-02,  5.79172846e-02,  0.00000000e+00,
#          1.61064426e-02,  0.00000000e+00, -1.81353600e+00,
#          0.00000000e+00,  3.18833416e-03, -9.32608337e-03,
#          2.30845279e-02],
#        [ 3.47091778e-02,  3.33250947e-02,  0.00000000e+00,
#          3.19410117e-02,  0.00000000e+00, -1.83928159e+00,
#          0.00000000e+00,  4.49003131e-03,  2.62316691e-02,
#          1.65430878e-02],
#        [ 3.01433515e-01,  3.20349316e-01,  0.00000000e+00,
#          3.04374691e-01,  0.00000000e+00, -1.52555610e+00,
#          0.00000000e+00,  2.93013676e-01,  2.93994068e-01,
#          3.20349316e-01],
#        [-4.22886802e-02, -3.30037898e-02,  0.00000000e+00,
#         -7.76404680e-02,  0.00000000e+00,  3.60748064e+00,
#          0.00000000e+00, -1.25885648e-02, -5.08238590e-02,
#         -8.31768001e-02],
#        [ 3.39281595e-01,  3.25902126e-01,  0.00000000e+00,
#          3.03007085e-01,  0.00000000e+00, -1.56948426e+00,
#          0.00000000e+00,  3.01565332e-01,  3.03872137e-01,
#          3.03814467e-01],
#        [-7.00362498e-02, -5.71758115e-02,  0.00000000e+00,
#         -4.53534355e-02,  0.00000000e+00,  3.57765695e+00,
#          0.00000000e+00, -1.30581644e-02, -2.27467458e-02,
#         -6.13280606e-02],
#        [-1.10652496e-01, -1.04366452e-01,  0.00000000e+00,
#         -1.33201516e-01,  0.00000000e+00, -1.97264788e+00,
#          0.00000000e+00, -1.28645576e-01, -1.11690559e-01,
#         -1.30837041e-01],
#        [ 3.34832757e-01,  2.91983852e-01,  0.00000000e+00,
#          3.02364475e-01,  0.00000000e+00, -1.55588235e+00,
#          0.00000000e+00,  3.12918108e-01,  3.08881200e-01,
#          3.12860438e-01],
#        [ 1.73323447e-01,  1.61616411e-01,  0.00000000e+00,
#          1.64096227e-01,  0.00000000e+00, -1.67056352e+00,
#          0.00000000e+00,  1.53254243e-01,  1.56714450e-01,
#          1.69517219e-01],
#        [ 2.88902620e-01,  2.99975284e-01,  0.00000000e+00,
#          3.07933762e-01,  0.00000000e+00, -1.54016312e+00,
#          0.00000000e+00,  3.12951063e-01,  3.16641951e-01,
#          3.21716922e-01],
#        [-5.60388861e-02, -6.09408469e-02,  0.00000000e+00,
#         -5.64425770e-02,  0.00000000e+00,  3.59701763e+00,
#          0.00000000e+00, -3.49316197e-02, -1.86686439e-02,
#         -6.20365793e-02],
#        [ 4.82534190e-02,  1.84379634e-02,  0.00000000e+00,
#          2.72038227e-02,  0.00000000e+00, -1.82383424e+00,
#          0.00000000e+00, -1.91959137e-03,  3.84742132e-03,
#          3.59696820e-02],
#        [-1.16155874e-01, -3.23611798e-02,  0.00000000e+00,
#         -4.26264623e-02,  0.00000000e+00,  3.57957654e+00,
#          0.00000000e+00, -2.01927830e-02, -3.02273851e-02,
#         -3.00543747e-02],
#        [ 1.75481957e-02,  1.61641127e-02,  0.00000000e+00,
#          4.81710331e-02,  0.00000000e+00, -1.82605042e+00,
#          0.00000000e+00, -8.34569122e-03,  2.68907563e-02,
#          3.35804910e-02],
#        [-1.16518372e-01, -1.14211567e-01,  0.00000000e+00,
#         -1.08848245e-01,  0.00000000e+00, -1.95988631e+00,
#          0.00000000e+00, -1.45295765e-01, -1.33531059e-01,
#         -1.13750206e-01],
#        [ 6.70621190e-03,  4.97281265e-02,  0.00000000e+00,
#          1.82979074e-02,  0.00000000e+00, -1.83002966e+00,
#          0.00000000e+00,  4.68775746e-03,  1.35112869e-02,
#          4.50568463e-02],
#        [ 3.02768166e-02,  1.18800461e-02,  0.00000000e+00,
#          2.44521338e-02,  0.00000000e+00, -1.83869666e+00,
#          0.00000000e+00,  1.96655133e-02,  3.38523645e-02,
#          2.65282584e-02],
#        [-1.26857802e-01, -1.25704399e-01,  0.00000000e+00,
#         -1.40986983e-01,  0.00000000e+00, -1.98954523e+00,
#          0.00000000e+00, -9.82534190e-02, -1.05000824e-01,
#         -1.05692865e-01],
#        [-1.34289010e-01, -9.85335311e-02,  0.00000000e+00,
#         -1.23331686e-01,  0.00000000e+00, -1.93065579e+00,
#          0.00000000e+00, -1.48821882e-01, -1.44150601e-01,
#         -1.12259021e-01],
#        [-5.06590872e-02, -5.83292140e-02,  0.00000000e+00,
#         -4.63914978e-02,  0.00000000e+00,  3.56981381e+00,
#          0.00000000e+00, -4.81133630e-03, -4.75449003e-02,
#         -5.41192948e-02],
#        [-1.07208766e-01, -9.99423299e-02,  0.00000000e+00,
#         -9.39446367e-02,  0.00000000e+00, -2.00322953e+00,
#          0.00000000e+00, -1.24279123e-01, -1.53806228e-01,
#         -1.09630911e-01],
#        [-4.65727467e-02, -7.37930466e-02,  0.00000000e+00,
#         -6.34700939e-02,  0.00000000e+00,  3.60365793e+00,
#          0.00000000e+00, -1.50848575e-02, -3.52117318e-02,
#         -6.15669797e-02],
#        [-1.25935080e-01, -1.30721700e-01,  0.00000000e+00,
#         -1.13247652e-01,  0.00000000e+00, -1.97276322e+00,
#          0.00000000e+00, -1.11978909e-01, -1.19360685e-01,
#         -1.18034273e-01],
#        [ 3.15966387e-01,  3.31479651e-01,  0.00000000e+00,
#          3.19195914e-01,  0.00000000e+00, -1.53933927e+00,
#          0.00000000e+00,  3.02356237e-01,  2.67350470e-01,
#          3.10949086e-01],
#        [ 2.91423628e-01,  3.21296754e-01,  0.00000000e+00,
#          3.06244851e-01,  0.00000000e+00, -1.53320152e+00,
#          0.00000000e+00,  2.90731587e-01,  3.21700445e-01,
#          3.09762729e-01],
#        [-3.76421157e-02, -7.19558412e-02,  0.00000000e+00,
#         -5.93837535e-02,  0.00000000e+00,  3.57516065e+00,
#          0.00000000e+00, -2.77805240e-02, -2.22441918e-02,
#         -4.81957489e-02],
#        [ 6.25556105e-02,  3.25671445e-02,  0.00000000e+00,
#          1.41127039e-02,  0.00000000e+00, -1.88127369e+00,
#          0.00000000e+00,  3.14137420e-02,  1.39396935e-02,
#          3.46432691e-02],
#        [ 3.50222442e-02,  3.95781842e-02,  0.00000000e+00,
#          4.88054045e-02,  0.00000000e+00, -1.84404350e+00,
#          0.00000000e+00, -7.76898995e-03,  1.27039051e-02,
#          2.36612292e-02],
#        [-1.23999011e-01, -1.08831768e-01,  0.00000000e+00,
#         -1.22153567e-01,  0.00000000e+00, -1.97140386e+00,
#          0.00000000e+00, -1.43779865e-01, -1.17655297e-01,
#         -1.04218158e-01],
#        [-1.10957324e-01, -1.02479815e-01,  0.00000000e+00,
#         -1.19204152e-01,  0.00000000e+00, -2.01949250e+00,
#          0.00000000e+00, -1.23125721e-01, -1.21395617e-01,
#         -9.53863899e-02],
#        [-3.20316362e-02, -6.88828473e-02,  0.00000000e+00,
#         -7.53419015e-02,  0.00000000e+00,  3.57258197e+00,
#          0.00000000e+00, -1.57109903e-02, -2.07859614e-02,
#         -5.18701598e-02],
#        [ 4.12094249e-02,  3.42890097e-02,  0.00000000e+00,
#          2.74345032e-03,  0.00000000e+00, -1.84944801e+00,
#          0.00000000e+00,  1.70456418e-02,  2.83489867e-02,
#          3.37699786e-02],
#        [ 4.11682320e-02,  9.72235953e-02,  0.00000000e+00,
#          9.87230186e-02,  0.00000000e+00,  3.72081068e+00,
#          0.00000000e+00,  1.22310101e-01,  1.08872961e-01,
#          1.18849893e-01],
#        [-5.96226726e-02, -4.44554292e-02,  0.00000000e+00,
#         -5.72581974e-02,  0.00000000e+00,  3.56234965e+00,
#          0.00000000e+00, -2.42132147e-02, -2.87114846e-02,
#         -4.01301697e-02]])
#
# .base_values =
# array([3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152,
#        3.69204152, 3.69204152, 3.69204152, 3.69204152, 3.69204152])
#
# .data =
# array([[ 7.9499998e+00,  2.2500000e+01,  1.0000000e+00, -1.3063488e+00,
#          0.0000000e+00,  8.2794362e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.0333338e+00,  2.2500000e+01,  1.0000000e+00, -1.3474106e+00,
#          0.0000000e+00,  8.2043688e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.8066668e+01,  2.2009586e+01,  1.0000000e+00, -1.2432564e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.2950000e+01,  2.2500000e+01,  1.0000000e+00, -1.2314777e+00,
#          0.0000000e+00,  3.2472816e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.2300000e+01,  2.2500000e+01,  1.0000000e+00, -1.3553598e+00,
#          0.0000000e+00,  3.4788275e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 7.7500000e+00,  2.2500000e+01,  1.0000000e+00, -1.3193160e+00,
#          0.0000000e+00,  3.7454659e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.5950000e+01,  2.1299789e+01,  1.0000000e+00, -1.4406956e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.4833333e+01,  2.2500000e+01,  1.0000000e+00, -1.3089576e+00,
#          0.0000000e+00,  4.5730184e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.7500000e+00,  2.2500000e+01,  1.0000000e+00, -9.1639656e-01,
#          0.0000000e+00,  8.6559200e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.4666662e+00,  2.2500000e+01,  1.0000000e+00, -9.3077153e-01,
#          0.0000000e+00,  7.8571038e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.8999996e+00,  2.2500000e+01,  1.0000000e+00, -1.3383700e+00,
#          0.0000000e+00,  8.3142419e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.8999996e+00,  2.2500000e+01,  1.0000000e+00, -1.3868723e+00,
#          0.0000000e+00,  4.3535538e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.8999996e+00,  2.2500000e+01,  1.0000000e+00, -9.1336423e-01,
#          0.0000000e+00,  9.3594406e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.6299999e+01,  2.1224533e+01,  1.0000000e+00, -1.4367992e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.0350000e+01,  1.9844683e+01,  1.0000000e+00, -1.7687422e+00,
#          0.0000000e+00,  6.9732820e+04,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 9.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3925409e+00,
#          0.0000000e+00,  4.5493256e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.7066668e+01,  2.2500000e+01,  1.0000000e+00, -1.2462529e+00,
#          0.0000000e+00,  2.9385081e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.3999996e+00,  2.2500000e+01,  1.0000000e+00, -1.4039183e+00,
#          0.0000000e+00,  4.9581441e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.0666666e+00,  2.2500000e+01,  1.0000000e+00, -1.3451831e+00,
#          0.0000000e+00,  7.9648369e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.2900000e+01,  2.0080107e+01,  1.0000000e+00, -1.7570136e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.1000000e+01,  2.1073427e+01,  1.0000000e+00, -1.5583283e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.5266666e+01,  2.2500000e+01,  1.0000000e+00, -1.2951980e+00,
#          0.0000000e+00,  3.6318562e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.7866667e+01,  2.1914293e+01,  1.0000000e+00, -1.2788181e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.2500000e+01,  2.2500000e+01,  1.0000000e+00, -1.2405033e+00,
#          0.0000000e+00,  3.8960312e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.7066668e+01,  2.1643944e+01,  1.0000000e+00, -1.3570743e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.6200001e+01,  2.1384037e+01,  1.0000000e+00, -1.4210283e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.6466667e+01,  2.2500000e+01,  1.0000000e+00, -1.1982125e+00,
#          0.0000000e+00,  2.4163627e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.6883333e+01,  2.2500000e+01,  1.0000000e+00, -1.2612933e+00,
#          0.0000000e+00,  2.8109472e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.3900000e+01,  1.9855089e+01,  1.0000000e+00, -1.7743201e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 9.5500002e+00,  2.2500000e+01,  1.0000000e+00, -1.3196110e+00,
#          0.0000000e+00,  7.8707494e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.5233334e+01,  2.2500000e+01,  1.0000000e+00, -1.1933793e+00,
#          0.0000000e+00,  1.9148000e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.1666670e+00,  2.2500000e+01,  1.0000000e+00, -9.0076125e-01,
#          0.0000000e+00,  1.0037871e+06,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.7500000e+00,  1.8902485e+01,  1.0000000e+00, -1.5109793e+00,
#          0.0000000e+00,  2.9126125e+04,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 9.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3096637e+00,
#          0.0000000e+00,  7.9637550e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.8000000e+01,  2.2054972e+01,  1.0000000e+00, -1.2362453e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.4000000e+01,  2.2500000e+01,  1.0000000e+00, -1.3122170e+00,
#          0.0000000e+00,  4.5801072e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.8133333e+01,  2.2273815e+01,  1.0000000e+00, -1.2012879e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.7616667e+01,  2.1812960e+01,  1.0000000e+00, -1.3113441e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 9.2333336e+00,  2.2500000e+01,  1.0000000e+00, -8.9754415e-01,
#          0.0000000e+00,  7.6798769e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.0733334e+01,  2.2355658e+01,  1.0000000e+00, -1.3240988e+00,
#          0.0000000e+00,  8.1213788e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.3666667e+01,  2.0154055e+01,  1.0000000e+00, -1.6774626e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.0450000e+01,  1.9765842e+01,  1.0000000e+00, -1.8296645e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.3200000e+01,  2.2500000e+01,  1.0000000e+00, -1.3317845e+00,
#          0.0000000e+00,  2.9605675e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.2050000e+01,  2.2500000e+01,  1.0000000e+00, -1.2492890e+00,
#          0.0000000e+00,  4.6003988e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.1300000e+01,  2.2500000e+01,  1.0000000e+00, -1.3721721e+00,
#          0.0000000e+00,  2.1616444e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.4133333e+01,  2.0197199e+01,  1.0000000e+00, -1.6944761e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.0566667e+01,  2.1003061e+01,  1.0000000e+00, -1.5918901e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.3400000e+01,  2.2500000e+01,  1.0000000e+00, -1.2228595e+00,
#          0.0000000e+00,  2.6542950e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.4033334e+01,  2.0245115e+01,  1.0000000e+00, -1.6553352e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.1000000e+01,  2.2500000e+01,  1.0000000e+00, -1.3762612e+00,
#          0.0000000e+00,  3.2001931e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.9499998e+00,  2.2500000e+01,  1.0000000e+00, -1.2928467e+00,
#          0.0000000e+00,  8.1905031e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.0000000e+01,  2.2500000e+01,  1.0000000e+00, -1.3852885e+00,
#          0.0000000e+00,  4.2621947e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.0900000e+01,  2.2500000e+01,  1.0000000e+00, -1.3776487e+00,
#          0.0000000e+00,  3.0632153e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.6966667e+01,  2.2500000e+01,  1.0000000e+00, -1.2259418e+00,
#          0.0000000e+00,  2.7568653e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.4766666e+01,  2.0472578e+01,  1.0000000e+00, -1.6041418e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.1400000e+01,  2.0036509e+01,  1.0000000e+00, -1.7809134e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.0116667e+01,  2.2500000e+01,  1.0000000e+00, -1.3844887e+00,
#          0.0000000e+00,  4.0662894e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.5333338e+00,  2.2500000e+01,  1.0000000e+00, -9.2670786e-01,
#          0.0000000e+00,  8.4864812e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 7.7333331e+00,  2.2500000e+01,  1.0000000e+00, -1.3170264e+00,
#          0.0000000e+00,  2.9728316e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.2500000e+01,  2.2500000e+01,  1.0000000e+00, -1.3494936e+00,
#          0.0000000e+00,  3.5509988e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.5600000e+01,  2.2500000e+01,  1.0000000e+00, -1.1908478e+00,
#          0.0000000e+00,  1.7724128e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.8000002e+00,  2.2500000e+01,  1.0000000e+00, -1.3344414e+00,
#          0.0000000e+00,  8.4191462e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.7000000e+01,  2.2500000e+01,  1.0000000e+00, -1.2333423e+00,
#          0.0000000e+00,  2.8252575e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.7666664e+00,  2.2500000e+01,  1.0000000e+00, -1.3585078e+00,
#          0.0000000e+00,  8.7757019e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.3000002e+00,  2.2500000e+01,  1.0000000e+00, -9.3437868e-01,
#          0.0000000e+00,  5.0768744e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.3000000e+01,  1.9889418e+01,  1.0000000e+00, -1.7968026e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.3916667e+01,  2.2500000e+01,  1.0000000e+00, -1.3105718e+00,
#          0.0000000e+00,  4.3897825e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 7.8833332e+00,  2.2500000e+01,  1.0000000e+00, -1.3092225e+00,
#          0.0000000e+00,  8.4608494e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.4133333e+01,  2.2500000e+01,  1.0000000e+00, -1.2074137e+00,
#          0.0000000e+00,  2.3613044e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.1100000e+01,  2.1267605e+01,  1.0000000e+00, -1.5336390e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.0216666e+01,  1.8866011e+01,  1.0000000e+00, -2.0537446e+00,
#          0.0000000e+00,  2.7281879e+04,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.5000000e+01,  2.1001556e+01,  1.0000000e+00, -1.5069611e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.3500000e+01,  2.2500000e+01,  1.0000000e+00, -1.3197219e+00,
#          0.0000000e+00,  2.5593044e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.7333336e+00,  2.2500000e+01,  1.0000000e+00, -1.3595357e+00,
#          0.0000000e+00,  8.9026088e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.5816667e+01,  2.2500000e+01,  1.0000000e+00, -1.1916245e+00,
#          0.0000000e+00,  2.0124681e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.7033333e+01,  2.2500000e+01,  1.0000000e+00, -1.2393984e+00,
#          0.0000000e+00,  2.8826500e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.3100000e+01,  1.9748606e+01,  1.0000000e+00, -1.8249298e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 9.6499996e+00,  2.2500000e+01,  1.0000000e+00, -1.3257987e+00,
#          0.0000000e+00,  8.0325675e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.7850000e+01,  2.2016626e+01,  1.0000000e+00, -1.2469064e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 7.7666669e+00,  2.2500000e+01,  1.0000000e+00, -1.3208306e+00,
#          0.0000000e+00,  7.5856019e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.6666666e+01,  2.2500000e+01,  1.0000000e+00, -1.2694635e+00,
#          0.0000000e+00,  2.6677672e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.3666668e+00,  2.2500000e+01,  1.0000000e+00, -1.3202242e+00,
#          0.0000000e+00,  8.2679338e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 9.8500004e+00,  2.2500000e+01,  1.0000000e+00, -1.3363429e+00,
#          0.0000000e+00,  8.3665738e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.1200000e+01,  2.2500000e+01,  1.0000000e+00, -1.3729141e+00,
#          0.0000000e+00,  2.8007725e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 7.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3071365e+00,
#          0.0000000e+00,  5.4294512e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.3600000e+01,  1.9778240e+01,  1.0000000e+00, -1.8039948e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 8.6000004e+00,  2.2500000e+01,  1.0000000e+00, -9.2285353e-01,
#          0.0000000e+00,  8.2758681e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.0800000e+01,  1.9957764e+01,  1.0000000e+00, -1.7973120e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.5400000e+01,  2.2500000e+01,  1.0000000e+00, -1.2904031e+00,
#          0.0000000e+00,  3.1634697e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.5666667e+01,  2.2500000e+01,  1.0000000e+00, -1.2856631e+00,
#          0.0000000e+00,  2.3056422e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.5533334e+01,  2.2500000e+01,  1.0000000e+00, -1.2880247e+00,
#          0.0000000e+00,  2.7188234e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.3000000e+01,  2.0133152e+01,  1.0000000e+00, -1.6966237e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 9.1666670e+00,  2.2500000e+01,  1.0000000e+00, -1.3135743e+00,
#          0.0000000e+00,  2.8213841e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.5133333e+01,  2.2500000e+01,  1.0000000e+00, -1.2998743e+00,
#          0.0000000e+00,  3.9677281e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 8.6999998e+00,  2.2500000e+01,  1.0000000e+00, -1.3608601e+00,
#          0.0000000e+00,  9.0097869e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.0233334e+01,  2.2500000e+01,  1.0000000e+00, -1.3835917e+00,
#          0.0000000e+00,  3.8991516e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.1900000e+01,  2.0088835e+01,  1.0000000e+00, -1.7584049e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 8.0500002e+00,  2.2500000e+01,  1.0000000e+00, -9.3893021e-01,
#          0.0000000e+00,  3.6065997e+05,  0.0000000e+00,  2.2500000e+01,
#          2.3500000e+01,  1.0000000e+00],
#        [ 1.6833334e+01,  2.1596045e+01,  1.0000000e+00, -1.3536187e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00],
#        [ 1.4800000e+01,  2.0943169e+01,  1.0000000e+00, -1.5230863e+00,
#          0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  1.8833334e+01,
#          2.6500000e+01,  1.0000000e+00]], dtype=float32)

# %%
"""
Global bar plot
================

Passing a matrix of SHAP values to the bar plot function creates a global feature importance 
plot, where the global importance of each feature is taken to be the mean absolute value for 
that feature over all the given samples.

# By default the bar plot only shows a maximum of ten bars, but this can be controlled with the `max_display` parameter.
"""
shap.plots.bar(shap_values_1)

# %%
# for _ in range(50):
#     shap.plots.bar(shap_values_1[_], max_display=13)

# %%
"""
beeswarm summary plot
======================

The beeswarm plot is designed to display an information-dense summary of how the top features 
in a dataset impact the model’s output. Each instance the given explanation is represented by 
a single dot on each feature row. The x position of the dot is determined by the SHAP value 
(shap_values.value[instance,feature]) of that feature, and dots “pile up” along each feature row 
to show density. Color is used to display the original value of a feature 
(shap_values.data[instance,feature]).

By default the maximum number of features shown is ten, but this can be adjusted with the max_display parameter.
"""
shap.plots.beeswarm(shap_values_1, max_display=6)

# %%
"""
Feature ordering
=================

By default the features are ordered using shap_values.abs.mean(0), which is the mean absolute value 
of the SHAP values for each feature. This order however places more emphasis on broad average impact, 
and less on rare but high magnitude impacts. If we want to find features with high impacts for individual 
people we can instead sort by the max absolute value.
"""
shap.plots.beeswarm(shap_values_1, max_display=6, order=shap_values_1.abs.max(0))

# %%
"""
Sometimes it is helpful to transform the SHAP values before we plots them. Below we plot the absolute 
value and fix the color to be red. This creates a richer parallel to the standard shap_values.abs.mean(0) 
bar plot, since the bar plot just plots the mean value of the dots in the beeswarm plot.
"""
shap.plots.beeswarm(shap_values_1.abs, max_display=23, color="shap_red")

# %%
"""
A simple violin summary plot
=============================

The violin summary plot offers a compact representation of the distribution and variability of SHAP 
values for each feature. Individual violin plots are stacked by importance of the particular feature 
on model output (sum of the absolute values of the SHAP values per feature).

Violin plots use “violin-shaped” figures to display the distribution and density of SHAP values for their 
respective feature. The violins can therefore provide insights into the range, variability, skewness, 
symmetry, and multimodality of the SHAP value distribution for a specific feature.

The overall violin summary plot allow for comparisons in feature importance. Wider violins indicate higher 
density and more frequent values, thus providing insights into the relative importance of each feature with 
regard to the model output.
"""
shap.plots.violin(shap_values_1, max_display=23)

# %%
"""
Simple dependence scatter plot
===============================

A dependence scatter plot shows the effect a single feature has on the predictions made by the model.

* Each dot is a single prediction (row) from the dataset.
* The x-axis is the value of the feature (from the X matrix, stored in explanation.data).
* The y-axis is the SHAP value for that feature (stored in explanation.values), which represents how much knowing 
that feature’s value changes the output of the model for that sample’s prediction. For this model the units are 
log-odds of making over 50k annually.
* The light grey area at the bottom of the plot is a histogram showing the distribution of data values.
"""

features = feature_names.copy()

# for feature in features:
#     shap.plots.scatter(
#         shap_values_1[:, feature],
#         # color=shap_values_1[:, "Zone Thermal Comfort Fanger Model PMV"]
#         )

# %%
# # for feature in features:
# features_copy = features.copy()
# features_copy.remove("Estado del actuador")
# for feature2 in features_copy:
#     shap.plots.scatter(
#         shap_values_1[:, "Estado del actuador"],
#         color=shap_values_1[:, feature2]
#         )

# %%
shap.plots.scatter(
    shap_values_1[:, "HVAC: Heating:DistrictHeatingWater"],
    color=shap_values_1[:, "HVAC: Site Outdoor Air Drybulb Temperature: Environment"]
    )

# %%
"""
Heatmap
========

Passing a matrix of SHAP values to the heatmap plot function creates a plot with the instances on the x-axis, 
the model inputs on the y-axis, and the SHAP values encoded on a color scale. By default the samples are ordered 
using shap.order.hclust, which orders the samples based on a hierarchical clustering by their explanation 
similarity. This results in samples that have the same model output for the same reason getting grouped together 
(such as people with a high impact from capital gain in the plot below).

The output of the model is shown above the heatmap matrix (centered around the explaination’s .base_value), and 
the global importance of each model input shown as a bar plot on the right hand side of the plot (by default this 
is the shap.order.abs.mean measure of overall importance).
"""
shap.plots.heatmap(shap_values_1, max_display=23)
# Out:
# <Axes: xlabel='Instances'>

# %%
# for i in range(len(background_data_np_sample)):
#     shap.initjs()
#     shap.force_plot(explainer.expected_value, shap_values[i], background_data_np_sample[i], matplotlib=True, show=True)

# for i in range(14):
#     shap.dependence_plot(i, shap_values, background_data_np_sample)

# %%
# Parameter importance

# import eli5
# from eli5.sklearn import PermutationImportance

# val_X = df["observations"][0:100]
# val_y = df["actions"][0:100]

# perm = PermutationImportance(model_predict, random_state=1).fit(val_X, val_y)
# eli5.show_weights(perm, feature_names = val_X.columns.tolist())
