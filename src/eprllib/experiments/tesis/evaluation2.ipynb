# %%
import os
os.environ['RAY_DEDUP_LOGS'] = '0'

import numpy as np
import shap
import matplotlib.pyplot as plt
import json

from tempfile import TemporaryDirectory
from typing import List, Dict

import ray
from ray.tune import register_env
from ray.rllib.algorithms.algorithm import Algorithm
from ray.rllib.policy.policy import Policy

from ray.rllib.models import ModelCatalog
from eprllib.examples.example_central_agent_files.policy_model import CustomTransformerModel
ModelCatalog.register_custom_model("custom_transformer", CustomTransformerModel)

from eprllib.Environment.Environment import Environment
from eprllib.Environment.EnvironmentConfig import EnvironmentConfig
from eprllib.Agents.Filters.DefaultFilter import DefaultFilter
from eprllib.Agents.Triggers.SetpointTriggers import DualSetpointTriggerDiscreteAndAvailabilityTrigger
# from eprllib.Agents.Rewards.EnergyAndAshrae55SimpleModel import EnergyAndASHRAE55SimpleModel
from eprllib.Agents.Rewards.NygardFerguson1990 import NygardFerguson1990_ended
from eprllib.AgentsConnectors.DefaultConnector import DefaultConnector

from eprllib.Agents.AgentSpec import (
    AgentSpec,
    ObservationSpec,
    RewardSpec,
    ActionSpec,
    TriggerSpec,
    FilterSpec
)
from eprllib.examples.example_thermostat_files.curriculum_learning import episode_fn
from eprllib.examples.example_thermostat_files.policy_mapping import policy_map_fn

from eprllib.PostProcess.Evaluation import generate_experience
from eprllib.AgentsConnectors.BaseConnector import BaseConnector

with open("C:/Users/grhen/Documents/GitHub2/eprllib/src/eprllib/examples/example_thermostat_files/curriculum_evaluation.json", "r") as f:
    episode_config = json.load(f)
# Out:
# WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
checkpoint_path = "C:/Users/grhen/ray_results/tesis/20251029120943-task2/PPO-4ca92_00000/checkpoint_000049"

# %%
"""
Esta configuración debe coincidir con la de entrenamiento.
"""
experiment_name:str = "tesis"
name:str = "task2"

eprllib_config = EnvironmentConfig()
eprllib_config.generals(
    epjson_path = "src/eprllib/examples/example_central_agent_files/model.epJSON",
    epw_path = "src/eprllib/examples/example_central_agent_files/weathers/ESP_PV_San.Sebastian-Igueldo.080270_TMYx.2004-2018.epw",
    output_path = TemporaryDirectory("output","",'C:/Users/grhen/Documents/Resultados_RLforEP').name,
    ep_terminal_output = False,
    timeout = 10,
    evaluation = False,
)
eprllib_config.connector(
    connector_fn = DefaultConnector,
    connector_fn_config = {},
)
eprllib_config.agents(
    agents_config = {
        "HVAC": AgentSpec(
            observation = ObservationSpec(
                variables = [
                    ("Site Outdoor Air Drybulb Temperature", "Environment"),
                    # ("Site Outdoor Air Relative Humidity", "Environment"),
                    ("Zone Mean Air Temperature", "Thermal Zone"),
                    # ("Zone Air Relative Humidity", "Thermal Zone"),
                    ("Zone People Occupant Count", "Thermal Zone"),
                    ("Zone Thermal Comfort Fanger Model PMV", "People")
                ],
                # simulation_parameters = {
                #     'hour': True,
                #     'day_of_week': True,
                #     'minutes': True,
                #     'day_of_year': True,
                #     # 'today_weather_horizontal_ir_at_time': True,
                # },
                meters = [
                    "Electricity:Building",
                    "Heating:DistrictHeatingWater",
                    "Cooling:DistrictCooling",
                ],
                use_actuator_state = True,
                use_one_day_weather_prediction = False,
                weather_prediction_hours = 3,
                prediction_variables = {
                    'outdoor_dry_bulb': True,
                },
                # internal_variables = [
                #     ("Zone Floor Area", "Thermal Zone"),
                # ],
                # history_len=6,
                user_occupation_funtion = False,
                user_type = "Office schedule",
                zone_type = "daytime",
                occupation_schedule = ("Schedule:Constant", "Schedule Value", "occupancy_schedule"),
                user_occupation_forecast = False,
                occupation_prediction_hours = 3,
                summer_months = [11, 12, 1, 2],
                # other_obs = {
                #     "war_north": 0,  # Window-to-wall ratio north
                #     "war_south": 0,  # Window-to-wall ratio south
                #     "war_east": 0,   # Window-to-wall ratio east
                #     "war_west": 0,   # Window-to-wall ratio west
                #     "latitude": 0,  # Latitude
                #     "longitude": 0,  # Longitude
                #     # "elevation": 0,  # Elevation
                #     # "time_zone": 0,  # Time zone
                # }
            ),
            action = ActionSpec(
                actuators = [
                    ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                ],
            ),
            filter= FilterSpec(
                filter_fn = DefaultFilter,
                filter_fn_config = {},
            ),
            trigger= TriggerSpec(
                trigger_fn = DualSetpointTriggerDiscreteAndAvailabilityTrigger,
                trigger_fn_config = {
                    'temperature_range': (17, 28),
                    "band_gap_range_len": 3,
                    "action_space_dim": 10,
                    'actuator_for_cooling': ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    'actuator_for_heating': ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    'availability_actuator': ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                },
            ),
            reward = RewardSpec(
                reward_fn = NygardFerguson1990_ended,
                reward_fn_config = {
                    "thermal_zone": "Thermal Zone",
                    "C2": 6000,
                    'people_name': "People",
                    'cooling_name': "Cooling:DistrictCooling",
                    'heating_name': "Heating:DistrictHeatingWater",
                    'cooling_energy_ref': 0,
                    'heating_energy_ref': 0,
                },
            ),
        ),
    }
)

eprllib_config.episodes(
    episode_fn = episode_fn,
    episode_fn_config = episode_config,
    # cut_episode_len = 2
)

assert eprllib_config.agents_config is not None, "Agents configuration is not defined."

number_of_agents = len([keys for keys in eprllib_config.agents_config.keys()])
ray.init(_temp_dir='C:/Users/grhen/ray_results/tmp')
register_env(name="EPEnv", env_creator=lambda args: Environment(args))
env_config = eprllib_config.to_dict()

old_algo = Algorithm.from_checkpoint(checkpoint_path)
# Out:
# 2025-11-10 11:08:26,612	INFO worker.py:1918 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\algorithms\algorithm.py:520: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=6964) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=6964)
# (pid=20564) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=20564)
# (pid=9524) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=9524)
# (pid=23628) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=23628)
# (pid=5560) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=5560)
# (pid=17856) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=17856)
# (pid=21524) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=21524)
# 2025-11-10 11:08:58,196	INFO trainable.py:161 -- Trainable.setup took 29.020 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2025-11-10 11:08:58,196	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
# ray.shutdown()

# %%
single_policy = old_algo.get_policy("single_policy")

# Generate experience
df = generate_experience(
    env = Environment,
    env_config = env_config,
    policies = {
        "HVAC": single_policy,
    },
    num_episodes = 1
)

old_algo.stop()
ray.shutdown()

# %%
feature_names: Dict[str, List[str]] = {agent: [] for agent in env_config["agents_config"].keys()}
feature_names_index: Dict[str, Dict[str, int]] = {agent: {} for agent in env_config["agents_config"].keys()}
connector_fn: BaseConnector = env_config['connector_fn'](env_config["connector_fn_config"])

for agent in env_config["agents_config"].keys():
    connector_fn.get_agent_obs_dim(env_config,agent)
    feature_names_index[agent] = connector_fn.get_agent_obs_indexed(env_config,agent)
    for key in feature_names_index[agent].keys():
        feature_names[agent].append(key)

for agent in feature_names.keys():
    if env_config["agents_config"][agent]["observation"]["history_len"] > 1:
        feature_names_h = feature_names[agent].copy()
        for h in range(env_config["agents_config"][agent]["observation"]["history_len"]):
            feature_names_h_new: List[str] = []
            for value in feature_names_h:
                feature_names_h_new.append(f"h{h}_{value}")
            feature_names[agent].extend(feature_names_h_new)

# %%
feature_names
# Out:
# {'HVAC': ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#   'HVAC: Zone Mean Air Temperature: Thermal Zone',
#   'HVAC: Zone People Occupant Count: Thermal Zone',
#   'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#   'HVAC: Electricity:Building',
#   'HVAC: Heating:DistrictHeatingWater',
#   'HVAC: Cooling:DistrictCooling',
#   'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#   'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#   'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']}

# %%
df
# Out:
# {'experiment': {'episode_1': {'timestep_1': {'HVAC': {'observation': array([11.55, 24.  ,  1.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,
#              0.  ], dtype=float32),
#      'action': None,
#      'reward': 0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_2': {'HVAC': {'observation': array([ 1.1550000e+01,  2.6627615e+01,  1.0000000e+00, -2.1120442e-01,
#              0.0000000e+00,  1.0847919e+06,  0.0000000e+00,  2.6900000e+01,
#              2.7900000e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_3': {'HVAC': {'observation': array([ 1.1100000e+01,  2.5807726e+01,  1.0000000e+00, -3.0736747e-01,
#              0.0000000e+00,  6.1877138e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_4': {'HVAC': {'observation': array([ 1.0650000e+01,  2.5800011e+01,  1.0000000e+00, -3.2221210e-01,
#              0.0000000e+00,  9.5773594e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_5': {'HVAC': {'observation': array([ 1.0200000e+01,  2.5800001e+01,  1.0000000e+00, -3.2843471e-01,
#              0.0000000e+00,  1.2216621e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_6': {'HVAC': {'observation': array([ 9.7500000e+00,  2.5800001e+01,  1.0000000e+00, -3.3559263e-01,
#              0.0000000e+00,  1.4384910e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_7': {'HVAC': {'observation': array([ 9.3000002e+00,  2.5799999e+01,  1.0000000e+00, -3.4257725e-01,
#              0.0000000e+00,  1.5932764e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-7.609608672775028e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_8': {'HVAC': {'observation': array([ 9.2333336e+00,  2.5799999e+01,  1.0000000e+00, -3.4721160e-01,
#              0.0000000e+00,  1.5756066e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_9': {'HVAC': {'observation': array([ 9.1666670e+00,  2.5799999e+01,  1.0000000e+00, -3.5040995e-01,
#              0.0000000e+00,  1.5576208e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_10': {'HVAC': {'observation': array([ 9.1000004e+00,  2.5799999e+01,  1.0000000e+00, -3.5276979e-01,
#              0.0000000e+00,  1.5449109e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_11': {'HVAC': {'observation': array([ 9.0333338e+00,  2.5799999e+01,  1.0000000e+00, -3.5478866e-01,
#              0.0000000e+00,  1.5368682e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_12': {'HVAC': {'observation': array([ 8.9666662e+00,  2.5799999e+01,  1.0000000e+00, -3.5659605e-01,
#              0.0000000e+00,  1.5287062e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_13': {'HVAC': {'observation': array([ 8.8999996e+00,  2.5799999e+01,  1.0000000e+00, -3.5839823e-01,
#              0.0000000e+00,  1.5204861e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-9.929865974191428e-05),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_14': {'HVAC': {'observation': array([ 8.8500004e+00,  2.5799999e+01,  1.0000000e+00, -3.5837081e-01,
#              0.0000000e+00,  9.3460975e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_15': {'HVAC': {'observation': array([ 8.8000002e+00,  2.5799999e+01,  1.0000000e+00, -3.5792333e-01,
#              0.0000000e+00,  9.7299738e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_16': {'HVAC': {'observation': array([ 8.7500000e+00,  2.5799999e+01,  1.0000000e+00, -3.5896412e-01,
#              0.0000000e+00,  1.4297984e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_17': {'HVAC': {'observation': array([ 8.6999998e+00,  2.5799999e+01,  1.0000000e+00, -3.6033410e-01,
#              0.0000000e+00,  1.4433476e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_18': {'HVAC': {'observation': array([ 8.6499996e+00,  2.5799999e+01,  1.0000000e+00, -3.6148438e-01,
#              0.0000000e+00,  1.4820719e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_19': {'HVAC': {'observation': array([ 8.6000004e+00,  2.5799999e+01,  1.0000000e+00, -3.6216554e-01,
#              0.0000000e+00,  1.3773014e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00010305299384398221),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_20': {'HVAC': {'observation': array([ 8.5666666e+00,  2.5799999e+01,  1.0000000e+00, -3.6297572e-01,
#              0.0000000e+00,  1.4389435e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_21': {'HVAC': {'observation': array([ 8.5333338e+00,  2.5799999e+01,  1.0000000e+00, -3.6392254e-01,
#              0.0000000e+00,  1.4003448e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_22': {'HVAC': {'observation': array([ 8.5000000e+00,  2.5799999e+01,  1.0000000e+00, -3.6487070e-01,
#              0.0000000e+00,  1.3518168e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_23': {'HVAC': {'observation': array([ 8.4666662e+00,  2.5799999e+01,  1.0000000e+00, -3.6583942e-01,
#              0.0000000e+00,  1.3196315e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_24': {'HVAC': {'observation': array([ 8.4333334e+00,  2.5799999e+01,  1.0000000e+00, -3.6541122e-01,
#              0.0000000e+00,  8.1205400e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_25': {'HVAC': {'observation': array([ 8.400000e+00,  2.580000e+01,  1.000000e+00, -3.646289e-01,
#              0.000000e+00,  7.858447e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.0001059019639518615),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_26': {'HVAC': {'observation': array([ 8.3666668e+00,  2.5799999e+01,  1.0000000e+00, -3.6425644e-01,
#              0.0000000e+00,  8.4994788e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_27': {'HVAC': {'observation': array([ 8.3333330e+00,  2.5799999e+01,  1.0000000e+00, -3.6432382e-01,
#              0.0000000e+00,  9.1068081e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_28': {'HVAC': {'observation': array([ 8.3000002e+00,  2.5799999e+01,  1.0000000e+00, -3.6468977e-01,
#              0.0000000e+00,  9.6871719e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_29': {'HVAC': {'observation': array([ 8.2666664e+00,  2.5799999e+01,  1.0000000e+00, -3.6517844e-01,
#              0.0000000e+00,  1.0245362e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_30': {'HVAC': {'observation': array([ 8.2333336e+00,  2.5799999e+01,  1.0000000e+00, -3.6568356e-01,
#              0.0000000e+00,  1.0784801e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_31': {'HVAC': {'observation': array([ 8.1999998e+00,  2.5799999e+01,  1.0000000e+00, -3.6616784e-01,
#              0.0000000e+00,  1.1308214e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00010607613043994696),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_32': {'HVAC': {'observation': array([ 8.1499996e+00,  2.5799999e+01,  1.0000000e+00, -3.6621132e-01,
#              0.0000000e+00,  8.3977431e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_33': {'HVAC': {'observation': array([ 8.100000e+00,  2.580000e+01,  1.000000e+00, -3.636828e-01,
#              0.000000e+00,  3.950805e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_34': {'HVAC': {'observation': array([ 8.0500002e+00,  2.5799999e+01,  1.0000000e+00, -3.6378703e-01,
#              0.0000000e+00,  7.8210962e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_35': {'HVAC': {'observation': array([ 8.0000000e+00,  2.5799999e+01,  1.0000000e+00, -3.6767498e-01,
#              0.0000000e+00,  1.0966082e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_36': {'HVAC': {'observation': array([ 7.9499998e+00,  2.5799999e+01,  1.0000000e+00, -3.7338430e-01,
#              0.0000000e+00,  1.3465424e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_37': {'HVAC': {'observation': array([ 7.9000001e+00,  2.5799999e+01,  1.0000000e+00, -3.7866077e-01,
#              0.0000000e+00,  1.3673166e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00010849036850121704),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_38': {'HVAC': {'observation': array([ 7.8833332e+00,  2.5799999e+01,  1.0000000e+00, -6.6991985e-01,
#              0.0000000e+00,  1.3732221e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_39': {'HVAC': {'observation': array([ 7.8666668e+00,  2.5799999e+01,  1.0000000e+00, -6.7231768e-01,
#              0.0000000e+00,  1.3791388e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_40': {'HVAC': {'observation': array([ 7.8499999e+00,  2.5799999e+01,  1.0000000e+00, -6.7397320e-01,
#              0.0000000e+00,  1.3850598e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_41': {'HVAC': {'observation': array([ 7.8333335e+00,  2.5799999e+01,  1.0000000e+00, -6.7522860e-01,
#              0.0000000e+00,  1.3909889e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_42': {'HVAC': {'observation': array([ 7.8166666e+00,  2.5799999e+01,  1.0000000e+00, -6.7624581e-01,
#              0.0000000e+00,  1.3969216e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_43': {'HVAC': {'observation': array([ 7.8000002e+00,  2.5799999e+01,  1.0000000e+00, -6.7713469e-01,
#              0.0000000e+00,  1.4028729e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.0004267825110715392),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_44': {'HVAC': {'observation': array([ 7.7833333e+00,  2.5799999e+01,  1.0000000e+00, -6.7723674e-01,
#              0.0000000e+00,  1.3757775e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_45': {'HVAC': {'observation': array([ 7.7666669e+00,  2.5799999e+01,  1.0000000e+00, -6.7658484e-01,
#              0.0000000e+00,  1.2595396e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_46': {'HVAC': {'observation': array([ 7.750000e+00,  2.580000e+01,  1.000000e+00, -6.745211e-01,
#              0.000000e+00,  7.885849e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_47': {'HVAC': {'observation': array([ 7.7333331e+00,  2.5799999e+01,  1.0000000e+00, -6.7178565e-01,
#              0.0000000e+00,  6.9249338e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_48': {'HVAC': {'observation': array([ 7.7166667e+00,  2.5799999e+01,  1.0000000e+00, -6.7063743e-01,
#              0.0000000e+00,  1.1895919e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_49': {'HVAC': {'observation': array([ 7.6999998e+00,  2.5799999e+01,  1.0000000e+00, -6.7034465e-01,
#              0.0000000e+00,  1.3643930e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00042567242066940804),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_50': {'HVAC': {'observation': array([ 7.6999998e+00,  2.5799999e+01,  1.0000000e+00, -6.7019182e-01,
#              0.0000000e+00,  1.3482759e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_51': {'HVAC': {'observation': array([ 7.6999998e+00,  2.5799999e+01,  1.0000000e+00, -6.6959131e-01,
#              0.0000000e+00,  1.1343139e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_52': {'HVAC': {'observation': array([ 7.700000e+00,  2.580000e+01,  1.000000e+00, -6.682442e-01,
#              0.000000e+00,  8.666967e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_53': {'HVAC': {'observation': array([ 7.700000e+00,  2.580000e+01,  1.000000e+00, -6.653360e-01,
#              0.000000e+00,  4.986711e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_54': {'HVAC': {'observation': array([ 7.6999998e+00,  2.5799999e+01,  1.0000000e+00, -6.5852326e-01,
#              0.0000000e+00,  6.7930106e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_55': {'HVAC': {'observation': array([ 7.6999998e+00,  2.5799999e+01,  1.0000000e+00, -6.5578282e-01,
#              0.0000000e+00,  9.8793975e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.0004118129699645505),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_56': {'HVAC': {'observation': array([ 7.9499998e+00,  2.5799999e+01,  1.0000000e+00, -6.5383023e-01,
#              0.0000000e+00,  1.3389474e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_57': {'HVAC': {'observation': array([ 8.1999998e+00,  2.5799999e+01,  1.0000000e+00, -6.5170109e-01,
#              0.0000000e+00,  1.3507092e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_58': {'HVAC': {'observation': array([ 8.4499998e+00,  2.5799999e+01,  1.0000000e+00, -6.4835072e-01,
#              0.0000000e+00,  1.3758516e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_59': {'HVAC': {'observation': array([ 8.6999998e+00,  2.5799999e+01,  1.0000000e+00, -6.4216876e-01,
#              0.0000000e+00,  1.4075884e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_60': {'HVAC': {'observation': array([ 8.9499998e+00,  2.5799999e+01,  1.0000000e+00, -6.3711226e-01,
#              0.0000000e+00,  1.3381811e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_61': {'HVAC': {'observation': array([ 9.1999998e+00,  2.5799999e+01,  1.0000000e+00, -6.3154924e-01,
#              0.0000000e+00,  1.2730439e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00038161562502783024),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_62': {'HVAC': {'observation': array([ 9.5833330e+00,  2.5799999e+01,  1.0000000e+00, -6.2496424e-01,
#              0.0000000e+00,  1.1434930e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_63': {'HVAC': {'observation': array([ 9.9666662e+00,  2.5799999e+01,  1.0000000e+00, -6.1492276e-01,
#              0.0000000e+00,  2.3875488e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_64': {'HVAC': {'observation': array([ 1.0350000e+01,  2.5799999e+01,  1.0000000e+00, -6.0775453e-01,
#              0.0000000e+00,  1.0824758e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_65': {'HVAC': {'observation': array([ 1.0733334e+01,  2.5799999e+01,  1.0000000e+00, -6.0212559e-01,
#              0.0000000e+00,  1.1494990e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_66': {'HVAC': {'observation': array([ 1.1116667e+01,  2.5799999e+01,  1.0000000e+00, -5.9463817e-01,
#              0.0000000e+00,  1.1816148e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_67': {'HVAC': {'observation': array([ 1.1500000e+01,  2.5799999e+01,  1.0000000e+00, -5.8775300e-01,
#              0.0000000e+00,  1.1313765e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00032857321887347075),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_68': {'HVAC': {'observation': array([ 1.1800000e+01,  2.5799999e+01,  1.0000000e+00, -5.8109462e-01,
#              0.0000000e+00,  1.0646091e+06,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_69': {'HVAC': {'observation': array([ 1.210000e+01,  2.580000e+01,  1.000000e+00, -5.747789e-01,
#              0.000000e+00,  9.053060e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_70': {'HVAC': {'observation': array([ 1.2400000e+01,  2.5799999e+01,  1.0000000e+00, -5.6685686e-01,
#              0.0000000e+00,  2.6919091e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_71': {'HVAC': {'observation': array([ 1.2700000e+01,  2.5799999e+01,  1.0000000e+00, -5.5718338e-01,
#              0.0000000e+00,  8.8994194e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_72': {'HVAC': {'observation': array([ 1.3000000e+01,  2.5799999e+01,  1.0000000e+00, -5.5021554e-01,
#              0.0000000e+00,  9.8164994e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_73': {'HVAC': {'observation': array([ 1.3300000e+01,  2.5799999e+01,  1.0000000e+00, -5.4111606e-01,
#              0.0000000e+00,  9.9639006e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00027566379964243467),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_74': {'HVAC': {'observation': array([ 1.3666667e+01,  2.5799999e+01,  1.0000000e+00, -5.3396136e-01,
#              0.0000000e+00,  9.6845375e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_75': {'HVAC': {'observation': array([ 1.4033334e+01,  2.5799999e+01,  1.0000000e+00, -5.2707165e-01,
#              0.0000000e+00,  9.4050962e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_76': {'HVAC': {'observation': array([ 1.4400000e+01,  2.5799999e+01,  1.0000000e+00, -5.2054864e-01,
#              0.0000000e+00,  9.1239425e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_77': {'HVAC': {'observation': array([ 1.4766666e+01,  2.5799999e+01,  1.0000000e+00, -5.1749337e-01,
#              0.0000000e+00,  8.8643938e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_78': {'HVAC': {'observation': array([ 1.5133333e+01,  2.5799999e+01,  1.0000000e+00, -5.1455283e-01,
#              0.0000000e+00,  8.6079600e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_79': {'HVAC': {'observation': array([ 1.5500000e+01,  2.5799999e+01,  1.0000000e+00, -5.1031107e-01,
#              0.0000000e+00,  8.3510094e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00023115197777578533),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_80': {'HVAC': {'observation': array([ 1.5766666e+01,  2.5799999e+01,  1.0000000e+00, -5.0671029e-01,
#              0.0000000e+00,  7.7319125e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_81': {'HVAC': {'observation': array([ 1.6033333e+01,  2.5799999e+01,  1.0000000e+00, -5.0216401e-01,
#              0.0000000e+00,  7.1365506e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_82': {'HVAC': {'observation': array([ 1.630000e+01,  2.580000e+01,  1.000000e+00, -4.970478e-01,
#              0.000000e+00,  6.565149e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_83': {'HVAC': {'observation': array([ 1.6566668e+01,  2.5799999e+01,  1.0000000e+00, -4.9337399e-01,
#              0.0000000e+00,  5.9788312e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_84': {'HVAC': {'observation': array([ 1.6833334e+01,  2.5799999e+01,  1.0000000e+00, -4.8964414e-01,
#              0.0000000e+00,  5.4127319e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_85': {'HVAC': {'observation': array([ 1.7100000e+01,  2.5799999e+01,  1.0000000e+00, -4.8587731e-01,
#              0.0000000e+00,  4.8878134e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00020676391972183623),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_86': {'HVAC': {'observation': array([ 1.7250000e+01,  2.5799999e+01,  1.0000000e+00, -4.8196253e-01,
#              0.0000000e+00,  4.7879588e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_87': {'HVAC': {'observation': array([ 1.7400000e+01,  2.5799999e+01,  1.0000000e+00, -4.7987407e-01,
#              0.0000000e+00,  4.7059234e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_88': {'HVAC': {'observation': array([ 1.7549999e+01,  2.5799999e+01,  1.0000000e+00, -4.7609752e-01,
#              0.0000000e+00,  4.6143088e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_89': {'HVAC': {'observation': array([ 1.7700001e+01,  2.5799999e+01,  1.0000000e+00, -4.7317708e-01,
#              0.0000000e+00,  4.5300078e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_90': {'HVAC': {'observation': array([ 1.7850000e+01,  2.5799999e+01,  1.0000000e+00, -4.7023287e-01,
#              0.0000000e+00,  4.4485934e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_91': {'HVAC': {'observation': array([ 1.8000000e+01,  2.5799999e+01,  1.0000000e+00, -4.6738636e-01,
#              0.0000000e+00,  4.3694100e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00018752158843482784),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_92': {'HVAC': {'observation': array([ 1.8033333e+01,  2.5799999e+01,  1.0000000e+00, -4.6571738e-01,
#              0.0000000e+00,  4.4642228e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_93': {'HVAC': {'observation': array([ 1.8066668e+01,  2.5799999e+01,  1.0000000e+00, -4.6550670e-01,
#              0.0000000e+00,  4.5577738e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_94': {'HVAC': {'observation': array([ 1.8100000e+01,  2.5799999e+01,  1.0000000e+00, -4.6612573e-01,
#              0.0000000e+00,  4.5031200e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_95': {'HVAC': {'observation': array([ 1.8133333e+01,  2.5799999e+01,  1.0000000e+00, -4.6648943e-01,
#              0.0000000e+00,  4.3950400e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_96': {'HVAC': {'observation': array([ 1.8166666e+01,  2.5799999e+01,  1.0000000e+00, -4.6708149e-01,
#              0.0000000e+00,  4.3089712e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_97': {'HVAC': {'observation': array([ 1.8200001e+01,  2.5799999e+01,  1.0000000e+00, -4.6787637e-01,
#              0.0000000e+00,  4.2465631e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00018023940365352348),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_98': {'HVAC': {'observation': array([ 1.8133333e+01,  2.5799999e+01,  1.0000000e+00, -4.6840489e-01,
#              0.0000000e+00,  3.4226728e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_99': {'HVAC': {'observation': array([ 1.8066668e+01,  2.5799999e+01,  1.0000000e+00, -4.6748742e-01,
#              0.0000000e+00,  2.5392391e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_100': {'HVAC': {'observation': array([ 1.8000000e+01,  2.5799999e+01,  1.0000000e+00, -4.6929881e-01,
#              0.0000000e+00,  4.2279012e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_101': {'HVAC': {'observation': array([ 1.7933332e+01,  2.5799999e+01,  1.0000000e+00, -4.7441399e-01,
#              0.0000000e+00,  4.4222347e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_102': {'HVAC': {'observation': array([ 1.7866667e+01,  2.5799999e+01,  1.0000000e+00, -4.8003447e-01,
#              0.0000000e+00,  4.6169044e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_103': {'HVAC': {'observation': array([ 1.7799999e+01,  2.5799999e+01,  1.0000000e+00, -4.8709625e-01,
#              0.0000000e+00,  4.7200897e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00018723161551615936),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_104': {'HVAC': {'observation': array([ 1.7616667e+01,  2.5799999e+01,  1.0000000e+00, -4.9162412e-01,
#              0.0000000e+00,  4.7940338e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_105': {'HVAC': {'observation': array([ 1.7433332e+01,  2.5799999e+01,  1.0000000e+00, -4.9527502e-01,
#              0.0000000e+00,  4.8687491e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_106': {'HVAC': {'observation': array([ 1.7250000e+01,  2.5799999e+01,  1.0000000e+00, -4.9833521e-01,
#              0.0000000e+00,  4.9435878e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_107': {'HVAC': {'observation': array([ 1.7066668e+01,  2.5799999e+01,  1.0000000e+00, -5.0167698e-01,
#              0.0000000e+00,  5.0226044e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_108': {'HVAC': {'observation': array([ 1.6883333e+01,  2.5799999e+01,  1.0000000e+00, -5.0375301e-01,
#              0.0000000e+00,  5.0929744e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_109': {'HVAC': {'observation': array([ 1.670000e+01,  2.580000e+01,  1.000000e+00, -5.058056e-01,
#              0.000000e+00,  5.161567e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00021006635953071666),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_110': {'HVAC': {'observation': array([ 1.645000e+01,  2.580000e+01,  1.000000e+00, -5.078688e-01,
#              0.000000e+00,  5.310235e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_111': {'HVAC': {'observation': array([ 1.6200001e+01,  2.5799999e+01,  1.0000000e+00, -5.0968736e-01,
#              0.0000000e+00,  5.4611812e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_112': {'HVAC': {'observation': array([ 1.5950000e+01,  2.5799999e+01,  1.0000000e+00, -5.1111996e-01,
#              0.0000000e+00,  5.6120725e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_113': {'HVAC': {'observation': array([ 1.5700000e+01,  2.5799999e+01,  1.0000000e+00, -5.1080006e-01,
#              0.0000000e+00,  5.7509738e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_114': {'HVAC': {'observation': array([ 1.5450000e+01,  2.5799999e+01,  1.0000000e+00, -5.1023853e-01,
#              0.0000000e+00,  5.8864856e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_115': {'HVAC': {'observation': array([ 1.5200000e+01,  2.5799999e+01,  1.0000000e+00, -5.0962496e-01,
#              0.0000000e+00,  6.0221638e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00022017332719707206),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_116': {'HVAC': {'observation': array([ 1.510000e+01,  2.580000e+01,  1.000000e+00, -5.093430e-01,
#              0.000000e+00,  6.065707e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_117': {'HVAC': {'observation': array([ 1.5000000e+01,  2.5799999e+01,  1.0000000e+00, -5.0951815e-01,
#              0.0000000e+00,  6.1088069e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_118': {'HVAC': {'observation': array([ 1.4900000e+01,  2.5799999e+01,  1.0000000e+00, -5.0997716e-01,
#              0.0000000e+00,  6.1511069e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_119': {'HVAC': {'observation': array([ 1.480000e+01,  2.580000e+01,  1.000000e+00, -5.106224e-01,
#              0.000000e+00,  6.192800e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_120': {'HVAC': {'observation': array([ 1.4700000e+01,  2.5799999e+01,  1.0000000e+00, -5.1140237e-01,
#              0.0000000e+00,  6.2342762e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_121': {'HVAC': {'observation': array([ 1.460000e+01,  2.580000e+01,  1.000000e+00, -5.122396e-01,
#              0.000000e+00,  6.275451e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00022081365351296677),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_122': {'HVAC': {'observation': array([ 1.4483334e+01,  2.5799999e+01,  1.0000000e+00, -5.1350343e-01,
#              0.0000000e+00,  6.8078094e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_123': {'HVAC': {'observation': array([ 1.4366667e+01,  2.5799999e+01,  1.0000000e+00, -5.1514202e-01,
#              0.0000000e+00,  7.3630994e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_124': {'HVAC': {'observation': array([ 1.4250000e+01,  2.5799999e+01,  1.0000000e+00, -5.1705557e-01,
#              0.0000000e+00,  7.9414906e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_125': {'HVAC': {'observation': array([ 1.4133333e+01,  2.5799999e+01,  1.0000000e+00, -5.1906306e-01,
#              0.0000000e+00,  8.5429419e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_126': {'HVAC': {'observation': array([ 1.4016666e+01,  2.5799999e+01,  1.0000000e+00, -5.2108371e-01,
#              0.0000000e+00,  9.1675362e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
# ...
#              0.0000000e+00,  7.9921606e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_250': {'HVAC': {'observation': array([ 1.3750000e+01,  2.5799999e+01,  1.0000000e+00, -5.2176851e-01,
#              0.0000000e+00,  7.6444625e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_251': {'HVAC': {'observation': array([ 1.3666667e+01,  2.5799999e+01,  1.0000000e+00, -5.2626055e-01,
#              0.0000000e+00,  6.8963456e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_252': {'HVAC': {'observation': array([ 1.3583333e+01,  2.5799999e+01,  1.0000000e+00, -5.3054225e-01,
#              0.0000000e+00,  6.2861425e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_253': {'HVAC': {'observation': array([ 1.350000e+01,  2.580000e+01,  1.000000e+00, -5.364607e-01,
#              0.000000e+00,  5.579525e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00023820910916437667),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_254': {'HVAC': {'observation': array([ 1.335000e+01,  2.580000e+01,  1.000000e+00, -5.413898e-01,
#              0.000000e+00,  5.917086e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_255': {'HVAC': {'observation': array([ 1.320000e+01,  2.580000e+01,  1.000000e+00, -5.472192e-01,
#              0.000000e+00,  6.088509e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_256': {'HVAC': {'observation': array([ 1.3050000e+01,  2.5799999e+01,  1.0000000e+00, -5.5322343e-01,
#              0.0000000e+00,  6.2616819e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_257': {'HVAC': {'observation': array([ 1.2900000e+01,  2.5799999e+01,  1.0000000e+00, -5.5560160e-01,
#              0.0000000e+00,  6.4516544e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_258': {'HVAC': {'observation': array([ 1.2750000e+01,  2.5799999e+01,  1.0000000e+00, -5.5790704e-01,
#              0.0000000e+00,  6.6478738e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_259': {'HVAC': {'observation': array([ 1.260000e+01,  2.580000e+01,  1.000000e+00, -5.601374e-01,
#              0.000000e+00,  6.843994e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.0002648392677586051),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_260': {'HVAC': {'observation': array([ 1.2500000e+01,  2.5799999e+01,  1.0000000e+00, -5.6248909e-01,
#              0.0000000e+00,  6.7883075e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_261': {'HVAC': {'observation': array([ 1.240000e+01,  2.580000e+01,  1.000000e+00, -5.649473e-01,
#              0.000000e+00,  6.729181e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_262': {'HVAC': {'observation': array([ 1.2300000e+01,  2.5799999e+01,  1.0000000e+00, -5.6751317e-01,
#              0.0000000e+00,  6.6668169e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_263': {'HVAC': {'observation': array([ 1.2200000e+01,  2.5799999e+01,  1.0000000e+00, -5.7002896e-01,
#              0.0000000e+00,  6.6298381e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_264': {'HVAC': {'observation': array([ 1.2100000e+01,  2.5799999e+01,  1.0000000e+00, -5.7259488e-01,
#              0.0000000e+00,  6.6127025e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_265': {'HVAC': {'observation': array([ 1.200000e+01,  2.580000e+01,  1.000000e+00, -5.751633e-01,
#              0.000000e+00,  6.593967e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.000283254358107203),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_266': {'HVAC': {'observation': array([ 1.1883333e+01,  2.5799999e+01,  1.0000000e+00, -5.7740611e-01,
#              0.0000000e+00,  6.6105112e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_267': {'HVAC': {'observation': array([ 1.1766666e+01,  2.5799999e+01,  1.0000000e+00, -5.7924545e-01,
#              0.0000000e+00,  6.6262425e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_268': {'HVAC': {'observation': array([ 1.1650000e+01,  2.5799999e+01,  1.0000000e+00, -5.8056545e-01,
#              0.0000000e+00,  6.2895069e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_269': {'HVAC': {'observation': array([ 1.1533334e+01,  2.5799999e+01,  1.0000000e+00, -5.8136851e-01,
#              0.0000000e+00,  5.8545600e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_270': {'HVAC': {'observation': array([ 1.1416667e+01,  2.5799999e+01,  1.0000000e+00, -5.8172214e-01,
#              0.0000000e+00,  5.3786812e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_271': {'HVAC': {'observation': array([ 1.1300000e+01,  2.5799999e+01,  1.0000000e+00, -5.8161694e-01,
#              0.0000000e+00,  4.8501278e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.0002968404906682996),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_272': {'HVAC': {'observation': array([ 1.1200000e+01,  2.5799999e+01,  1.0000000e+00, -5.8209705e-01,
#              0.0000000e+00,  5.6679112e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_273': {'HVAC': {'observation': array([ 1.1100000e+01,  2.5799999e+01,  1.0000000e+00, -5.8332771e-01,
#              0.0000000e+00,  6.2822594e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_274': {'HVAC': {'observation': array([ 1.1000000e+01,  2.5799999e+01,  1.0000000e+00, -5.8462626e-01,
#              0.0000000e+00,  6.1648094e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_275': {'HVAC': {'observation': array([ 1.090000e+01,  2.580000e+01,  1.000000e+00, -5.856154e-01,
#              0.000000e+00,  5.980206e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_276': {'HVAC': {'observation': array([ 1.0800000e+01,  2.5799999e+01,  1.0000000e+00, -5.8628637e-01,
#              0.0000000e+00,  5.7898381e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_277': {'HVAC': {'observation': array([ 1.0700000e+01,  2.5799999e+01,  1.0000000e+00, -5.8671230e-01,
#              0.0000000e+00,  5.5939794e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00030223903098497006),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_278': {'HVAC': {'observation': array([ 1.0583333e+01,  2.5799999e+01,  1.0000000e+00, -5.8726573e-01,
#              0.0000000e+00,  6.0543050e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_279': {'HVAC': {'observation': array([ 1.0466666e+01,  2.5799999e+01,  1.0000000e+00, -5.8804095e-01,
#              0.0000000e+00,  6.5433850e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_280': {'HVAC': {'observation': array([ 1.0350000e+01,  2.5799999e+01,  1.0000000e+00, -5.8885109e-01,
#              0.0000000e+00,  6.8123794e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_281': {'HVAC': {'observation': array([ 1.0233334e+01,  2.5799999e+01,  1.0000000e+00, -5.8953369e-01,
#              0.0000000e+00,  6.9865669e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_282': {'HVAC': {'observation': array([ 1.0116667e+01,  2.5799999e+01,  1.0000000e+00, -5.9008813e-01,
#              0.0000000e+00,  7.1872394e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_283': {'HVAC': {'observation': array([ 1.000000e+01,  2.580000e+01,  1.000000e+00, -5.905560e-01,
#              0.000000e+00,  7.423596e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.00030753264498165067),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_284': {'HVAC': {'observation': array([ 9.900000e+00,  2.580000e+01,  1.000000e+00, -5.917409e-01,
#              0.000000e+00,  7.529026e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_285': {'HVAC': {'observation': array([ 9.8000002e+00,  2.5799999e+01,  1.0000000e+00, -5.9373695e-01,
#              0.0000000e+00,  7.6347800e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_286': {'HVAC': {'observation': array([ 9.700000e+00,  2.580000e+01,  1.000000e+00, -5.963533e-01,
#              0.000000e+00,  7.755710e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_287': {'HVAC': {'observation': array([ 9.600000e+00,  2.580000e+01,  1.000000e+00, -5.993821e-01,
#              0.000000e+00,  7.916265e+05,  0.000000e+00,  2.580000e+01,
#              2.680000e+01,  1.000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_288': {'HVAC': {'observation': array([ 9.5000000e+00,  2.5799999e+01,  1.0000000e+00, -6.0266936e-01,
#              0.0000000e+00,  8.0770325e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_289': {'HVAC': {'observation': array([ 9.3999996e+00,  2.5799999e+01,  1.0000000e+00, -6.0611624e-01,
#              0.0000000e+00,  8.2380412e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-0.0003192333787276362),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_290': {'HVAC': {'observation': array([ 9.3999996e+00,  2.5799999e+01,  1.0000000e+00, -6.0611624e-01,
#              0.0000000e+00,  8.2380412e+05,  0.0000000e+00,  2.5799999e+01,
#              2.6799999e+01,  1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': np.float64(-5.486417570542639e-05),
#      'done': True,
#      'truncated': False,
#      'info': {}}}}}}

# %%
# for agent in feature_names_index.keys():
#     energy_total: List[float] = []
#     for timestep in range(1,len(df["experiment"]["episode_1"])):
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]])
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Cooling:DistrictCooling"]])
#     print(sum(energy_total)/3600000)

# %%
for agent in feature_names_index.keys():
    action_list_1: List[float] = []
    action_list_2: List[float] = []
    av_list: List[int] = []
    t_r_list: List[float] = []
    t_c_list: List[float] = []
    t_i_list: List[float] = []
    occ_list: List[float] = []
    t_out_list: List[float] = []
    energy_list: List[float] = []
    pmv_list: List[float] = []
    pmv_hist: List[float] = []
    for timestep in range(1,len(df["experiment"]["episode_1"])):
        if env_config["agents_config"][agent]["observation"]["history_len"] > 1:
            t_i_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Mean Air Temperature: Thermal Zone"]])
            t_out_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Site Outdoor Air Drybulb Temperature: Environment"]])
            energy_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]]/3600000)
            occ_t = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone People Occupant Count: Thermal Zone"]]
            if occ_t > 0:
                occ_list.append(occ_t)
                pmv_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
                pmv_hist.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
            else:
                occ_list.append(0)
                pmv_list.append(0)
        
        else:
            t_i_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Mean Air Temperature: Thermal Zone"]])
            t_out_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Site Outdoor Air Drybulb Temperature: Environment"]])
            energy_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]]/3600000)
            occ_t = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone People Occupant Count: Thermal Zone"]]
            if occ_t > 0:
                occ_list.append(occ_t)
                pmv_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
                pmv_hist.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
            else:
                occ_list.append(0)
                pmv_list.append(0)
        
        
        if df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"] is None:
            pass
        else:
            a1 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][0]
            a2 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][1]
            action_list_1.append(a1)
            action_list_2.append(a2)
            temp_range = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["temperature_range"]
            action_range: int = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["action_space_dim"]
            if a1 > 0:
                t_r_list.append(min(temp_range)+((a2/action_range)*(max(temp_range)-min(temp_range)))+(a1-1)/2 + 1)
                t_c_list.append(min(temp_range)+((a2/action_range)*(max(temp_range)-min(temp_range)))-(a1-1)/2)
                av_list.append(a1)
            else:
                t_r_list.append(0)
                t_c_list.append(0)
                av_list.append(0)

# %%
for agent in feature_names_index.keys():
    # 1. Time series plot
    plt.figure(figsize=(7, 5))
    plt.subplot(2, 1, 1)
    plt.plot(t_r_list, label='Tr', color='blue', alpha=0.6)
    plt.plot(t_c_list, label='Tc', color='red', alpha=0.6)
    plt.plot(t_i_list, label='Ti', color='green', alpha=0.6)
    plt.plot(t_out_list, label='To', color='black', alpha=0.6)
    plt.ylabel('Temperatura, °C')
    plt.grid(True, alpha=0.3)
    plt.legend(loc='upper left', bbox_to_anchor=(-0.37, 1), fontsize=9)
    
    plt.subplot(2, 1, 2)
    # plt.plot(av_list, label='Disponibilidad', color='red', alpha=0.6)
    plt.plot(occ_list, label='Ocupación', color='blue', alpha=0.6)
    plt.plot(pmv_list, label='PMV', color='green', alpha=0.6)
    plt.plot(energy_list, label='Energía', color='purple', alpha=0.6)
    plt.legend(loc='upper left', bbox_to_anchor=(-0.37, 1), fontsize=9)
    plt.xlabel('Paso de tiempo')
    plt.ylabel('Energía, kWh | adim')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
for agent in feature_names_index.keys():
    # 2. Histogram
    plt.figure(figsize=(7, 5))
    plt.hist(action_list_2, bins=11, color='skyblue', edgecolor='black')
    plt.hist(action_list_1, bins=11, color='lightgreen', edgecolor='black')
    plt.xlabel('Valor de la action')
    plt.xlim((0, 10))
    plt.ylabel('Frecuencia')
    # plt.ylim((0, 1))
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
for agent in feature_names_index.keys():
    # 3. PMV histogram plot    
    plt.figure(figsize=(7, 5))
    plt.hist(pmv_hist, bins=20, color='lightgreen', edgecolor='black')
    plt.xlabel('PMV Value')
    plt.xlim((-3, 3))
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# Basic statistical analysis
for agent in feature_names_index.keys():
    print(f"\nStatistical Summary ({agent}):")
    print(f"Mean: {np.mean(action_list_1):.2f}")
    print(f"Median: {np.median(action_list_1):.2f}")
    print(f"Std Dev: {np.std(action_list_1):.2f}")
    print(f"Min: {np.min(action_list_1):.2f}")
    print(f"Max: {np.max(action_list_1):.2f}")
    print(f"Mean: {np.mean(action_list_2):.2f}")
    print(f"Median: {np.median(action_list_2):.2f}")
    print(f"Std Dev: {np.std(action_list_2):.2f}")
    print(f"Min: {np.min(action_list_2):.2f}")
    print(f"Max: {np.max(action_list_2):.2f}")
    print(f"Total Energy Consumption (kWh): {sum(energy_list):.2f}")
# Out:
# Statistical Summary (HVAC):
# Mean: 1.00
# Median: 1.00
# Std Dev: 0.00
# Min: 1.00
# Max: 1.00
# Mean: 8.00
# Median: 8.00
# Std Dev: 0.06
# Min: 8.00
# Max: 9.00
# Total Energy Consumption (kWh): 69.86

# %%
obs: List[float|int] = [-3,-2,-1,0,1,2,3]
rew: List[float] = []
for _ in range(len(obs)):
    rew.append(-(np.exp(obs[_]**2) - 1.0)/(np.exp(3**2)-1))
    
print(rew)
# Out:
# [np.float64(-1.0), np.float64(-0.006615353594489847), np.float64(-0.00021207899644323422), np.float64(-0.0), np.float64(-0.00021207899644323422), np.float64(-0.006615353594489847), np.float64(-1.0)]

# %%
norm_energy: List[float] = [1.0,0.75,0.5,0.25,0.0]
c: float = 6000 / (60/6) * (np.exp(3**2)-1)

rew_e: List[float] = []
for _ in range(len(norm_energy)):
    rew_e.append(-norm_energy[_] * (1 / c))
    
print(rew_e)
# Out:
# [np.float64(-2.0570839324364178e-07), np.float64(-1.5428129493273133e-07), np.float64(-1.0285419662182089e-07), np.float64(-5.1427098310910444e-08), np.float64(-0.0)]

# %%
labelsize = 14
time_steps = np.arange(len(action_list_2))
time_steps_1 = np.arange(len(action_list_2)+1)
# --- Creación de la figura y subgráficas ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14.5, 6))
# fig.suptitle('Análisis de Control y Ocupación', fontsize=18, fontweight='bold', y=1.02)

# --- Subgráfica 1: Gráfico de series de tiempo ---
# Determinar y aplicar el color de fondo basado en la ocupación
is_occupied = False
start_occupancy = 0
for i, occ in enumerate(occ_list):
    if occ > 0 and not is_occupied:
        is_occupied = True
        start_occupancy = i
    elif occ == 0 and is_occupied:
        is_occupied = False
        end_occupancy = i
        # Usar axvspan para crear la región sombreada.
        # El color semi-transparente ayuda a ver las líneas del grid.
        ax1.axvspan(start_occupancy, end_occupancy, color='#ADD8E6', alpha=0.3, label='Ocupado' if start_occupancy == 0 else "")

# Dibujar las líneas de las series de tiempo sobre el fondo
ax1.plot(time_steps, t_r_list, label='Temp. Refri.', color='#1f77b4', linewidth=2, linestyle='--')
ax1.plot(time_steps, t_c_list, label='Temp. Calef.', color='#1f77b4', linewidth=2, linestyle=':')
ax1.plot(time_steps_1, t_i_list, label='Temp. Interna', color='#d62728', linestyle='--')
ax1.plot(time_steps_1, t_out_list, label='Temp. Externa', color='#2ca02c', linestyle='--')

# ax1.set_title('Valores de Control y Temperaturas', fontsize=14)
ax1.set_xlabel('Paso de Tiempo', fontsize=labelsize)
ax1.set_ylabel('Valor', fontsize=12)
ax1.tick_params(axis='both', which='major', labelsize=labelsize)
ax1.grid(True, linestyle='--', alpha=0.6)
# ax1.legend(loc='upper right')
ax1.legend(loc='upper left', bbox_to_anchor=(-0.5, 1), fontsize=labelsize)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# --- Subgráfica 2: Histograma normalizado ---
# Para obtener el porcentaje en el eje Y, usamos el argumento 'weights'.
total_actions = len(action_list_2)
weights = np.ones(total_actions) / total_actions * 100

n, bins, patches = ax2.hist(action_list_2, bins=np.arange(-0.5, 11.5, 1), weights=weights, color="#86EE80", edgecolor='black', alpha=0.8)
n, bins, patches = ax2.hist(action_list_1, bins=np.arange(-0.5, 11.5, 1), weights=weights, color='#87CEEB', edgecolor='black', alpha=0.8)
ax2.set_xlabel('Valor de la Acción', fontsize=labelsize)
ax2.set_ylabel('Porcentaje de Frecuencia', fontsize=labelsize)

# Aumentar el tamaño de la fuente para los valores de los ejes
ax2.tick_params(axis='both', which='major', labelsize=labelsize)
ax2.set_xlim(0, 11)
# Establecer los valores discretos en el eje horizontal
ax2.set_xticks(np.arange(0, 11))
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

# Mejorar el diseño del layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15.5, 5))

# # Histogram
# plt.hist(action_list, bins=30, color='skyblue', edgecolor='black')
# plt.title('Distribución de acciones')
# plt.xlabel('Valor de la action')
# plt.ylabel('Frecuencia')
# plt.grid(True, alpha=0.3)

# plt.tight_layout()
# plt.show()

# %%
# # Scatter plot of the variables action_list = df[agent]["actions"] vs cooling_energy = []
# action_list = df[agent]["actions"]
# cooling_energy = []
# for timestep in range(len(df[agent]["infos"])-1):
#     cooling_energy.append(df[agent]["infos"][timestep][f"{agent}: Cooling:DistrictCooling"])

# plt.figure(figsize=(7.5, 5))
# plt.scatter(action_list, cooling_energy, s=1)
# plt.xlabel("Action")
# plt.ylabel("Cooling energy")
# plt.title("Scatter plot of Action vs Cooling energy")
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
# # Analyze transitions between actions
# transitions = np.diff(action_list)
# plt.figure(figsize=(10, 4))
# plt.plot(transitions, label='Action Changes')
# plt.title('Action Transitions Over Time')
# plt.xlabel('Time Step')
# plt.ylabel('Change in Action')
# plt.grid(True, alpha=0.3)
# plt.show()

# # Calculate transition statistics
# print("\nTransition Analysis:")
# print(f"Mean absolute change: {np.mean(np.abs(transitions)):.2f}")
# print(f"Max increase: {np.max(transitions):.2f}")
# print(f"Max decrease: {np.min(transitions):.2f}")

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15, 5))

# # 1. Time series plot
# plt.scatter(action_list, occ_list, color='blue', alpha=0.6)
# plt.title('Action-occupancy distribution')
# plt.xlabel('Action Value')
# plt.ylabel('Occupancy')
# plt.grid(True, alpha=0.3)

# %%
from typing import List, Any, Optional

agent:str = "HVAC"

feature_names_list: List[str] = feature_names[agent]

data_obs_list: List[Any] = []
for timestep in range(1,len(df["experiment"]["episode_1"])):
    data_obs_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"])
        
data_obs = np.array(data_obs_list)

# %%
feature_names_list
# Out:
# ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#  'HVAC: Zone Mean Air Temperature: Thermal Zone',
#  'HVAC: Zone People Occupant Count: Thermal Zone',
#  'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#  'HVAC: Electricity:Building',
#  'HVAC: Heating:DistrictHeatingWater',
#  'HVAC: Cooling:DistrictCooling',
#  'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#  'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#  'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']

# %%
print(data_obs.shape)
# Out:
# (289, 10)

# %%
from numpy.typing import NDArray
from numpy import float32
import torch
# Model prediction function (adapted for RLlib)
POLICY: Optional[Policy] = None
def model_predict(
    data: NDArray[float32],
):
    # Transform the lists in tensors.
    obs_tensor = torch.tensor(data, dtype=torch.float32)
    
    # Compute the actions.
    with torch.no_grad():
        predictions = POLICY.compute_actions(
            obs_batch=obs_tensor.numpy(), 
            exploration=False, 
        )[0]
    return predictions

# %%
# Use KernelExplainer
data_obs_sample = shap.sample(data_obs, 1000)

POLICY = single_policy
explainer = shap.KernelExplainer(
    model_predict,
    data=data_obs_sample,
    feature_names=feature_names_list
    )
# Out:
# Using 289 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.

# %%
background_data_np_sample = shap.sample(data_obs, 100)

# %%
shap_values_1 = explainer(background_data_np_sample)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
shap_values_1
# Out:
# .values =
# array([[[-0.01141045,  0.00263635],
#         [-0.0240402 , -0.0042264 ],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.02726973, -0.00405339],
#         [-0.01908057,  0.00154062],
#         [-0.02380952,  0.00298237]],
#
#        [[-0.01962432,  0.0033737 ],
#         [-0.01939364,  0.01069781],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.02296919, -0.013812  ],
#         [-0.02319987,  0.        ],
#         [-0.02048937,  0.00077855]],
#
#        [[-0.02470753,  0.00496787],
#         [-0.01565332,  0.00906245],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.0274757 , -0.01071841],
#         [-0.01986324,  0.00225737],
#         [-0.02309277, -0.00489372]],
#
#        ...,
#
#        [[-0.02374362,  0.00882353],
#         [-0.02166749,  0.00426759],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.01838029, -0.00865052],
#         [-0.02034108,  0.00420992],
#         [-0.02731916,  0.00519031]],
#
#        [[-0.01950074,  0.00467952],
#         [-0.01759763,  0.00421816],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.02676718, -0.01181414],
#         [-0.02342231,  0.00450651],
#         [-0.03045807,  0.00387214]],
#
#        [[-0.02377657, -0.00734058],
#         [-0.01806723,  0.00961443],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.01973966, -0.00837865],
#         [-0.02746746,  0.0067886 ],
#         [-0.02037403, -0.00226561]]])
#
# .base_values =
# array([[1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917],
#        [1.15570934, 7.98615917]])
#
# .data =
# array([[ 7.9499998e+00,  2.5799999e+01,  1.0000000e+00, -6.5383023e-01,
#          0.0000000e+00,  1.3389474e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.0333338e+00,  2.5799999e+01,  1.0000000e+00, -5.7095194e-01,
#          0.0000000e+00,  1.2517155e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.8066668e+01,  2.5799999e+01,  1.0000000e+00, -4.6550670e-01,
#          0.0000000e+00,  4.5577738e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.2950000e+01,  2.5799999e+01,  1.0000000e+00, -4.5543543e-01,
#          0.0000000e+00,  6.6598438e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.2300000e+01,  2.5799999e+01,  1.0000000e+00, -5.6751317e-01,
#          0.0000000e+00,  6.6668169e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 7.7500000e+00,  2.5799999e+01,  1.0000000e+00, -6.7452109e-01,
#          0.0000000e+00,  7.8858488e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5950000e+01,  2.5799999e+01,  1.0000000e+00, -5.1111996e-01,
#          0.0000000e+00,  5.6120725e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.4833333e+01,  2.5799999e+01,  1.0000000e+00, -5.2755195e-01,
#          0.0000000e+00,  8.6804806e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.7500000e+00,  2.5799999e+01,  1.0000000e+00, -3.5896412e-01,
#          0.0000000e+00,  1.4297984e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.4666662e+00,  2.5799999e+01,  1.0000000e+00, -3.6583942e-01,
#          0.0000000e+00,  1.3196315e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.8999996e+00,  2.5799999e+01,  1.0000000e+00, -5.6315422e-01,
#          0.0000000e+00,  1.2773244e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.8999996e+00,  2.5799999e+01,  1.0000000e+00, -5.9174091e-01,
#          0.0000000e+00,  7.5290262e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.8999996e+00,  2.5799999e+01,  1.0000000e+00, -3.5839823e-01,
#          0.0000000e+00,  1.5204861e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.6299999e+01,  2.5799999e+01,  1.0000000e+00, -4.9704781e-01,
#          0.0000000e+00,  6.5651488e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0350000e+01,  2.5799999e+01,  1.0000000e+00, -6.0775453e-01,
#          0.0000000e+00,  1.0824758e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.6999998e+00,  2.5799999e+01,  1.0000000e+00, -5.9635329e-01,
#          0.0000000e+00,  7.7557100e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.7066668e+01,  2.5799999e+01,  1.0000000e+00, -4.6858066e-01,
#          0.0000000e+00,  6.9958356e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.3999996e+00,  2.5799999e+01,  1.0000000e+00, -6.0611624e-01,
#          0.0000000e+00,  8.2380412e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.0666666e+00,  2.5799999e+01,  1.0000000e+00, -5.6906128e-01,
#          0.0000000e+00,  1.2223948e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.2900000e+01,  2.5799999e+01,  1.0000000e+00, -5.3251684e-01,
#          0.0000000e+00,  7.7705950e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.1000000e+01,  2.5799999e+01,  1.0000000e+00, -5.2760863e-01,
#          0.0000000e+00,  5.2009356e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5266666e+01,  2.5799999e+01,  1.0000000e+00, -5.1340216e-01,
#          0.0000000e+00,  7.4491194e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.7866667e+01,  2.5799999e+01,  1.0000000e+00, -4.8003447e-01,
#          0.0000000e+00,  4.6169044e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.2500000e+01,  2.5799999e+01,  1.0000000e+00, -4.6434677e-01,
#          0.0000000e+00,  7.4700381e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.7066668e+01,  2.5799999e+01,  1.0000000e+00, -5.0167698e-01,
#          0.0000000e+00,  5.0226044e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.6200001e+01,  2.5799999e+01,  1.0000000e+00, -5.0968736e-01,
#          0.0000000e+00,  5.4611812e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.6466667e+01,  2.5799999e+01,  1.0000000e+00, -4.2079133e-01,
#          0.0000000e+00,  6.1269462e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.6883333e+01,  2.5799999e+01,  1.0000000e+00, -4.8300460e-01,
#          0.0000000e+00,  6.7084669e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3900000e+01,  2.5799999e+01,  1.0000000e+00, -5.2305359e-01,
#          0.0000000e+00,  9.8152231e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.5500002e+00,  2.5799999e+01,  1.0000000e+00, -5.5084175e-01,
#          0.0000000e+00,  1.2188768e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5233334e+01,  2.5799999e+01,  1.0000000e+00, -4.1719440e-01,
#          0.0000000e+00,  5.1256381e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.1666670e+00,  2.5799999e+01,  1.0000000e+00, -3.5040995e-01,
#          0.0000000e+00,  1.5576208e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.7500000e+00,  2.5800001e+01,  1.0000000e+00, -3.3559263e-01,
#          0.0000000e+00,  1.4384910e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.6999998e+00,  2.5799999e+01,  1.0000000e+00, -5.3415304e-01,
#          0.0000000e+00,  1.2277371e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.8000000e+01,  2.5799999e+01,  1.0000000e+00, -4.6738636e-01,
#          0.0000000e+00,  4.3694100e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.4000000e+01,  2.5799999e+01,  1.0000000e+00, -5.2857298e-01,
#          0.0000000e+00,  8.4648362e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.8133333e+01,  2.5799999e+01,  1.0000000e+00, -4.6840489e-01,
#          0.0000000e+00,  3.4226728e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.7616667e+01,  2.5799999e+01,  1.0000000e+00, -4.9162412e-01,
#          0.0000000e+00,  4.7940338e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.2333336e+00,  2.5799999e+01,  1.0000000e+00, -3.4721160e-01,
#          0.0000000e+00,  1.5756066e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0733334e+01,  2.5799999e+01,  1.0000000e+00, -6.0212559e-01,
#          0.0000000e+00,  1.1494990e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3666667e+01,  2.5799999e+01,  1.0000000e+00, -5.3396136e-01,
#          0.0000000e+00,  9.6845375e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0450000e+01,  2.5799999e+01,  1.0000000e+00, -5.3319144e-01,
#          0.0000000e+00,  8.8996206e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3200000e+01,  2.5799999e+01,  1.0000000e+00, -5.4721922e-01,
#          0.0000000e+00,  6.0885088e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.2050000e+01,  2.5799999e+01,  1.0000000e+00, -4.7301665e-01,
#          0.0000000e+00,  8.3376188e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.1300000e+01,  2.5799999e+01,  1.0000000e+00, -5.8161694e-01,
#          0.0000000e+00,  4.8501278e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.4133333e+01,  2.5799999e+01,  1.0000000e+00, -5.1906306e-01,
#          0.0000000e+00,  8.5429419e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0566667e+01,  2.5799999e+01,  1.0000000e+00, -5.2895004e-01,
#          0.0000000e+00,  3.6432100e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3400000e+01,  2.5799999e+01,  1.0000000e+00, -4.4690397e-01,
#          0.0000000e+00,  5.9057906e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.4033334e+01,  2.5799999e+01,  1.0000000e+00, -5.2707165e-01,
#          0.0000000e+00,  9.4050962e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.1000000e+01,  2.5799999e+01,  1.0000000e+00, -5.8462626e-01,
#          0.0000000e+00,  6.1648094e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.9499998e+00,  2.5799999e+01,  1.0000000e+00, -6.3711226e-01,
#          0.0000000e+00,  1.3381811e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0000000e+01,  2.5799999e+01,  1.0000000e+00, -5.9055603e-01,
#          0.0000000e+00,  7.4235962e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0900000e+01,  2.5799999e+01,  1.0000000e+00, -5.8561540e-01,
#          0.0000000e+00,  5.9802062e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.6966667e+01,  2.5799999e+01,  1.0000000e+00, -4.4826087e-01,
#          0.0000000e+00,  6.7260381e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.4766666e+01,  2.5799999e+01,  1.0000000e+00, -5.1749337e-01,
#          0.0000000e+00,  8.8643938e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.1400000e+01,  2.5799999e+01,  1.0000000e+00, -5.3315276e-01,
#          0.0000000e+00,  7.3509312e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0116667e+01,  2.5799999e+01,  1.0000000e+00, -5.9008813e-01,
#          0.0000000e+00,  7.1872394e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.5333338e+00,  2.5799999e+01,  1.0000000e+00, -3.6392254e-01,
#          0.0000000e+00,  1.4003448e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 7.7333331e+00,  2.5799999e+01,  1.0000000e+00, -6.7178565e-01,
#          0.0000000e+00,  6.9249338e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.2500000e+01,  2.5799999e+01,  1.0000000e+00, -5.6248909e-01,
#          0.0000000e+00,  6.7883075e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5600000e+01,  2.5799999e+01,  1.0000000e+00, -4.1454452e-01,
#          0.0000000e+00,  4.9821381e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.8000002e+00,  2.5799999e+01,  1.0000000e+00, -5.6186807e-01,
#          0.0000000e+00,  1.2900092e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.7000000e+01,  2.5799999e+01,  1.0000000e+00, -4.5574936e-01,
#          0.0000000e+00,  6.8208625e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.7666664e+00,  2.5799999e+01,  1.0000000e+00, -5.8096462e-01,
#          0.0000000e+00,  1.3183848e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.3000002e+00,  2.5799999e+01,  1.0000000e+00, -3.6468977e-01,
#          0.0000000e+00,  9.6871719e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3000000e+01,  2.5799999e+01,  1.0000000e+00, -5.3387767e-01,
#          0.0000000e+00,  8.5032950e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3916667e+01,  2.5799999e+01,  1.0000000e+00, -5.2678210e-01,
#          0.0000000e+00,  8.1822912e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 7.8833332e+00,  2.5799999e+01,  1.0000000e+00, -6.6991985e-01,
#          0.0000000e+00,  1.3732221e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.4133333e+01,  2.5799999e+01,  1.0000000e+00, -4.3158048e-01,
#          0.0000000e+00,  5.5823925e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.1100000e+01,  2.5799999e+01,  1.0000000e+00, -5.2978420e-01,
#          0.0000000e+00,  3.1894759e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0216666e+01,  2.5799999e+01,  1.0000000e+00, -5.4852360e-01,
#          0.0000000e+00,  1.1560632e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5000000e+01,  2.5799999e+01,  1.0000000e+00, -5.0951815e-01,
#          0.0000000e+00,  6.1088069e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3500000e+01,  2.5799999e+01,  1.0000000e+00, -5.3646070e-01,
#          0.0000000e+00,  5.5795250e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.7333336e+00,  2.5799999e+01,  1.0000000e+00, -5.8182108e-01,
#          0.0000000e+00,  1.3335228e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5816667e+01,  2.5799999e+01,  1.0000000e+00, -4.1505760e-01,
#          0.0000000e+00,  5.3749700e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.7033333e+01,  2.5799999e+01,  1.0000000e+00, -4.6177942e-01,
#          0.0000000e+00,  6.9088719e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3100000e+01,  2.5799999e+01,  1.0000000e+00, -5.3481567e-01,
#          0.0000000e+00,  9.3101725e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.6499996e+00,  2.5799999e+01,  1.0000000e+00, -5.5605727e-01,
#          0.0000000e+00,  1.2402609e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.7850000e+01,  2.5799999e+01,  1.0000000e+00, -4.7023287e-01,
#          0.0000000e+00,  4.4485934e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 7.7666669e+00,  2.5799999e+01,  1.0000000e+00, -6.7658484e-01,
#          0.0000000e+00,  1.2595396e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.6666666e+01,  2.5799999e+01,  1.0000000e+00, -4.9058643e-01,
#          0.0000000e+00,  6.4106556e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.3666668e+00,  2.5799999e+01,  1.0000000e+00, -5.4461312e-01,
#          0.0000000e+00,  1.2604331e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.8500004e+00,  2.5799999e+01,  1.0000000e+00, -5.6262892e-01,
#          0.0000000e+00,  1.2836605e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.1200000e+01,  2.5799999e+01,  1.0000000e+00, -5.8209705e-01,
#          0.0000000e+00,  5.6679112e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 7.6999998e+00,  2.5799999e+01,  1.0000000e+00, -6.5578282e-01,
#          0.0000000e+00,  9.8793975e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3600000e+01,  2.5799999e+01,  1.0000000e+00, -5.2822620e-01,
#          0.0000000e+00,  9.7485381e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.6000004e+00,  2.5799999e+01,  1.0000000e+00, -3.6216554e-01,
#          0.0000000e+00,  1.3773014e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0800000e+01,  2.5799999e+01,  1.0000000e+00, -5.2831322e-01,
#          0.0000000e+00,  7.5068156e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5400000e+01,  2.5799999e+01,  1.0000000e+00, -5.0908148e-01,
#          0.0000000e+00,  6.8018894e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5666667e+01,  2.5799999e+01,  1.0000000e+00, -5.0499731e-01,
#          0.0000000e+00,  5.6032106e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5533334e+01,  2.5799999e+01,  1.0000000e+00, -5.0703841e-01,
#          0.0000000e+00,  6.1828750e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.3000000e+01,  2.5799999e+01,  1.0000000e+00, -5.5021554e-01,
#          0.0000000e+00,  9.8164994e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 9.1666670e+00,  2.5799999e+01,  1.0000000e+00, -5.4518998e-01,
#          0.0000000e+00,  5.8375506e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.5133333e+01,  2.5799999e+01,  1.0000000e+00, -5.1768249e-01,
#          0.0000000e+00,  7.8983612e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.6999998e+00,  2.5799999e+01,  1.0000000e+00, -5.8271301e-01,
#          0.0000000e+00,  1.3460581e+06,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.0233334e+01,  2.5799999e+01,  1.0000000e+00, -5.8953369e-01,
#          0.0000000e+00,  6.9865669e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.1900000e+01,  2.5799999e+01,  1.0000000e+00, -5.2867973e-01,
#          0.0000000e+00,  7.4876481e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 8.0500002e+00,  2.5799999e+01,  1.0000000e+00, -3.6378703e-01,
#          0.0000000e+00,  7.8210962e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.6833334e+01,  2.5799999e+01,  1.0000000e+00, -4.8964414e-01,
#          0.0000000e+00,  5.4127319e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00],
#        [ 1.4800000e+01,  2.5799999e+01,  1.0000000e+00, -5.1062238e-01,
#          0.0000000e+00,  6.1928000e+05,  0.0000000e+00,  2.5799999e+01,
#          2.6799999e+01,  1.0000000e+00]], dtype=float32)

# %%
# Nombres de las acciones para los títulos de los gráficos (opcional pero recomendado)
action_names = ["Acción 1", "Acción 2"]

# Iteramos a través de los valores SHAP para cada acción de salida
for i, shap_values_for_action in enumerate(shap_values_1):
    
    # Creamos un objeto Explanation unificado para esta acción específica.
    # SHAP maneja internamente si la salida es de una o varias clases.
    # Le pasamos los valores SHAP, los datos originales y los nombres de las features.
    explanation_for_action = shap.Explanation(
        values=shap_values_for_action,
        base_values=explainer.expected_value[i], # El valor base para esta acción
        data=background_data_np_sample, # Los datos que se explicaron
        feature_names=feature_names # Tus nombres de features
    )

    # Generamos el gráfico de barras para la acción actual
    print(f"--- Gráfico de Importancia de Features para: {action_names[i]} ---")
    
    # Usamos la nueva API de ploteo que es más robusta
    shap.plots.bar(explanation_for_action, show=False)
    
    # Personalizamos y mostramos el gráfico con matplotlib
    plt.title(f"Importancia Global de Features para {action_names[i]}")
    plt.show()
# Out:
# --- Gráfico de Importancia de Features para: Acción 1 ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 21
#      18 print(f"--- Gráfico de Importancia de Features para: {action_names[i]} ---")
#      20 # Usamos la nueva API de ploteo que es más robusta
# ---> 21 shap.plots.bar(explanation_for_action, show=False)
#      23 # Personalizamos y mostramos el gráfico con matplotlib
#      24 plt.title(f"Importancia Global de Features para {action_names[i]}")
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_bar.py:106, in bar(shap_values, max_display, order, clustering, clustering_cutoff, show_data, ax, show)
#     102     raise TypeError(emsg)
#     104 if len(exp.shape) == 2:
#     105     # collapse the Explanation arrays to be of shape (#features,)
# --> 106     cohort_exps[i] = exp.abs.mean(0)
#     107 if cohort_exps[i].shape != cohort_exps[0].shape:
#     108     emsg = "When passing several Explanation objects, they must all have the same number of feature columns!"
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:540, in Explanation.abs(self)
#     538 @property
#     539 def abs(self):
# --> 540     return self._numpy_func("abs")
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:504, in Explanation._numpy_func(self, fname, **kwargs)
#     501     new_self = new_self[axis]
#     502     new_self.op_history = new_self.op_history[:-1]  # pop off the slicing operation we just used
# --> 504 if self.feature_names is not None and not is_1d(self.feature_names) and axis == 0:
#     505     new_values = self._flatten_feature_names()
#     506     new_self.feature_names = np.array(list(new_values.keys()))
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:810, in is_1d(val)
#     809 def is_1d(val):
# --> 810     return not (isinstance(val[0], (list, np.ndarray)))
#
# KeyError: 0

# %%
"""
Global bar plot
================

Passing a matrix of SHAP values to the bar plot function creates a global feature importance 
plot, where the global importance of each feature is taken to be the mean absolute value for 
that feature over all the given samples.

# By default the bar plot only shows a maximum of ten bars, but this can be controlled with the `max_display` parameter.
"""
shap.plots.bar(shap_values_1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 11
#       1 """
#       2 Global bar plot
#       3 ================
#    (...)
#       9 # By default the bar plot only shows a maximum of ten bars, but this can be controlled with the `max_display` parameter.
#      10 """
# ---> 11 shap.plots.bar(shap_values_1)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_bar.py:216, in bar(shap_values, max_display, order, clustering, clustering_cutoff, show_data, ax, show)
#     214 for inds in orig_inds:
#     215     if len(inds) == 1:
# --> 216         feature_names_new.append(feature_names[inds[0]])
#     217     else:
#     218         full_print = " + ".join([feature_names[i] for i in inds])
#
# IndexError: list index out of range

# %%
# for _ in range(50):
#     shap.plots.bar(shap_values_1[_], max_display=13)

# %%
"""
beeswarm summary plot
======================

The beeswarm plot is designed to display an information-dense summary of how the top features 
in a dataset impact the model’s output. Each instance the given explanation is represented by 
a single dot on each feature row. The x position of the dot is determined by the SHAP value 
(shap_values.value[instance,feature]) of that feature, and dots “pile up” along each feature row 
to show density. Color is used to display the original value of a feature 
(shap_values.data[instance,feature]).

By default the maximum number of features shown is ten, but this can be adjusted with the max_display parameter.
"""
shap.plots.beeswarm(shap_values_1, max_display=6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 14
#       1 """
#       2 beeswarm summary plot
#       3 ======================
#    (...)
#      12 By default the maximum number of features shown is ten, but this can be adjusted with the max_display parameter.
#      13 """
# ---> 14 shap.plots.beeswarm(shap_values_1, max_display=6)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_beeswarm.py:124, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     120 elif len(sv_shape) > 2:
#     121     emsg = (
#     122         "The beeswarm plot does not support plotting explanations with instances that have more than one dimension!"
#     123     )
# --> 124     raise ValueError(emsg)
#     126 if ax and plot_size:
#     127     emsg = (
#     128         "The beeswarm plot does not support passing an axis and adjusting the plot size. "
#     129         "To adjust the size of the plot, set plot_size to None and adjust the size on the original figure the axes was part of"
#     130     )
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
"""
Feature ordering
=================

By default the features are ordered using shap_values.abs.mean(0), which is the mean absolute value 
of the SHAP values for each feature. This order however places more emphasis on broad average impact, 
and less on rare but high magnitude impacts. If we want to find features with high impacts for individual 
people we can instead sort by the max absolute value.
"""
shap.plots.beeswarm(shap_values_1, max_display=6, order=shap_values_1.abs.max(0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 10
#       1 """
#       2 Feature ordering
#       3 =================
#    (...)
#       8 people we can instead sort by the max absolute value.
#       9 """
# ---> 10 shap.plots.beeswarm(shap_values_1, max_display=6, order=shap_values_1.abs.max(0))
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_beeswarm.py:124, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     120 elif len(sv_shape) > 2:
#     121     emsg = (
#     122         "The beeswarm plot does not support plotting explanations with instances that have more than one dimension!"
#     123     )
# --> 124     raise ValueError(emsg)
#     126 if ax and plot_size:
#     127     emsg = (
#     128         "The beeswarm plot does not support passing an axis and adjusting the plot size. "
#     129         "To adjust the size of the plot, set plot_size to None and adjust the size on the original figure the axes was part of"
#     130     )
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
"""
Sometimes it is helpful to transform the SHAP values before we plots them. Below we plot the absolute 
value and fix the color to be red. This creates a richer parallel to the standard shap_values.abs.mean(0) 
bar plot, since the bar plot just plots the mean value of the dots in the beeswarm plot.
"""
shap.plots.beeswarm(shap_values_1.abs, max_display=23, color="shap_red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 6
#       1 """
#       2 Sometimes it is helpful to transform the SHAP values before we plots them. Below we plot the absolute
#       3 value and fix the color to be red. This creates a richer parallel to the standard shap_values.abs.mean(0)
#       4 bar plot, since the bar plot just plots the mean value of the dots in the beeswarm plot.
#       5 """
# ----> 6 shap.plots.beeswarm(shap_values_1.abs, max_display=23, color="shap_red")
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_beeswarm.py:124, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     120 elif len(sv_shape) > 2:
#     121     emsg = (
#     122         "The beeswarm plot does not support plotting explanations with instances that have more than one dimension!"
#     123     )
# --> 124     raise ValueError(emsg)
#     126 if ax and plot_size:
#     127     emsg = (
#     128         "The beeswarm plot does not support passing an axis and adjusting the plot size. "
#     129         "To adjust the size of the plot, set plot_size to None and adjust the size on the original figure the axes was part of"
#     130     )
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
"""
A simple violin summary plot
=============================

The violin summary plot offers a compact representation of the distribution and variability of SHAP 
values for each feature. Individual violin plots are stacked by importance of the particular feature 
on model output (sum of the absolute values of the SHAP values per feature).

Violin plots use “violin-shaped” figures to display the distribution and density of SHAP values for their 
respective feature. The violins can therefore provide insights into the range, variability, skewness, 
symmetry, and multimodality of the SHAP value distribution for a specific feature.

The overall violin summary plot allow for comparisons in feature importance. Wider violins indicate higher 
density and more frequent values, thus providing insights into the relative importance of each feature with 
regard to the model output.
"""
shap.plots.violin(shap_values_1, max_display=23)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 17
#       1 """
#       2 A simple violin summary plot
#       3 =============================
#    (...)
#      15 regard to the model output.
#      16 """
# ---> 17 shap.plots.violin(shap_values_1, max_display=23)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_violin.py:186, in violin(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, use_log_scale)
#     184     ds = gaussian_kde(shaps + np.random.randn(len(shaps)) * (global_high - global_low) / 100)(xs)
#     185 else:
# --> 186     ds = gaussian_kde(shaps)(xs)
#     187 ds /= np.max(ds) * 3
#     189 values = features[:, i]
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\scipy\stats\_kde.py:204, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     201 if not self.dataset.size > 1:
#     202     raise ValueError("`dataset` input should have multiple elements.")
# --> 204 self.d, self.n = self.dataset.shape
#     206 if weights is not None:
#     207     self._weights = atleast_1d(weights).astype(float)
#
# ValueError: too many values to unpack (expected 2)

# %%
"""
Simple dependence scatter plot
===============================

A dependence scatter plot shows the effect a single feature has on the predictions made by the model.

* Each dot is a single prediction (row) from the dataset.
* The x-axis is the value of the feature (from the X matrix, stored in explanation.data).
* The y-axis is the SHAP value for that feature (stored in explanation.values), which represents how much knowing 
that feature’s value changes the output of the model for that sample’s prediction. For this model the units are 
log-odds of making over 50k annually.
* The light grey area at the bottom of the plot is a histogram showing the distribution of data values.
"""

features = feature_names.copy()

# for feature in features:
#     shap.plots.scatter(
#         shap_values_1[:, feature],
#         # color=shap_values_1[:, "Zone Thermal Comfort Fanger Model PMV"]
#         )

# %%
# # for feature in features:
# features_copy = features.copy()
# features_copy.remove("Estado del actuador")
# for feature2 in features_copy:
#     shap.plots.scatter(
#         shap_values_1[:, "Estado del actuador"],
#         color=shap_values_1[:, feature2]
#         )

# %%
shap.plots.scatter(
    shap_values_1[:, "Energía para enfriamiento"],
    color=shap_values_1[:, "Temperatura de bulbo seco"]
    )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 2
#       1 shap.plots.scatter(
# ----> 2     shap_values_1[:, "Energía para enfriamiento"],
#       3     color=shap_values_1[:, "Temperatura de bulbo seco"]
#       4     )
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:417, in Explanation.__getitem__(self, item)
#     415 if new_self is None:
#     416     new_self = copy.copy(self)
# --> 417 new_self._s = new_self._s.__getitem__(item)
#     418 new_self.op_history.append(OpHistoryItem(name="__getitem__", args=(item,), prev_shape=self.shape))
#     420 return new_self
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer.py:112, in Slicer.__getitem__(self, item)
#     110 index_slicer = AtomicSlicer(index_tup, max_dim=1)
#     111 slicer_index = index_slicer[tracked.dim]
# --> 112 sliced_o = tracked[slicer_index]
#     113 sliced_dim = resolve_dim(index_tup, tracked.dim)
#     115 new_tracked = tracked.__class__(sliced_o, sliced_dim)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:589, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     586 tail_slice = cls.type_map[o_type].tail_slice
#     588 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
# --> 589 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     590 return out
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:439, in ArrayHandler.tail_slice(cls, o, tail_index, max_dim, flatten)
#     437         return AtomicSlicer(o, max_dim=max_dim)[tail_index]
#     438 else:
# --> 439     inner = [AtomicSlicer(e, max_dim=max_dim)[tail_index] for e in o]
#     440     if _safe_isinstance(o, "numpy", "ndarray"):
#     441         import numpy
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:439, in <listcomp>(.0)
#     437         return AtomicSlicer(o, max_dim=max_dim)[tail_index]
#     438 else:
# --> 439     inner = [AtomicSlicer(e, max_dim=max_dim)[tail_index] for e in o]
#     440     if _safe_isinstance(o, "numpy", "ndarray"):
#     441         import numpy
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:588, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     585 head_slice = cls.type_map[o_type].head_slice
#     586 tail_slice = cls.type_map[o_type].tail_slice
# --> 588 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
#     589 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     590 return out
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:418, in ArrayHandler.head_slice(cls, o, index_tup, max_dim)
#     416 cut_index = index_tup[:cut]
#     417 is_element = any([True if isinstance(x, int) else False for x in cut_index])
# --> 418 sliced_o = o[cut_index]
#     420 return is_element, sliced_o, cut
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
"""
Heatmap
========

Passing a matrix of SHAP values to the heatmap plot function creates a plot with the instances on the x-axis, 
the model inputs on the y-axis, and the SHAP values encoded on a color scale. By default the samples are ordered 
using shap.order.hclust, which orders the samples based on a hierarchical clustering by their explanation 
similarity. This results in samples that have the same model output for the same reason getting grouped together 
(such as people with a high impact from capital gain in the plot below).

The output of the model is shown above the heatmap matrix (centered around the explaination’s .base_value), and 
the global importance of each model input shown as a bar plot on the right hand side of the plot (by default this 
is the shap.order.abs.mean measure of overall importance).
"""
shap.plots.heatmap(shap_values_1, max_display=23)
# Out:
# <Axes: xlabel='Instances'>

# %%
# for i in range(len(background_data_np_sample)):
#     shap.initjs()
#     shap.force_plot(explainer.expected_value, shap_values[i], background_data_np_sample[i], matplotlib=True, show=True)

# for i in range(14):
#     shap.dependence_plot(i, shap_values, background_data_np_sample)

# %%
# Parameter importance

# import eli5
# from eli5.sklearn import PermutationImportance

# val_X = df["observations"][0:100]
# val_y = df["actions"][0:100]

# perm = PermutationImportance(model_predict, random_state=1).fit(val_X, val_y)
# eli5.show_weights(perm, feature_names = val_X.columns.tolist())
