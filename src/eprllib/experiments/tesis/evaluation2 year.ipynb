# %%
import os
os.environ['RAY_DEDUP_LOGS'] = '0'

import numpy as np
import shap
import matplotlib.pyplot as plt
import json

from tempfile import TemporaryDirectory
from typing import List, Dict

import ray
from ray.tune import register_env
from ray.rllib.algorithms.algorithm import Algorithm
from ray.rllib.policy.policy import Policy

from ray.rllib.models import ModelCatalog
from eprllib.examples.example_central_agent_files.policy_model import CustomTransformerModel
ModelCatalog.register_custom_model("custom_transformer", CustomTransformerModel)

from eprllib.Environment.Environment import Environment
from eprllib.Environment.EnvironmentConfig import EnvironmentConfig
from eprllib.Agents.Filters.DefaultFilter import DefaultFilter
from eprllib.Agents.Triggers.SetpointTriggers import DualSetpointTriggerDiscreteAndAvailabilityTrigger
# from eprllib.Agents.Rewards.EnergyAndAshrae55SimpleModel import EnergyAndASHRAE55SimpleModel
from eprllib.Agents.Rewards.NygardFerguson1990 import NygardFerguson1990_ended
from eprllib.AgentsConnectors.DefaultConnector import DefaultConnector

from eprllib.Agents.AgentSpec import (
    AgentSpec,
    ObservationSpec,
    RewardSpec,
    ActionSpec,
    TriggerSpec,
    FilterSpec
)
from eprllib.examples.example_thermostat_files.curriculum_learning import episode_fn
from eprllib.examples.example_thermostat_files.policy_mapping import policy_map_fn

from eprllib.PostProcess.Evaluation import generate_experience
from eprllib.AgentsConnectors.BaseConnector import BaseConnector

with open("C:/Users/grhen/Documents/GitHub2/eprllib/src/eprllib/examples/example_thermostat_files/curriculum_evaluation_year.json", "r") as f:
    episode_config = json.load(f)
# Out:
# WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %%
checkpoint_path = "C:/Users/grhen/ray_results/tesis/20251029120943-task2/PPO-4ca92_00000/checkpoint_000049"

# %%
"""
Esta configuración debe coincidir con la de entrenamiento.
"""
experiment_name:str = "tesis"
name:str = "task2"

eprllib_config = EnvironmentConfig()
eprllib_config.generals(
    epjson_path = "src/eprllib/examples/example_central_agent_files/model.epJSON",
    epw_path = "src/eprllib/examples/example_central_agent_files/weathers/ESP_PV_San.Sebastian-Igueldo.080270_TMYx.2004-2018.epw",
    output_path = TemporaryDirectory("output","",'C:/Users/grhen/Documents/Resultados_RLforEP').name,
    ep_terminal_output = False,
    timeout = 10,
    evaluation = False,
)
eprllib_config.connector(
    connector_fn = DefaultConnector,
    connector_fn_config = {},
)
eprllib_config.agents(
    agents_config = {
        "HVAC": AgentSpec(
            observation = ObservationSpec(
                variables = [
                    ("Site Outdoor Air Drybulb Temperature", "Environment"),
                    # ("Site Outdoor Air Relative Humidity", "Environment"),
                    ("Zone Mean Air Temperature", "Thermal Zone"),
                    # ("Zone Air Relative Humidity", "Thermal Zone"),
                    ("Zone People Occupant Count", "Thermal Zone"),
                    ("Zone Thermal Comfort Fanger Model PMV", "People")
                ],
                # simulation_parameters = {
                #     'hour': True,
                #     'day_of_week': True,
                #     'minutes': True,
                #     'day_of_year': True,
                #     # 'today_weather_horizontal_ir_at_time': True,
                # },
                meters = [
                    "Electricity:Building",
                    "Heating:DistrictHeatingWater",
                    "Cooling:DistrictCooling",
                ],
                use_actuator_state = True,
                use_one_day_weather_prediction = False,
                weather_prediction_hours = 3,
                prediction_variables = {
                    'outdoor_dry_bulb': True,
                },
                # internal_variables = [
                #     ("Zone Floor Area", "Thermal Zone"),
                # ],
                # history_len=6,
                user_occupation_funtion = False,
                user_type = "Office schedule",
                zone_type = "daytime",
                occupation_schedule = ("Schedule:Constant", "Schedule Value", "occupancy_schedule"),
                user_occupation_forecast = False,
                occupation_prediction_hours = 3,
                summer_months = [11, 12, 1, 2],
                # other_obs = {
                #     "war_north": 0,  # Window-to-wall ratio north
                #     "war_south": 0,  # Window-to-wall ratio south
                #     "war_east": 0,   # Window-to-wall ratio east
                #     "war_west": 0,   # Window-to-wall ratio west
                #     "latitude": 0,  # Latitude
                #     "longitude": 0,  # Longitude
                #     # "elevation": 0,  # Elevation
                #     # "time_zone": 0,  # Time zone
                # }
            ),
            action = ActionSpec(
                actuators = [
                    ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                ],
            ),
            filter= FilterSpec(
                filter_fn = DefaultFilter,
                filter_fn_config = {},
            ),
            trigger= TriggerSpec(
                trigger_fn = DualSetpointTriggerDiscreteAndAvailabilityTrigger,
                trigger_fn_config = {
                    'temperature_range': (17, 28),
                    "band_gap_range_len": 3,
                    "action_space_dim": 10,
                    'actuator_for_cooling': ("Schedule:Compact", "Schedule Value", "cooling_setpoint"),
                    'actuator_for_heating': ("Schedule:Compact", "Schedule Value", "heating_setpoint"),
                    'availability_actuator': ("Schedule:Constant", "Schedule Value", "HVAC_OnOff"),
                },
            ),
            reward = RewardSpec(
                reward_fn = NygardFerguson1990_ended,
                reward_fn_config = {
                    "thermal_zone": "Thermal Zone",
                    "C2": 6000,
                    'people_name': "People",
                    'cooling_name': "Cooling:DistrictCooling",
                    'heating_name': "Heating:DistrictHeatingWater",
                    'cooling_energy_ref': 0,
                    'heating_energy_ref': 0,
                },
            ),
        ),
    }
)

eprllib_config.episodes(
    episode_fn = episode_fn,
    episode_fn_config = episode_config,
    # cut_episode_len = 2
)

assert eprllib_config.agents_config is not None, "Agents configuration is not defined."

number_of_agents = len([keys for keys in eprllib_config.agents_config.keys()])
ray.init(_temp_dir='C:/Users/grhen/ray_results/tmp')
register_env(name="EPEnv", env_creator=lambda args: Environment(args))
env_config = eprllib_config.to_dict()

old_algo = Algorithm.from_checkpoint(checkpoint_path)
# Out:
# 2025-11-10 16:09:58,658	INFO worker.py:1918 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8266
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\algorithms\algorithm.py:520: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\tune\logger\unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# (pid=27172) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27172)
# (pid=27212) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27212)
# (pid=27200) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27200)
# (pid=27180) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27180)
# (pid=27248) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27248)
# (pid=27240) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27240)
# (pid=27232) WARNING:tensorflow:From c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\ray\rllib\utils\framework.py:186: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# (pid=27232)
# 2025-11-10 16:10:44,526	INFO trainable.py:161 -- Trainable.setup took 40.880 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2025-11-10 16:10:44,530	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
# ray.shutdown()

# %%
single_policy = old_algo.get_policy("single_policy")

# Generate experience
df = generate_experience(
    env = Environment,
    env_config = env_config,
    policies = {
        "HVAC": single_policy,
    },
    num_episodes = 1
)

old_algo.stop()
ray.shutdown()

# %%
feature_names: Dict[str, List[str]] = {agent: [] for agent in env_config["agents_config"].keys()}
feature_names_index: Dict[str, Dict[str, int]] = {agent: {} for agent in env_config["agents_config"].keys()}
connector_fn: BaseConnector = env_config['connector_fn'](env_config["connector_fn_config"])

for agent in env_config["agents_config"].keys():
    connector_fn.get_agent_obs_dim(env_config,agent)
    feature_names_index[agent] = connector_fn.get_agent_obs_indexed(env_config,agent)
    for key in feature_names_index[agent].keys():
        feature_names[agent].append(key)

for agent in feature_names.keys():
    if env_config["agents_config"][agent]["observation"]["history_len"] > 1:
        feature_names_h = feature_names[agent].copy()
        for h in range(env_config["agents_config"][agent]["observation"]["history_len"]):
            feature_names_h_new: List[str] = []
            for value in feature_names_h:
                feature_names_h_new.append(f"h{h}_{value}")
            feature_names[agent].extend(feature_names_h_new)

# %%
feature_names
# Out:
# {'HVAC': ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#   'HVAC: Zone Mean Air Temperature: Thermal Zone',
#   'HVAC: Zone People Occupant Count: Thermal Zone',
#   'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#   'HVAC: Electricity:Building',
#   'HVAC: Heating:DistrictHeatingWater',
#   'HVAC: Cooling:DistrictCooling',
#   'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#   'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#   'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']}

# %%
df
# Out:
# {'experiment': {'episode_1': {'timestep_1': {'HVAC': {'observation': array([28.633333, 25.      ,  1.      ,  0.      ,  0.      ,  0.      ,
#              0.      ,  0.      ,  0.      ,  0.      ], dtype=float32),
#      'action': None,
#      'reward': 0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_2': {'HVAC': {'observation': array([2.8633333e+01, 2.7707125e+01, 1.0000000e+00, 7.0432609e-01,
#             0.0000000e+00, 1.7497984e+05, 8.5098641e+04, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_3': {'HVAC': {'observation': array([2.8066668e+01, 2.7287518e+01, 1.0000000e+00, 6.8363523e-01,
#             0.0000000e+00, 0.0000000e+00, 2.0237269e+05, 2.5299999e+01,
#             2.7299999e+01, 1.0000000e+00], dtype=float32),
#      'action': array([2, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_4': {'HVAC': {'observation': array([27.5       , 27.40419   ,  1.        ,  0.72568226,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_5': {'HVAC': {'observation': array([26.933332 , 27.760355 ,  1.       ,  0.8040308,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_6': {'HVAC': {'observation': array([26.366667 , 27.867905 ,  1.       ,  0.8466062,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_7': {'HVAC': {'observation': array([25.8     , 27.705734,  1.      ,  0.840216,  0.      ,  0.      ,
#              0.      , 17.      , 28.      ,  0.      ], dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.000606501429606449),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_8': {'HVAC': {'observation': array([25.65      , 27.594667  ,  1.        ,  0.83359355,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_9': {'HVAC': {'observation': array([25.5      , 27.603888 ,  1.       ,  0.8394242,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_10': {'HVAC': {'observation': array([25.35     , 27.65604  ,  1.       ,  0.8498163,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_11': {'HVAC': {'observation': array([25.2       , 27.70035   ,  1.        ,  0.85822916,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_12': {'HVAC': {'observation': array([25.05      , 27.737236  ,  1.        ,  0.86531436,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_13': {'HVAC': {'observation': array([24.9       , 27.780293  ,  1.        ,  0.87329704,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.0007939407990477951),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_14': {'HVAC': {'observation': array([24.75     , 27.743523 ,  1.       ,  0.8684189,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_15': {'HVAC': {'observation': array([24.6       , 27.640125  ,  1.        ,  0.85131806,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_16': {'HVAC': {'observation': array([24.45     , 27.521757 ,  1.       ,  0.8297052,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_17': {'HVAC': {'observation': array([24.3      , 27.411938 ,  1.       ,  0.8078543,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_18': {'HVAC': {'observation': array([24.15      , 27.324621  ,  1.        ,  0.78884655,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_19': {'HVAC': {'observation': array([24.       , 27.305998 ,  1.       ,  0.7807021,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.0007163355462070846),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_20': {'HVAC': {'observation': array([23.916666 , 27.297411 ,  1.       ,  0.7755962,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_21': {'HVAC': {'observation': array([23.833334 , 27.279911 ,  1.       ,  0.7699471,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_22': {'HVAC': {'observation': array([23.75     , 27.269558 ,  1.       ,  0.7658927,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_23': {'HVAC': {'observation': array([23.666666 , 27.282299 ,  1.       ,  0.7658317,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_24': {'HVAC': {'observation': array([23.583334 , 27.326227 ,  1.       ,  0.7711678,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_25': {'HVAC': {'observation': array([23.5       , 27.411978  ,  1.        ,  0.78376585,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.0006035960071819178),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_26': {'HVAC': {'observation': array([23.416666 , 27.456821 ,  1.       ,  0.7906788,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_27': {'HVAC': {'observation': array([23.333334 , 27.4613   ,  1.       ,  0.7910297,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_28': {'HVAC': {'observation': array([23.25      , 27.459938  ,  1.        ,  0.78987825,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_29': {'HVAC': {'observation': array([23.166666 , 27.469587 ,  1.       ,  0.7901138,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_30': {'HVAC': {'observation': array([23.083334  , 27.488327  ,  1.        ,  0.79174113,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_31': {'HVAC': {'observation': array([23.       , 27.511097 ,  1.       ,  0.7941103,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.0006444952284377534),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_32': {'HVAC': {'observation': array([22.933332 , 27.447227 ,  1.       ,  0.7832486,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_33': {'HVAC': {'observation': array([22.866667 , 27.319763 ,  1.       ,  0.7617443,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_34': {'HVAC': {'observation': array([22.8      , 27.184652 ,  1.       ,  0.7382358,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_35': {'HVAC': {'observation': array([22.733334  , 27.062435  ,  1.        ,  0.71650165,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_36': {'HVAC': {'observation': array([22.666666 , 26.94631  ,  1.       ,  0.6960662,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_37': {'HVAC': {'observation': array([22.6      , 26.828377 ,  1.       ,  0.6757535,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.0005222104965456934),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_38': {'HVAC': {'observation': array([2.2600000e+01, 2.6899984e+01, 1.0000000e+00, 2.6671356e-01,
#             0.0000000e+00, 1.1157386e+03, 0.0000000e+00, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_39': {'HVAC': {'observation': array([2.2600000e+01, 2.6801081e+01, 1.0000000e+00, 2.4487679e-01,
#             0.0000000e+00, 0.0000000e+00, 1.0387868e+05, 2.5799999e+01,
#             2.6799999e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_40': {'HVAC': {'observation': array([22.6       , 27.152214  ,  1.        ,  0.30451974,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_41': {'HVAC': {'observation': array([22.6       , 27.603046  ,  1.        ,  0.39404318,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_42': {'HVAC': {'observation': array([22.6       , 27.840807  ,  1.        ,  0.46793643,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_43': {'HVAC': {'observation': array([22.6      , 27.753101 ,  1.       ,  0.4679422,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.00010989019757321863),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_44': {'HVAC': {'observation': array([2.2883333e+01, 2.7899971e+01, 1.0000000e+00, 5.0645977e-01,
#             0.0000000e+00, 0.0000000e+00, 1.5913284e+03, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_45': {'HVAC': {'observation': array([23.166666 , 27.721367 ,  1.       ,  0.4811037,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_46': {'HVAC': {'observation': array([23.45      , 27.32658   ,  1.        ,  0.41199428,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_47': {'HVAC': {'observation': array([2.3733334e+01, 2.6949200e+01, 1.0000000e+00, 3.3310503e-01,
#             0.0000000e+00, 1.4188175e+03, 0.0000000e+00, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_48': {'HVAC': {'observation': array([24.016666  , 26.727303  ,  1.        ,  0.28372923,  0.        ,
#              0.        ,  0.        , 25.8       , 26.8       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_49': {'HVAC': {'observation': array([24.3       , 26.639326  ,  1.        ,  0.26212916,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.00012467739517313454),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_50': {'HVAC': {'observation': array([2.4683332e+01, 2.6898438e+01, 1.0000000e+00, 3.0736977e-01,
#             0.0000000e+00, 4.1100480e+04, 0.0000000e+00, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_51': {'HVAC': {'observation': array([2.5066668e+01, 2.6800816e+01, 1.0000000e+00, 2.9157087e-01,
#             0.0000000e+00, 0.0000000e+00, 9.9380492e+04, 2.5799999e+01,
#             2.6799999e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_52': {'HVAC': {'observation': array([25.45      , 27.00735   ,  1.        ,  0.32959327,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_53': {'HVAC': {'observation': array([25.833334 , 27.27727  ,  1.       ,  0.3812932,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_54': {'HVAC': {'observation': array([26.216667  , 27.466614  ,  1.        ,  0.41999367,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_55': {'HVAC': {'observation': array([26.6       , 27.613607  ,  1.        ,  0.44859233,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': np.float64(-0.00010799527465211964),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_56': {'HVAC': {'observation': array([27.016666  , 27.658838  ,  1.        ,  0.45986208,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_57': {'HVAC': {'observation': array([27.433332 , 27.760067 ,  1.       ,  0.4787122,  0.       ,
#              0.       ,  0.       , 17.       , 28.       ,  0.       ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_58': {'HVAC': {'observation': array([2.7850000e+01, 2.7899599e+01, 1.0000000e+00, 5.0768077e-01,
#             0.0000000e+00, 0.0000000e+00, 5.1059574e+04, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_59': {'HVAC': {'observation': array([2.8266666e+01, 2.7899996e+01, 1.0000000e+00, 5.0770038e-01,
#             0.0000000e+00, 0.0000000e+00, 2.4933281e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_60': {'HVAC': {'observation': array([2.8683332e+01, 2.7900000e+01, 1.0000000e+00, 5.0640255e-01,
#             0.0000000e+00, 0.0000000e+00, 4.2752091e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_61': {'HVAC': {'observation': array([2.9100000e+01, 2.7900000e+01, 1.0000000e+00, 5.0538719e-01,
#             0.0000000e+00, 0.0000000e+00, 5.9692425e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.000205570732203809),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_62': {'HVAC': {'observation': array([2.9516666e+01, 2.7900000e+01, 1.0000000e+00, 4.9897677e-01,
#             0.0000000e+00, 0.0000000e+00, 8.4039525e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_63': {'HVAC': {'observation': array([2.9933332e+01, 2.7900000e+01, 1.0000000e+00, 4.8821703e-01,
#             0.0000000e+00, 0.0000000e+00, 1.0884974e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_64': {'HVAC': {'observation': array([3.0350000e+01, 2.7900000e+01, 1.0000000e+00, 4.7800979e-01,
#             0.0000000e+00, 0.0000000e+00, 1.3334844e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_65': {'HVAC': {'observation': array([3.0766666e+01, 2.7900000e+01, 1.0000000e+00, 4.6830434e-01,
#             0.0000000e+00, 0.0000000e+00, 1.5070244e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_66': {'HVAC': {'observation': array([3.1183332e+01, 2.7900000e+01, 1.0000000e+00, 4.5837596e-01,
#             0.0000000e+00, 0.0000000e+00, 1.6189121e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_67': {'HVAC': {'observation': array([3.1600000e+01, 2.7900000e+01, 1.0000000e+00, 4.4812921e-01,
#             0.0000000e+00, 0.0000000e+00, 1.7083765e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00018724075209063242),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_68': {'HVAC': {'observation': array([3.1983334e+01, 2.7900000e+01, 1.0000000e+00, 4.4605353e-01,
#             0.0000000e+00, 0.0000000e+00, 1.8200359e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_69': {'HVAC': {'observation': array([3.2366665e+01, 2.7900000e+01, 1.0000000e+00, 4.4870573e-01,
#             0.0000000e+00, 0.0000000e+00, 1.8062219e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_70': {'HVAC': {'observation': array([3.2750000e+01, 2.7900000e+01, 1.0000000e+00, 4.4887850e-01,
#             0.0000000e+00, 0.0000000e+00, 1.6183209e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_71': {'HVAC': {'observation': array([3.3133335e+01, 2.7900000e+01, 1.0000000e+00, 4.4933054e-01,
#             0.0000000e+00, 0.0000000e+00, 1.3327950e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_72': {'HVAC': {'observation': array([3.3516666e+01, 2.7900000e+01, 1.0000000e+00, 4.4983962e-01,
#             0.0000000e+00, 0.0000000e+00, 8.9604112e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_73': {'HVAC': {'observation': array([3.3900002e+01, 2.7900000e+01, 1.0000000e+00, 4.5119852e-01,
#             0.0000000e+00, 0.0000000e+00, 3.7206734e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00016625365703935188),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_74': {'HVAC': {'observation': array([3.4216667e+01, 2.7900000e+01, 1.0000000e+00, 4.5385137e-01,
#             0.0000000e+00, 0.0000000e+00, 9.4643806e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_75': {'HVAC': {'observation': array([3.4533333e+01, 2.7900000e+01, 1.0000000e+00, 4.5615339e-01,
#             0.0000000e+00, 0.0000000e+00, 1.6469769e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_76': {'HVAC': {'observation': array([3.4849998e+01, 2.8927214e+01, 1.0000000e+00, 6.4193922e-01,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_77': {'HVAC': {'observation': array([3.5166668e+01, 3.0147568e+01, 1.0000000e+00, 8.8100958e-01,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_78': {'HVAC': {'observation': array([3.5483334e+01, 3.1011820e+01, 1.0000000e+00, 1.0574404e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_79': {'HVAC': {'observation': array([3.5799999e+01, 3.1478722e+01, 1.0000000e+00, 1.1600908e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.0008704735873256124),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_80': {'HVAC': {'observation': array([3.6066666e+01, 3.1810482e+01, 1.0000000e+00, 1.2322795e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_81': {'HVAC': {'observation': array([3.6333332e+01, 3.2140099e+01, 1.0000000e+00, 1.3030549e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_82': {'HVAC': {'observation': array([3.6599998e+01, 3.2460724e+01, 1.0000000e+00, 1.3724016e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_83': {'HVAC': {'observation': array([3.6866665e+01, 3.2787697e+01, 1.0000000e+00, 1.4428443e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_84': {'HVAC': {'observation': array([3.7133335e+01, 3.3124416e+01, 1.0000000e+00, 1.5152932e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_85': {'HVAC': {'observation': array([3.7400002e+01, 3.3457935e+01, 1.0000000e+00, 1.5875793e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.005060749257777842),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_86': {'HVAC': {'observation': array([3.7583332e+01, 3.3443130e+01, 1.0000000e+00, 1.5977713e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_87': {'HVAC': {'observation': array([3.7766666e+01, 3.3359261e+01, 1.0000000e+00, 1.5894220e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_88': {'HVAC': {'observation': array([3.7950001e+01, 3.3292305e+01, 1.0000000e+00, 1.5827866e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_89': {'HVAC': {'observation': array([3.8133335e+01, 3.3220619e+01, 1.0000000e+00, 1.5742720e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_90': {'HVAC': {'observation': array([3.8316666e+01, 3.3128628e+01, 1.0000000e+00, 1.5616128e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_91': {'HVAC': {'observation': array([3.8500000e+01, 3.3016079e+01, 1.0000000e+00, 1.5441769e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00812618029379997),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_92': {'HVAC': {'observation': array([3.8599998e+01, 3.3342438e+01, 1.0000000e+00, 1.6072086e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_93': {'HVAC': {'observation': array([3.8700001e+01, 3.3373882e+01, 1.0000000e+00, 1.6244719e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_94': {'HVAC': {'observation': array([3.8799999e+01, 3.3217392e+01, 1.0000000e+00, 1.6011213e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_95': {'HVAC': {'observation': array([3.8900002e+01, 3.2891357e+01, 1.0000000e+00, 1.5435094e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_96': {'HVAC': {'observation': array([3.9000000e+01, 3.2208961e+01, 1.0000000e+00, 1.4160624e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_97': {'HVAC': {'observation': array([3.9099998e+01, 3.0548197e+01, 1.0000000e+00, 1.1004481e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.006892589242278217),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_98': {'HVAC': {'observation': array([3.9133335e+01, 3.4085865e+01, 1.0000000e+00, 1.7276233e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_99': {'HVAC': {'observation': array([3.9166668e+01, 3.4682140e+01, 1.0000000e+00, 1.9019313e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_100': {'HVAC': {'observation': array([3.9200001e+01, 3.4552940e+01, 1.0000000e+00, 1.8885996e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_101': {'HVAC': {'observation': array([3.9233334e+01, 3.4442543e+01, 1.0000000e+00, 1.8742825e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_102': {'HVAC': {'observation': array([3.9266666e+01, 3.4346142e+01, 1.0000000e+00, 1.8623019e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_103': {'HVAC': {'observation': array([3.9299999e+01, 3.4079113e+01, 1.0000000e+00, 1.8188586e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.022141685805219698),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_104': {'HVAC': {'observation': array([3.9233334e+01, 3.4060139e+01, 1.0000000e+00, 1.8164642e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_105': {'HVAC': {'observation': array([3.9166668e+01, 3.3972000e+01, 1.0000000e+00, 1.8045470e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_106': {'HVAC': {'observation': array([3.9099998e+01, 3.3833637e+01, 1.0000000e+00, 1.7827628e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_107': {'HVAC': {'observation': array([3.9033333e+01, 3.3732758e+01, 1.0000000e+00, 1.7671218e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_108': {'HVAC': {'observation': array([3.8966667e+01, 3.3648540e+01, 1.0000000e+00, 1.7550075e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_109': {'HVAC': {'observation': array([3.8900002e+01, 3.3229195e+01, 1.0000000e+00, 1.6815223e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.01634658930096755),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_110': {'HVAC': {'observation': array([3.8733334e+01, 3.2954437e+01, 1.0000000e+00, 1.6264153e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_111': {'HVAC': {'observation': array([3.8566666e+01, 3.2690990e+01, 1.0000000e+00, 1.5770364e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_112': {'HVAC': {'observation': array([3.8400002e+01, 3.2259254e+01, 1.0000000e+00, 1.4959607e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_113': {'HVAC': {'observation': array([3.8233334e+01, 3.1733448e+01, 1.0000000e+00, 1.3922356e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_114': {'HVAC': {'observation': array([3.8066666e+01, 3.1129601e+01, 1.0000000e+00, 1.2728950e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_115': {'HVAC': {'observation': array([3.7900002e+01, 3.0413710e+01, 1.0000000e+00, 1.1315476e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.005565911325174045),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_116': {'HVAC': {'observation': array([3.7633335e+01, 2.9962408e+01, 1.0000000e+00, 1.0388663e+00,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_117': {'HVAC': {'observation': array([3.7366665e+01, 2.9582441e+01, 1.0000000e+00, 9.6458817e-01,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_118': {'HVAC': {'observation': array([3.7099998e+01, 2.9158709e+01, 1.0000000e+00, 8.8417256e-01,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_119': {'HVAC': {'observation': array([3.6833332e+01, 2.8450321e+01, 1.0000000e+00, 7.4915105e-01,
#             0.0000000e+00, 0.0000000e+00, 1.9200000e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_120': {'HVAC': {'observation': array([3.6566666e+01, 2.7930149e+01, 1.0000000e+00, 6.4692289e-01,
#             0.0000000e+00, 0.0000000e+00, 1.8348534e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_121': {'HVAC': {'observation': array([3.6299999e+01, 2.7900589e+01, 1.0000000e+00, 6.3447267e-01,
#             0.0000000e+00, 0.0000000e+00, 1.6700885e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.0007950099675982185),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_122': {'HVAC': {'observation': array([3.5983334e+01, 2.7900066e+01, 1.0000000e+00, 6.2490952e-01,
#             0.0000000e+00, 0.0000000e+00, 1.6168004e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_123': {'HVAC': {'observation': array([3.5666668e+01, 2.7900007e+01, 1.0000000e+00, 6.1408532e-01,
#             0.0000000e+00, 0.0000000e+00, 1.5073421e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_124': {'HVAC': {'observation': array([3.5349998e+01, 2.7900002e+01, 1.0000000e+00, 5.9792745e-01,
#             0.0000000e+00, 0.0000000e+00, 1.3587114e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_125': {'HVAC': {'observation': array([3.5033333e+01, 2.7900000e+01, 1.0000000e+00, 5.9443891e-01,
#             0.0000000e+00, 0.0000000e+00, 1.2282282e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_126': {'HVAC': {'observation': array([3.4716667e+01, 2.7900000e+01, 1.0000000e+00, 5.9024423e-01,
#             0.0000000e+00, 0.0000000e+00, 1.1054534e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_127': {'HVAC': {'observation': array([3.4400002e+01, 2.7900000e+01, 1.0000000e+00, 5.8741617e-01,
#             0.0000000e+00, 0.0000000e+00, 9.9011925e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00032399485859678143),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_128': {'HVAC': {'observation': array([3.410000e+01, 2.790000e+01, 1.000000e+00, 5.882702e-01,
#             0.000000e+00, 0.000000e+00, 9.822292e+05, 2.690000e+01,
#             2.790000e+01, 1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_129': {'HVAC': {'observation': array([3.3799999e+01, 2.7900000e+01, 1.0000000e+00, 5.9144378e-01,
#             0.0000000e+00, 0.0000000e+00, 8.8107356e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_130': {'HVAC': {'observation': array([3.3500000e+01, 2.7900000e+01, 1.0000000e+00, 5.9463346e-01,
#             0.0000000e+00, 0.0000000e+00, 7.4931562e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_131': {'HVAC': {'observation': array([3.3200001e+01, 2.7900000e+01, 1.0000000e+00, 5.9712076e-01,
#             0.0000000e+00, 0.0000000e+00, 6.2773719e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_132': {'HVAC': {'observation': array([3.290000e+01, 2.790000e+01, 1.000000e+00, 5.986993e-01,
#             0.000000e+00, 0.000000e+00, 5.163615e+05, 2.690000e+01,
#             2.790000e+01, 1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_133': {'HVAC': {'observation': array([3.260000e+01, 2.790000e+01, 1.000000e+00, 5.995643e-01,
# ...
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_958': {'HVAC': {'observation': array([3.1650000e+01, 2.7900000e+01, 1.0000000e+00, 4.9934456e-01,
#             0.0000000e+00, 0.0000000e+00, 9.4837312e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_959': {'HVAC': {'observation': array([3.1733334e+01, 2.7900000e+01, 1.0000000e+00, 4.9696422e-01,
#             0.0000000e+00, 0.0000000e+00, 9.7355275e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_960': {'HVAC': {'observation': array([3.1816668e+01, 2.7900000e+01, 1.0000000e+00, 4.9461284e-01,
#             0.0000000e+00, 0.0000000e+00, 9.6419706e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_961': {'HVAC': {'observation': array([3.1900000e+01, 2.7900000e+01, 1.0000000e+00, 4.9337044e-01,
#             0.0000000e+00, 0.0000000e+00, 9.2577931e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00020913731515392),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_962': {'HVAC': {'observation': array([3.1883333e+01, 2.7900000e+01, 1.0000000e+00, 4.9372354e-01,
#             0.0000000e+00, 0.0000000e+00, 9.1188706e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_963': {'HVAC': {'observation': array([3.1866667e+01, 2.7900000e+01, 1.0000000e+00, 4.9562964e-01,
#             0.0000000e+00, 0.0000000e+00, 8.9318744e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_964': {'HVAC': {'observation': array([3.185000e+01, 2.790000e+01, 1.000000e+00, 4.977446e-01,
#             0.000000e+00, 0.000000e+00, 8.672322e+05, 2.690000e+01,
#             2.790000e+01, 1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_965': {'HVAC': {'observation': array([3.1833334e+01, 2.7900000e+01, 1.0000000e+00, 4.9993607e-01,
#             0.0000000e+00, 0.0000000e+00, 8.3094619e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_966': {'HVAC': {'observation': array([3.1816668e+01, 2.7900000e+01, 1.0000000e+00, 5.0093633e-01,
#             0.0000000e+00, 0.0000000e+00, 7.8090669e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_967': {'HVAC': {'observation': array([3.1799999e+01, 2.7900000e+01, 1.0000000e+00, 5.0180101e-01,
#             0.0000000e+00, 0.0000000e+00, 7.1572175e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.0002092657824622765),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_968': {'HVAC': {'observation': array([3.1683332e+01, 2.7900000e+01, 1.0000000e+00, 5.0542814e-01,
#             0.0000000e+00, 0.0000000e+00, 7.3318106e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_969': {'HVAC': {'observation': array([3.1566668e+01, 2.7900000e+01, 1.0000000e+00, 5.1103336e-01,
#             0.0000000e+00, 0.0000000e+00, 7.5248350e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_970': {'HVAC': {'observation': array([3.145000e+01, 2.790000e+01, 1.000000e+00, 5.170235e-01,
#             0.000000e+00, 0.000000e+00, 7.726457e+05, 2.690000e+01,
#             2.790000e+01, 1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_971': {'HVAC': {'observation': array([3.1333334e+01, 2.7900000e+01, 1.0000000e+00, 5.2210003e-01,
#             0.0000000e+00, 0.0000000e+00, 7.9123781e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_972': {'HVAC': {'observation': array([3.1216667e+01, 2.7900000e+01, 1.0000000e+00, 5.2690655e-01,
#             0.0000000e+00, 0.0000000e+00, 8.0791156e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_973': {'HVAC': {'observation': array([3.1100000e+01, 2.7900000e+01, 1.0000000e+00, 5.3068024e-01,
#             0.0000000e+00, 0.0000000e+00, 8.2198769e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00022940124221201586),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_974': {'HVAC': {'observation': array([3.0900000e+01, 2.7900000e+01, 1.0000000e+00, 5.3658557e-01,
#             0.0000000e+00, 0.0000000e+00, 8.9837562e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_975': {'HVAC': {'observation': array([3.070000e+01, 2.790000e+01, 1.000000e+00, 5.431255e-01,
#             0.000000e+00, 0.000000e+00, 9.548589e+05, 2.690000e+01,
#             2.790000e+01, 1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_976': {'HVAC': {'observation': array([3.0500000e+01, 2.7900000e+01, 1.0000000e+00, 5.4935491e-01,
#             0.0000000e+00, 0.0000000e+00, 9.9300756e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_977': {'HVAC': {'observation': array([3.02999992e+01, 2.78999996e+01, 1.00000000e+00, 5.55140316e-01,
#             0.00000000e+00, 0.00000000e+00, 1.01311875e+06, 2.68999996e+01,
#             2.78999996e+01, 1.00000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_978': {'HVAC': {'observation': array([3.0100000e+01, 2.7900000e+01, 1.0000000e+00, 5.6047958e-01,
#             0.0000000e+00, 0.0000000e+00, 1.0066232e+06, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_979': {'HVAC': {'observation': array([2.990000e+01, 2.790000e+01, 1.000000e+00, 5.653533e-01,
#             0.000000e+00, 0.000000e+00, 9.353439e+05, 2.690000e+01,
#             2.790000e+01, 1.000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00026421748750090544),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_980': {'HVAC': {'observation': array([2.9666666e+01, 2.7900000e+01, 1.0000000e+00, 5.6539571e-01,
#             0.0000000e+00, 0.0000000e+00, 8.1754212e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_981': {'HVAC': {'observation': array([2.9433332e+01, 2.7900000e+01, 1.0000000e+00, 5.6312811e-01,
#             0.0000000e+00, 0.0000000e+00, 6.4177844e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_982': {'HVAC': {'observation': array([2.9200001e+01, 2.7900000e+01, 1.0000000e+00, 5.5924171e-01,
#             0.0000000e+00, 0.0000000e+00, 4.8003772e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_983': {'HVAC': {'observation': array([2.8966667e+01, 2.7900000e+01, 1.0000000e+00, 5.5709231e-01,
#             0.0000000e+00, 0.0000000e+00, 3.3829369e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_984': {'HVAC': {'observation': array([2.8733334e+01, 2.7900000e+01, 1.0000000e+00, 5.5473155e-01,
#             0.0000000e+00, 0.0000000e+00, 2.1688648e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_985': {'HVAC': {'observation': array([2.8500000e+01, 2.7900000e+01, 1.0000000e+00, 5.5193120e-01,
#             0.0000000e+00, 0.0000000e+00, 1.1596571e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.0002714902989766194),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_986': {'HVAC': {'observation': array([2.8250000e+01, 2.7900000e+01, 1.0000000e+00, 5.4838926e-01,
#             0.0000000e+00, 0.0000000e+00, 1.2338860e+05, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_987': {'HVAC': {'observation': array([2.8000000e+01, 2.7900000e+01, 1.0000000e+00, 5.4676300e-01,
#             0.0000000e+00, 0.0000000e+00, 7.5752766e+04, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_988': {'HVAC': {'observation': array([2.7750000e+01, 2.7900000e+01, 1.0000000e+00, 5.4535484e-01,
#             0.0000000e+00, 0.0000000e+00, 4.3512500e+03, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_989': {'HVAC': {'observation': array([27.5       , 27.781086  ,  1.        ,  0.52358806,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_990': {'HVAC': {'observation': array([27.25      , 27.628176  ,  1.        ,  0.49427548,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_991': {'HVAC': {'observation': array([27.      , 27.507292,  1.      ,  0.4697  ,  0.      ,  0.      ,
#              0.      , 26.9     , 27.9     ,  1.      ], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00023263441261358445),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_992': {'HVAC': {'observation': array([26.833334  , 27.411484  ,  1.        ,  0.45383778,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_993': {'HVAC': {'observation': array([26.666666  , 27.316698  ,  1.        ,  0.44078845,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_994': {'HVAC': {'observation': array([26.5       , 27.2178    ,  1.        ,  0.42755422,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_995': {'HVAC': {'observation': array([26.333334 , 27.116388 ,  1.       ,  0.4132071,  0.       ,
#              0.       ,  0.       , 26.9      , 27.9      ,  1.       ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_996': {'HVAC': {'observation': array([26.166666  , 27.014809  ,  1.        ,  0.40009394,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_997': {'HVAC': {'observation': array([26.        , 26.913994  ,  1.        ,  0.38553286,  0.        ,
#              0.        ,  0.        , 26.9       , 27.9       ,  1.        ],
#            dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': np.float64(-0.00014363930556759034),
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_998': {'HVAC': {'observation': array([25.833334  , 26.84539   ,  1.        ,  0.37287304,  0.        ,
#              0.        ,  0.        , 17.        , 28.        ,  0.        ],
#            dtype=float32),
#      'action': array([0, 3], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_999': {'HVAC': {'observation': array([2.5666666e+01, 2.6899755e+01, 1.0000000e+00, 3.7964681e-01,
#             0.0000000e+00, 3.3058070e+04, 0.0000000e+00, 2.6900000e+01,
#             2.7900000e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 9], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    'timestep_1000': {'HVAC': {'observation': array([2.5500000e+01, 2.6800005e+01, 1.0000000e+00, 3.6014065e-01,
#             0.0000000e+00, 0.0000000e+00, 8.3695648e+02, 2.5799999e+01,
#             2.6799999e+01, 1.0000000e+00], dtype=float32),
#      'action': array([1, 8], dtype=int32),
#      'reward': 0.0,
#      'done': False,
#      'truncated': False,
#      'info': {}}},
#    ...}}}

# %%
# for agent in feature_names_index.keys():
#     energy_total: List[float] = []
#     for timestep in range(1,len(df["experiment"]["episode_1"])):
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]])
#         energy_total.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Cooling:DistrictCooling"]])
#     print(sum(energy_total)/3600000)

# %%
for agent in feature_names_index.keys():
    action_list_1: List[float] = []
    action_list_2: List[float] = []
    av_list: List[int] = []
    t_r_list: List[float] = []
    t_c_list: List[float] = []
    t_i_list: List[float] = []
    occ_list: List[float] = []
    t_out_list: List[float] = []
    energy_list: List[float] = []
    pmv_list: List[float] = []
    pmv_hist: List[float] = []
    for timestep in range(1,len(df["experiment"]["episode_1"])):
        if env_config["agents_config"][agent]["observation"]["history_len"] > 1:
            t_i_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Mean Air Temperature: Thermal Zone"]])
            t_out_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Site Outdoor Air Drybulb Temperature: Environment"]])
            energy_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]]/3600000)
            occ_t = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone People Occupant Count: Thermal Zone"]]
            if occ_t > 0:
                occ_list.append(occ_t)
                pmv_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
                pmv_hist.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][0][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
            else:
                occ_list.append(0)
                pmv_list.append(0)
        
        else:
            t_i_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Mean Air Temperature: Thermal Zone"]])
            t_out_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Site Outdoor Air Drybulb Temperature: Environment"]])
            energy_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Heating:DistrictHeatingWater"]]/3600000)
            occ_t = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone People Occupant Count: Thermal Zone"]]
            if occ_t > 0:
                occ_list.append(occ_t)
                pmv_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
                pmv_hist.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"][feature_names_index[agent][f"{agent}: Zone Thermal Comfort Fanger Model PMV: People"]])
            else:
                occ_list.append(0)
                pmv_list.append(0)
        
        
        if df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"] is None:
            pass
        else:
            a1 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][0]
            a2 = df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["action"][1]
            action_list_1.append(a1)
            action_list_2.append(a2)
            temp_range = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["temperature_range"]
            action_range: int = env_config["agents_config"][agent]["trigger"]["trigger_fn_config"]["action_space_dim"]
            if a1 > 0:
                t_r_list.append(min(temp_range)+((a2/action_range)*(max(temp_range)-min(temp_range)))+(a1-1)/2 + 1)
                t_c_list.append(min(temp_range)+((a2/action_range)*(max(temp_range)-min(temp_range)))-(a1-1)/2)
                av_list.append(a1)
            else:
                t_r_list.append(0)
                t_c_list.append(0)
                av_list.append(0)

# %%
for agent in feature_names_index.keys():
    # 1. Time series plot
    plt.figure(figsize=(7, 5))
    plt.subplot(2, 1, 1)
    plt.plot(t_r_list, label='Tr', color='blue', alpha=0.6)
    plt.plot(t_c_list, label='Tc', color='red', alpha=0.6)
    plt.plot(t_i_list, label='Ti', color='green', alpha=0.6)
    plt.plot(t_out_list, label='To', color='black', alpha=0.6)
    plt.ylabel('Temperatura, °C')
    plt.grid(True, alpha=0.3)
    plt.legend(loc='upper left', bbox_to_anchor=(-0.37, 1), fontsize=9)
    
    plt.subplot(2, 1, 2)
    # plt.plot(av_list, label='Disponibilidad', color='red', alpha=0.6)
    plt.plot(occ_list, label='Ocupación', color='blue', alpha=0.6)
    plt.plot(pmv_list, label='PMV', color='green', alpha=0.6)
    plt.plot(energy_list, label='Energía', color='purple', alpha=0.6)
    plt.legend(loc='upper left', bbox_to_anchor=(-0.37, 1), fontsize=9)
    plt.xlabel('Paso de tiempo')
    plt.ylabel('Energía, kWh | adim')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
for agent in feature_names_index.keys():
    # 2. Histogram
    plt.figure(figsize=(7, 5))
    plt.hist(action_list_2, bins=11, color='skyblue', edgecolor='black')
    plt.hist(action_list_1, bins=11, color='lightgreen', edgecolor='black')
    plt.xlabel('Valor de la action')
    plt.xlim((0, 10))
    plt.ylabel('Frecuencia')
    # plt.ylim((0, 1))
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
for agent in feature_names_index.keys():
    # 3. PMV histogram plot    
    plt.figure(figsize=(7, 5))
    plt.hist(pmv_hist, bins=100, color='lightgreen', edgecolor='black')
    plt.xlabel('PMV Value')
    plt.xlim((-3, 3))
    plt.ylim((0, 6000))
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# Basic statistical analysis
for agent in feature_names_index.keys():
    print(f"\nStatistical Summary ({agent}):")
    print(f"Mean: {np.mean(action_list_1):.2f}")
    print(f"Median: {np.median(action_list_1):.2f}")
    print(f"Std Dev: {np.std(action_list_1):.2f}")
    print(f"Min: {np.min(action_list_1):.2f}")
    print(f"Max: {np.max(action_list_1):.2f}")
    print(f"Mean: {np.mean(action_list_2):.2f}")
    print(f"Median: {np.median(action_list_2):.2f}")
    print(f"Std Dev: {np.std(action_list_2):.2f}")
    print(f"Min: {np.min(action_list_2):.2f}")
    print(f"Max: {np.max(action_list_2):.2f}")
    print(f"Total Energy Consumption (kWh): {sum(energy_list):.2f}")
# Out:
# Statistical Summary (HVAC):
# Mean: 0.98
# Median: 1.00
# Std Dev: 0.33
# Min: 0.00
# Max: 3.00
# Mean: 7.90
# Median: 8.00
# Std Dev: 1.20
# Min: 0.00
# Max: 9.00
# Total Energy Consumption (kWh): 9088.76

# %%
obs: List[float|int] = [-3,-2,-1,0,1,2,3]
rew: List[float] = []
for _ in range(len(obs)):
    rew.append(-(np.exp(obs[_]**2) - 1.0)/(np.exp(3**2)-1))
    
print(rew)
# Out:
# [np.float64(-1.0), np.float64(-0.006615353594489847), np.float64(-0.00021207899644323422), np.float64(-0.0), np.float64(-0.00021207899644323422), np.float64(-0.006615353594489847), np.float64(-1.0)]

# %%
norm_energy: List[float] = [1.0,0.75,0.5,0.25,0.0]
c: float = 6000 / (60/6) * (np.exp(3**2)-1)

rew_e: List[float] = []
for _ in range(len(norm_energy)):
    rew_e.append(-norm_energy[_] * (1 / c))
    
print(rew_e)
# Out:
# [np.float64(-2.0570839324364178e-07), np.float64(-1.5428129493273133e-07), np.float64(-1.0285419662182089e-07), np.float64(-5.1427098310910444e-08), np.float64(-0.0)]

# %%
labelsize = 14
time_steps = np.arange(len(action_list_2))
time_steps_1 = np.arange(len(action_list_2)+1)
# --- Creación de la figura y subgráficas ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14.5, 6))
# fig.suptitle('Análisis de Control y Ocupación', fontsize=18, fontweight='bold', y=1.02)

# --- Subgráfica 1: Gráfico de series de tiempo ---
# Determinar y aplicar el color de fondo basado en la ocupación
is_occupied = False
start_occupancy = 0
for i, occ in enumerate(occ_list):
    if occ > 0 and not is_occupied:
        is_occupied = True
        start_occupancy = i
    elif occ == 0 and is_occupied:
        is_occupied = False
        end_occupancy = i
        # Usar axvspan para crear la región sombreada.
        # El color semi-transparente ayuda a ver las líneas del grid.
        ax1.axvspan(start_occupancy, end_occupancy, color='#ADD8E6', alpha=0.3, label='Ocupado' if start_occupancy == 0 else "")

# Dibujar las líneas de las series de tiempo sobre el fondo
ax1.plot(time_steps, t_r_list, label='Temp. Refri.', color='#1f77b4', linewidth=2, linestyle='--')
ax1.plot(time_steps, t_c_list, label='Temp. Calef.', color='#1f77b4', linewidth=2, linestyle=':')
ax1.plot(time_steps_1, t_i_list, label='Temp. Interna', color='#d62728', linestyle='--')
ax1.plot(time_steps_1, t_out_list, label='Temp. Externa', color='#2ca02c', linestyle='--')

# ax1.set_title('Valores de Control y Temperaturas', fontsize=14)
ax1.set_xlabel('Paso de Tiempo', fontsize=labelsize)
ax1.set_ylabel('Valor', fontsize=12)
ax1.tick_params(axis='both', which='major', labelsize=labelsize)
ax1.grid(True, linestyle='--', alpha=0.6)
# ax1.legend(loc='upper right')
ax1.legend(loc='upper left', bbox_to_anchor=(-0.5, 1), fontsize=labelsize)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# --- Subgráfica 2: Histograma normalizado ---
# Para obtener el porcentaje en el eje Y, usamos el argumento 'weights'.
total_actions = len(action_list_2)
weights = np.ones(total_actions) / total_actions * 100

n, bins, patches = ax2.hist(action_list_2, bins=np.arange(-0.5, 11.5, 1), weights=weights, color="#86EE80", edgecolor='black', alpha=0.8)
n, bins, patches = ax2.hist(action_list_1, bins=np.arange(-0.5, 11.5, 1), weights=weights, color='#87CEEB', edgecolor='black', alpha=0.8)
ax2.set_xlabel('Valor de la Acción', fontsize=labelsize)
ax2.set_ylabel('Porcentaje de Frecuencia', fontsize=labelsize)

# Aumentar el tamaño de la fuente para los valores de los ejes
ax2.tick_params(axis='both', which='major', labelsize=labelsize)
ax2.set_xlim(0, 11)
# Establecer los valores discretos en el eje horizontal
ax2.set_xticks(np.arange(0, 11))
ax2.grid(True, linestyle='--', alpha=0.6)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

# Mejorar el diseño del layout
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15.5, 5))

# # Histogram
# plt.hist(action_list, bins=30, color='skyblue', edgecolor='black')
# plt.title('Distribución de acciones')
# plt.xlabel('Valor de la action')
# plt.ylabel('Frecuencia')
# plt.grid(True, alpha=0.3)

# plt.tight_layout()
# plt.show()

# %%
# # Scatter plot of the variables action_list = df[agent]["actions"] vs cooling_energy = []
# action_list = df[agent]["actions"]
# cooling_energy = []
# for timestep in range(len(df[agent]["infos"])-1):
#     cooling_energy.append(df[agent]["infos"][timestep][f"{agent}: Cooling:DistrictCooling"])

# plt.figure(figsize=(7.5, 5))
# plt.scatter(action_list, cooling_energy, s=1)
# plt.xlabel("Action")
# plt.ylabel("Cooling energy")
# plt.title("Scatter plot of Action vs Cooling energy")
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
# # Analyze transitions between actions
# transitions = np.diff(action_list)
# plt.figure(figsize=(10, 4))
# plt.plot(transitions, label='Action Changes')
# plt.title('Action Transitions Over Time')
# plt.xlabel('Time Step')
# plt.ylabel('Change in Action')
# plt.grid(True, alpha=0.3)
# plt.show()

# # Calculate transition statistics
# print("\nTransition Analysis:")
# print(f"Mean absolute change: {np.mean(np.abs(transitions)):.2f}")
# print(f"Max increase: {np.max(transitions):.2f}")
# print(f"Max decrease: {np.min(transitions):.2f}")

# %%
# # Create a figure with multiple subplots
# plt.figure(figsize=(15, 5))

# # 1. Time series plot
# plt.scatter(action_list, occ_list, color='blue', alpha=0.6)
# plt.title('Action-occupancy distribution')
# plt.xlabel('Action Value')
# plt.ylabel('Occupancy')
# plt.grid(True, alpha=0.3)

# %%
from typing import List, Any, Optional

agent:str = "HVAC"

feature_names_list: List[str] = feature_names[agent]

data_obs_list: List[Any] = []
for timestep in range(1,len(df["experiment"]["episode_1"])):
    data_obs_list.append(df["experiment"]["episode_1"][f"timestep_{timestep}"][agent]["observation"])
        
data_obs = np.array(data_obs_list)

# %%
feature_names_list
# Out:
# ['HVAC: Site Outdoor Air Drybulb Temperature: Environment',
#  'HVAC: Zone Mean Air Temperature: Thermal Zone',
#  'HVAC: Zone People Occupant Count: Thermal Zone',
#  'HVAC: Zone Thermal Comfort Fanger Model PMV: People',
#  'HVAC: Electricity:Building',
#  'HVAC: Heating:DistrictHeatingWater',
#  'HVAC: Cooling:DistrictCooling',
#  'HVAC: Schedule:Compact: Schedule Value: heating_setpoint',
#  'HVAC: Schedule:Compact: Schedule Value: cooling_setpoint',
#  'HVAC: Schedule:Constant: Schedule Value: HVAC_OnOff']

# %%
print(data_obs.shape)
# Out:
# (52561, 10)

# %%
from numpy.typing import NDArray
from numpy import float32
import torch
# Model prediction function (adapted for RLlib)
POLICY: Optional[Policy] = None
def model_predict(
    data: NDArray[float32],
):
    # Transform the lists in tensors.
    obs_tensor = torch.tensor(data, dtype=torch.float32)
    
    # Compute the actions.
    with torch.no_grad():
        predictions = POLICY.compute_actions(
            obs_batch=obs_tensor.numpy(), 
            exploration=False, 
        )[0]
    return predictions

# %%
# Use KernelExplainer
data_obs_sample = shap.sample(data_obs, 1000)

POLICY = single_policy
explainer = shap.KernelExplainer(
    model_predict,
    data=data_obs_sample,
    feature_names=feature_names_list
    )
# Out:
# Using 1000 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.

# %%
background_data_np_sample = shap.sample(data_obs, 100)

# %%
shap_values_1 = explainer(background_data_np_sample)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
shap_values_1
# Out:
# .values =
# array([[[-0.08827262, -0.0173381 ],
#         [ 0.01035595,  0.00049286],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.04236071, -0.17365476],
#         [-0.00953214,  0.01135952],
#         [-0.01607976,  0.00724286]],
#
#        [[-0.00425595, -0.00050119],
#         [-0.02256071, -0.00382024],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.04207738, -0.18627262],
#         [-0.02284167,  0.00454167],
#         [-0.02478214,  0.00592976]],
#
#        [[ 0.01001429, -0.00024048],
#         [-0.06293571, -0.10706905],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.03391429, -0.1256619 ],
#         [-0.02377381,  0.00247619],
#         [-0.02534524,  0.00485714]],
#
#        ...,
#
#        [[ 0.02500714,  0.00167262],
#         [-0.01989286, -0.01071786],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.04048095, -0.186625  ],
#         [-0.02344524, -0.00063214],
#         [-0.02294762,  0.00290833]],
#
#        [[ 0.03197857, -0.02585714],
#         [-0.02339524, -0.01442143],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.04256905, -0.1813    ],
#         [-0.02193333,  0.00478333],
#         [-0.0214619 ,  0.0106381 ]],
#
#        [[ 0.02819881,  0.00319048],
#         [-0.02452024, -0.00885952],
#         [ 0.        ,  0.        ],
#         ...,
#         [-0.03764405, -0.1885619 ],
#         [-0.021025  ,  0.0057619 ],
#         [-0.02462976,  0.00618333]]])
#
# .base_values =
# array([[1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834],
#        [1.169, 7.834]])
#
# .data =
# array([[ 3.07000008e+01,  2.79162083e+01,  1.00000000e+00,
#          2.69043744e-01,  0.00000000e+00,  0.00000000e+00,
#          1.34624500e+06,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 2.05000000e+01,  2.57999668e+01,  1.00000000e+00,
#         -3.46782029e-01,  0.00000000e+00,  1.47489062e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.39333334e+01,  1.87956715e+01,  1.00000000e+00,
#         -1.56960356e+00,  0.00000000e+00,  2.03548375e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.20000000e+01,  2.65026493e+01,  1.00000000e+00,
#          1.48052901e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 2.74333324e+01,  2.71219463e+01,  1.00000000e+00,
#          7.95109197e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 8.93333340e+00,  2.57999992e+01,  1.00000000e+00,
#         -4.12436873e-01,  0.00000000e+00,  7.03762188e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.20000000e+01,  2.57999992e+01,  1.00000000e+00,
#         -4.55597430e-01,  0.00000000e+00,  4.15350594e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.70333328e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.14405552e-01,  0.00000000e+00,  6.37777562e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.71833324e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.78366679e-01,  0.00000000e+00,  8.07557562e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 4.66666651e+00,  2.57999992e+01,  1.00000000e+00,
#         -3.88045371e-01,  0.00000000e+00,  9.01147812e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.68999996e+01,  2.68992577e+01,  1.00000000e+00,
#         -4.54737283e-02,  0.00000000e+00,  6.13746406e+04,
#          0.00000000e+00,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 3.01666660e+01,  2.79000015e+01,  1.00000000e+00,
#          3.04162681e-01,  0.00000000e+00,  0.00000000e+00,
#          8.72677938e+05,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 1.55000000e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.17775071e-01,  0.00000000e+00,  1.10952175e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.62999992e+01,  2.66768265e+01,  1.00000000e+00,
#          7.39452690e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 1.89666672e+01,  2.57999763e+01,  1.00000000e+00,
#         -2.48210505e-01,  0.00000000e+00,  7.74112125e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.26333332e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.32297504e-01,  0.00000000e+00,  1.06976227e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 9.98333359e+00,  2.57999992e+01,  1.00000000e+00,
#         -4.26588774e-01,  0.00000000e+00,  1.06343750e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 3.08166676e+01,  2.78999996e+01,  1.00000000e+00,
#          6.01933062e-01,  0.00000000e+00,  0.00000000e+00,
#          9.44623125e+05,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 3.83166656e+01,  3.31286278e+01,  1.00000000e+00,
#          1.56161284e+00,  0.00000000e+00,  0.00000000e+00,
#          1.92000000e+06,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 1.90000000e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.76436111e-01,  0.00000000e+00,  7.05399812e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.11499996e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.12405248e-01,  0.00000000e+00,  5.61273750e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.72666664e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.91473335e-01,  0.00000000e+00,  6.68255500e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.79500008e+01,  2.74505405e+01,  1.00000000e+00,
#          1.87814191e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 2.01666660e+01,  2.69035320e+01,  1.00000000e+00,
#          1.88848808e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 1.85166664e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.07467899e-01,  0.00000000e+00,  2.00827480e+04,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.24666672e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.66118681e-01,  0.00000000e+00,  6.76116094e+04,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.67000008e+01,  2.42514095e+01,  1.00000000e+00,
#         -5.86390972e-01,  0.00000000e+00,  1.67480650e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.09666662e+01,  2.06334896e+01,  1.00000000e+00,
#         -1.29100752e+00,  0.00000000e+00,  1.93154800e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.50500002e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.64131033e-01,  0.00000000e+00,  7.87904375e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.12999992e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.44196525e-01,  0.00000000e+00,  3.44055562e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.75499992e+01,  2.72090282e+01,  1.00000000e+00,
#          2.93657839e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.58999996e+01,  2.88999996e+01,
#          1.00000000e+00],
#        [ 2.92500000e+01,  2.78999996e+01,  1.00000000e+00,
#          6.25139058e-01,  0.00000000e+00,  0.00000000e+00,
#          6.04880312e+05,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 9.33333302e+00,  2.48464985e+01,  1.00000000e+00,
#         -3.93152893e-01,  0.00000000e+00,  1.65891400e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.36499996e+01,  2.57999992e+01,  1.00000000e+00,
#         -4.34921890e-01,  0.00000000e+00,  7.90201188e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 3.27000008e+01,  2.78999996e+01,  1.00000000e+00,
#          5.76841295e-01,  0.00000000e+00,  0.00000000e+00,
#          1.46383825e+06,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 1.63333340e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.02103913e-01,  0.00000000e+00,  2.77032938e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.36000004e+01,  2.59249210e+01,  1.00000000e+00,
#          6.82202950e-02,  0.00000000e+00,  1.10994906e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 8.94999981e+00,  2.57999992e+01,  1.00000000e+00,
#         -4.58822101e-01,  0.00000000e+00,  3.35597281e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.56000004e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.06351011e-01,  0.00000000e+00,  1.82757516e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 9.39999962e+00,  2.57999992e+01,  1.00000000e+00,
#         -3.72742951e-01,  0.00000000e+00,  8.28131375e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 5.69999981e+00,  2.54105835e+01,  1.00000000e+00,
#         -3.07841867e-01,  0.00000000e+00,  1.59145400e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.58000002e+01,  2.42816639e+01,  1.00000000e+00,
#         -6.07274354e-01,  0.00000000e+00,  1.67013050e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.80666676e+01,  2.74334087e+01,  1.00000000e+00,
#         -9.14434940e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 1.83666668e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.58430600e-01,  0.00000000e+00,  7.31339125e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.08999996e+01,  2.55678806e+01,  1.00000000e+00,
#         -1.41704962e-01,  0.00000000e+00,  1.62972650e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.18000002e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.03397764e-01,  0.00000000e+00,  1.40126238e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.19333324e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.32076362e-01,  0.00000000e+00,  7.23618672e+04,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.44666662e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.75458390e-01,  0.00000000e+00,  5.79421312e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 3.04666672e+01,  2.86172543e+01,  1.00000000e+00,
#          4.17385519e-01,  0.00000000e+00,  0.00000000e+00,
#          1.92000000e+06,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 3.07333336e+01,  2.79003143e+01,  1.00000000e+00,
#          3.24707508e-01,  0.00000000e+00,  0.00000000e+00,
#          1.35406850e+06,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 1.28999996e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.08675110e-01,  0.00000000e+00,  1.27347469e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.33999996e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.18983078e-01,  0.00000000e+00,  1.54000375e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 9.39999962e+00,  2.57999992e+01,  1.00000000e+00,
#         -3.84996831e-01,  0.00000000e+00,  2.93570719e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.59333334e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.80950600e-01,  0.00000000e+00,  6.14361062e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 4.59999990e+00,  2.57999992e+01,  1.00000000e+00,
#         -2.28961095e-01,  0.00000000e+00,  1.92987422e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.46000004e+01,  2.58961525e+01,  1.00000000e+00,
#         -5.68892062e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 2.82000008e+01,  2.78999996e+01,  1.00000000e+00,
#          5.03348410e-01,  0.00000000e+00,  0.00000000e+00,
#          9.61345234e+04,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 2.73166676e+01,  2.69625053e+01,  1.00000000e+00,
#         -9.52007398e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 2.50000000e+00,  2.57999916e+01,  1.00000000e+00,
#         -2.12638065e-01,  0.00000000e+00,  1.04466250e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.58500004e+01,  2.64645538e+01,  1.00000000e+00,
#          6.11473583e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 1.87999992e+01,  2.36895409e+01,  1.00000000e+00,
#         -8.10822308e-01,  0.00000000e+00,  1.72741675e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.32333336e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.37873822e-01,  0.00000000e+00,  5.40487031e+04,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.93333340e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.70138383e-01,  0.00000000e+00,  8.78427656e+04,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.92000008e+01,  2.57999992e+01,  1.00000000e+00,
#         -5.57663329e-02,  0.00000000e+00,  2.66695781e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.35000000e+01,  2.57999992e+01,  1.00000000e+00,
#          7.91013688e-02,  0.00000000e+00,  2.67376062e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.42833328e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.14611918e-01,  0.00000000e+00,  9.90421484e+04,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.87666664e+01,  2.57999992e+01,  1.00000000e+00,
#         -4.28797215e-01,  0.00000000e+00,  5.43875625e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.03333330e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.93534631e-01,  0.00000000e+00,  1.99163781e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.12666664e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.00677598e-01,  0.00000000e+00,  3.66888625e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.46999998e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.02330345e-01,  0.00000000e+00,  1.18712488e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 8.46666622e+00,  2.57999992e+01,  1.00000000e+00,
#         -2.66211718e-01,  0.00000000e+00,  1.40362562e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 4.55000019e+00,  1.96585236e+01,  1.00000000e+00,
#         -1.83970773e+00,  0.00000000e+00,  1.99457350e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.09500008e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.25871032e-01,  0.00000000e+00,  1.89929891e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 3.01666660e+01,  2.78999996e+01,  1.00000000e+00,
#          2.30734855e-01,  0.00000000e+00,  0.00000000e+00,
#          1.07211162e+06,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 2.96499996e+01,  2.78999996e+01,  1.00000000e+00,
#          2.67374784e-01,  0.00000000e+00,  0.00000000e+00,
#          5.38800500e+05,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 3.26666665e+00,  2.57999992e+01,  1.00000000e+00,
#         -4.13075030e-01,  0.00000000e+00,  1.41718375e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.34333324e+01,  2.57999992e+01,  1.00000000e+00,
#         -3.61594170e-01,  0.00000000e+00,  1.94912250e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.73333335e+00,  2.57999992e+01,  1.00000000e+00,
#         -4.91935104e-01,  0.00000000e+00,  1.41701925e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.96333332e+01,  2.57999992e+01,  1.00000000e+00,
#         -1.34084478e-01,  0.00000000e+00,  5.31391000e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.97000008e+01,  2.78999996e+01,  1.00000000e+00,
#          1.32348090e-01,  0.00000000e+00,  0.00000000e+00,
#          2.62164656e+05,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 2.83999996e+01,  2.78999996e+01,  1.00000000e+00,
#          3.10232341e-01,  0.00000000e+00,  0.00000000e+00,
#          9.15094141e+04,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 1.21666670e+01,  2.57998314e+01,  1.00000000e+00,
#         -5.09905756e-01,  0.00000000e+00,  1.54410038e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.20000000e+01,  2.57999992e+01,  1.00000000e+00,
#         -8.76791179e-02,  0.00000000e+00,  6.05655688e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.92999992e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.71935433e-01,  0.00000000e+00,  7.54663188e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 9.23333359e+00,  2.57999992e+01,  1.00000000e+00,
#         -3.57887954e-01,  0.00000000e+00,  5.09802125e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.37000008e+01,  2.58394241e+01,  1.00000000e+00,
#          1.15787946e-01,  0.00000000e+00,  3.11568094e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 5.59999990e+00,  2.57999992e+01,  1.00000000e+00,
#         -4.16886896e-01,  0.00000000e+00,  1.28094975e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.67333336e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.32510477e-01,  0.00000000e+00,  5.97937188e+04,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 3.07333336e+01,  2.78999996e+01,  1.00000000e+00,
#          2.51669198e-01,  0.00000000e+00,  0.00000000e+00,
#          1.55985912e+06,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 2.88666668e+01,  2.76050701e+01,  1.00000000e+00,
#          2.54487425e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 2.67333336e+01,  2.70129662e+01,  1.00000000e+00,
#          1.62268907e-01,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.70000000e+01,  2.80000000e+01,
#          0.00000000e+00],
#        [ 1.88500004e+01,  2.57999287e+01,  1.00000000e+00,
#         -4.22487408e-01,  0.00000000e+00,  1.05996275e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.15000000e+01,  2.57999992e+01,  1.00000000e+00,
#         -4.45495099e-01,  0.00000000e+00,  3.87052000e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 1.02166662e+01,  2.52763195e+01,  1.00000000e+00,
#         -1.50270388e-01,  0.00000000e+00,  1.62531812e+06,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 8.23333359e+00,  2.57999992e+01,  1.00000000e+00,
#         -2.84825861e-01,  0.00000000e+00,  3.23044000e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 2.82333336e+01,  2.78997746e+01,  1.00000000e+00,
#          3.37338686e-01,  0.00000000e+00,  0.00000000e+00,
#          1.56276562e+05,  2.68999996e+01,  2.78999996e+01,
#          1.00000000e+00],
#        [ 1.53666668e+01,  2.57999992e+01,  1.00000000e+00,
#         -2.79346526e-01,  0.00000000e+00,  8.64012188e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 6.44999981e+00,  2.57999992e+01,  1.00000000e+00,
#         -8.19648504e-02,  0.00000000e+00,  4.52613156e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 6.99999988e-01,  2.57999992e+01,  1.00000000e+00,
#         -2.28437871e-01,  0.00000000e+00,  5.71782688e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00],
#        [ 5.69999981e+00,  2.57999992e+01,  1.00000000e+00,
#         -5.02558351e-01,  0.00000000e+00,  2.83319094e+05,
#          0.00000000e+00,  2.57999992e+01,  2.67999992e+01,
#          1.00000000e+00]], dtype=float32)

# %%
# Nombres de las acciones para los títulos de los gráficos (opcional pero recomendado)
action_names = ["Acción 1", "Acción 2"]

# Iteramos a través de los valores SHAP para cada acción de salida
for i, shap_values_for_action in enumerate(shap_values_1):
    
    # Creamos un objeto Explanation unificado para esta acción específica.
    # SHAP maneja internamente si la salida es de una o varias clases.
    # Le pasamos los valores SHAP, los datos originales y los nombres de las features.
    explanation_for_action = shap.Explanation(
        values=shap_values_for_action,
        base_values=explainer.expected_value[i], # El valor base para esta acción
        data=background_data_np_sample, # Los datos que se explicaron
        feature_names=feature_names # Tus nombres de features
    )

    # Generamos el gráfico de barras para la acción actual
    print(f"--- Gráfico de Importancia de Features para: {action_names[i]} ---")
    
    # Usamos la nueva API de ploteo que es más robusta
    shap.plots.bar(explanation_for_action, show=False)
    
    # Personalizamos y mostramos el gráfico con matplotlib
    plt.title(f"Importancia Global de Features para {action_names[i]}")
    plt.show()
# Out:
# --- Gráfico de Importancia de Features para: Acción 1 ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 21
#      18 print(f"--- Gráfico de Importancia de Features para: {action_names[i]} ---")
#      20 # Usamos la nueva API de ploteo que es más robusta
# ---> 21 shap.plots.bar(explanation_for_action, show=False)
#      23 # Personalizamos y mostramos el gráfico con matplotlib
#      24 plt.title(f"Importancia Global de Features para {action_names[i]}")
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_bar.py:106, in bar(shap_values, max_display, order, clustering, clustering_cutoff, show_data, ax, show)
#     102     raise TypeError(emsg)
#     104 if len(exp.shape) == 2:
#     105     # collapse the Explanation arrays to be of shape (#features,)
# --> 106     cohort_exps[i] = exp.abs.mean(0)
#     107 if cohort_exps[i].shape != cohort_exps[0].shape:
#     108     emsg = "When passing several Explanation objects, they must all have the same number of feature columns!"
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:540, in Explanation.abs(self)
#     538 @property
#     539 def abs(self):
# --> 540     return self._numpy_func("abs")
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:504, in Explanation._numpy_func(self, fname, **kwargs)
#     501     new_self = new_self[axis]
#     502     new_self.op_history = new_self.op_history[:-1]  # pop off the slicing operation we just used
# --> 504 if self.feature_names is not None and not is_1d(self.feature_names) and axis == 0:
#     505     new_values = self._flatten_feature_names()
#     506     new_self.feature_names = np.array(list(new_values.keys()))
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:810, in is_1d(val)
#     809 def is_1d(val):
# --> 810     return not (isinstance(val[0], (list, np.ndarray)))
#
# KeyError: 0

# %%
"""
Global bar plot
================

Passing a matrix of SHAP values to the bar plot function creates a global feature importance 
plot, where the global importance of each feature is taken to be the mean absolute value for 
that feature over all the given samples.

# By default the bar plot only shows a maximum of ten bars, but this can be controlled with the `max_display` parameter.
"""
shap.plots.bar(shap_values_1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 11
#       1 """
#       2 Global bar plot
#       3 ================
#    (...)
#       9 # By default the bar plot only shows a maximum of ten bars, but this can be controlled with the `max_display` parameter.
#      10 """
# ---> 11 shap.plots.bar(shap_values_1)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_bar.py:216, in bar(shap_values, max_display, order, clustering, clustering_cutoff, show_data, ax, show)
#     214 for inds in orig_inds:
#     215     if len(inds) == 1:
# --> 216         feature_names_new.append(feature_names[inds[0]])
#     217     else:
#     218         full_print = " + ".join([feature_names[i] for i in inds])
#
# IndexError: list index out of range

# %%
# for _ in range(50):
#     shap.plots.bar(shap_values_1[_], max_display=13)

# %%
"""
beeswarm summary plot
======================

The beeswarm plot is designed to display an information-dense summary of how the top features 
in a dataset impact the model’s output. Each instance the given explanation is represented by 
a single dot on each feature row. The x position of the dot is determined by the SHAP value 
(shap_values.value[instance,feature]) of that feature, and dots “pile up” along each feature row 
to show density. Color is used to display the original value of a feature 
(shap_values.data[instance,feature]).

By default the maximum number of features shown is ten, but this can be adjusted with the max_display parameter.
"""
shap.plots.beeswarm(shap_values_1, max_display=6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 14
#       1 """
#       2 beeswarm summary plot
#       3 ======================
#    (...)
#      12 By default the maximum number of features shown is ten, but this can be adjusted with the max_display parameter.
#      13 """
# ---> 14 shap.plots.beeswarm(shap_values_1, max_display=6)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_beeswarm.py:124, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     120 elif len(sv_shape) > 2:
#     121     emsg = (
#     122         "The beeswarm plot does not support plotting explanations with instances that have more than one dimension!"
#     123     )
# --> 124     raise ValueError(emsg)
#     126 if ax and plot_size:
#     127     emsg = (
#     128         "The beeswarm plot does not support passing an axis and adjusting the plot size. "
#     129         "To adjust the size of the plot, set plot_size to None and adjust the size on the original figure the axes was part of"
#     130     )
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
"""
Feature ordering
=================

By default the features are ordered using shap_values.abs.mean(0), which is the mean absolute value 
of the SHAP values for each feature. This order however places more emphasis on broad average impact, 
and less on rare but high magnitude impacts. If we want to find features with high impacts for individual 
people we can instead sort by the max absolute value.
"""
shap.plots.beeswarm(shap_values_1, max_display=6, order=shap_values_1.abs.max(0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 10
#       1 """
#       2 Feature ordering
#       3 =================
#    (...)
#       8 people we can instead sort by the max absolute value.
#       9 """
# ---> 10 shap.plots.beeswarm(shap_values_1, max_display=6, order=shap_values_1.abs.max(0))
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_beeswarm.py:124, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     120 elif len(sv_shape) > 2:
#     121     emsg = (
#     122         "The beeswarm plot does not support plotting explanations with instances that have more than one dimension!"
#     123     )
# --> 124     raise ValueError(emsg)
#     126 if ax and plot_size:
#     127     emsg = (
#     128         "The beeswarm plot does not support passing an axis and adjusting the plot size. "
#     129         "To adjust the size of the plot, set plot_size to None and adjust the size on the original figure the axes was part of"
#     130     )
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
"""
Sometimes it is helpful to transform the SHAP values before we plots them. Below we plot the absolute 
value and fix the color to be red. This creates a richer parallel to the standard shap_values.abs.mean(0) 
bar plot, since the bar plot just plots the mean value of the dots in the beeswarm plot.
"""
shap.plots.beeswarm(shap_values_1.abs, max_display=23, color="shap_red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 6
#       1 """
#       2 Sometimes it is helpful to transform the SHAP values before we plots them. Below we plot the absolute
#       3 value and fix the color to be red. This creates a richer parallel to the standard shap_values.abs.mean(0)
#       4 bar plot, since the bar plot just plots the mean value of the dots in the beeswarm plot.
#       5 """
# ----> 6 shap.plots.beeswarm(shap_values_1.abs, max_display=23, color="shap_red")
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_beeswarm.py:124, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     120 elif len(sv_shape) > 2:
#     121     emsg = (
#     122         "The beeswarm plot does not support plotting explanations with instances that have more than one dimension!"
#     123     )
# --> 124     raise ValueError(emsg)
#     126 if ax and plot_size:
#     127     emsg = (
#     128         "The beeswarm plot does not support passing an axis and adjusting the plot size. "
#     129         "To adjust the size of the plot, set plot_size to None and adjust the size on the original figure the axes was part of"
#     130     )
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
"""
A simple violin summary plot
=============================

The violin summary plot offers a compact representation of the distribution and variability of SHAP 
values for each feature. Individual violin plots are stacked by importance of the particular feature 
on model output (sum of the absolute values of the SHAP values per feature).

Violin plots use “violin-shaped” figures to display the distribution and density of SHAP values for their 
respective feature. The violins can therefore provide insights into the range, variability, skewness, 
symmetry, and multimodality of the SHAP value distribution for a specific feature.

The overall violin summary plot allow for comparisons in feature importance. Wider violins indicate higher 
density and more frequent values, thus providing insights into the relative importance of each feature with 
regard to the model output.
"""
shap.plots.violin(shap_values_1, max_display=23)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 17
#       1 """
#       2 A simple violin summary plot
#       3 =============================
#    (...)
#      15 regard to the model output.
#      16 """
# ---> 17 shap.plots.violin(shap_values_1, max_display=23)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\plots\_violin.py:186, in violin(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, use_log_scale)
#     184     ds = gaussian_kde(shaps + np.random.randn(len(shaps)) * (global_high - global_low) / 100)(xs)
#     185 else:
# --> 186     ds = gaussian_kde(shaps)(xs)
#     187 ds /= np.max(ds) * 3
#     189 values = features[:, i]
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\scipy\stats\_kde.py:204, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     201 if not self.dataset.size > 1:
#     202     raise ValueError("`dataset` input should have multiple elements.")
# --> 204 self.d, self.n = self.dataset.shape
#     206 if weights is not None:
#     207     self._weights = atleast_1d(weights).astype(float)
#
# ValueError: too many values to unpack (expected 2)

# %%
"""
Simple dependence scatter plot
===============================

A dependence scatter plot shows the effect a single feature has on the predictions made by the model.

* Each dot is a single prediction (row) from the dataset.
* The x-axis is the value of the feature (from the X matrix, stored in explanation.data).
* The y-axis is the SHAP value for that feature (stored in explanation.values), which represents how much knowing 
that feature’s value changes the output of the model for that sample’s prediction. For this model the units are 
log-odds of making over 50k annually.
* The light grey area at the bottom of the plot is a histogram showing the distribution of data values.
"""

features = feature_names.copy()

# for feature in features:
#     shap.plots.scatter(
#         shap_values_1[:, feature],
#         # color=shap_values_1[:, "Zone Thermal Comfort Fanger Model PMV"]
#         )

# %%
# # for feature in features:
# features_copy = features.copy()
# features_copy.remove("Estado del actuador")
# for feature2 in features_copy:
#     shap.plots.scatter(
#         shap_values_1[:, "Estado del actuador"],
#         color=shap_values_1[:, feature2]
#         )

# %%
shap.plots.scatter(
    shap_values_1[:, "Energía para enfriamiento"],
    color=shap_values_1[:, "Temperatura de bulbo seco"]
    )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[91], line 2
#       1 shap.plots.scatter(
# ----> 2     shap_values_1[:, "Energía para enfriamiento"],
#       3     color=shap_values_1[:, "Temperatura de bulbo seco"]
#       4     )
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\shap\_explanation.py:417, in Explanation.__getitem__(self, item)
#     415 if new_self is None:
#     416     new_self = copy.copy(self)
# --> 417 new_self._s = new_self._s.__getitem__(item)
#     418 new_self.op_history.append(OpHistoryItem(name="__getitem__", args=(item,), prev_shape=self.shape))
#     420 return new_self
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer.py:112, in Slicer.__getitem__(self, item)
#     110 index_slicer = AtomicSlicer(index_tup, max_dim=1)
#     111 slicer_index = index_slicer[tracked.dim]
# --> 112 sliced_o = tracked[slicer_index]
#     113 sliced_dim = resolve_dim(index_tup, tracked.dim)
#     115 new_tracked = tracked.__class__(sliced_o, sliced_dim)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:589, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     586 tail_slice = cls.type_map[o_type].tail_slice
#     588 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
# --> 589 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     590 return out
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:439, in ArrayHandler.tail_slice(cls, o, tail_index, max_dim, flatten)
#     437         return AtomicSlicer(o, max_dim=max_dim)[tail_index]
#     438 else:
# --> 439     inner = [AtomicSlicer(e, max_dim=max_dim)[tail_index] for e in o]
#     440     if _safe_isinstance(o, "numpy", "ndarray"):
#     441         import numpy
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:439, in <listcomp>(.0)
#     437         return AtomicSlicer(o, max_dim=max_dim)[tail_index]
#     438 else:
# --> 439     inner = [AtomicSlicer(e, max_dim=max_dim)[tail_index] for e in o]
#     440     if _safe_isinstance(o, "numpy", "ndarray"):
#     441         import numpy
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:588, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     585 head_slice = cls.type_map[o_type].head_slice
#     586 tail_slice = cls.type_map[o_type].tail_slice
# --> 588 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
#     589 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     590 return out
#
# File c:\Users\grhen\Documents\GitHub2\eprllib\eprllib-dev\lib\site-packages\slicer\slicer_internal.py:418, in ArrayHandler.head_slice(cls, o, index_tup, max_dim)
#     416 cut_index = index_tup[:cut]
#     417 is_element = any([True if isinstance(x, int) else False for x in cut_index])
# --> 418 sliced_o = o[cut_index]
#     420 return is_element, sliced_o, cut
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
"""
Heatmap
========

Passing a matrix of SHAP values to the heatmap plot function creates a plot with the instances on the x-axis, 
the model inputs on the y-axis, and the SHAP values encoded on a color scale. By default the samples are ordered 
using shap.order.hclust, which orders the samples based on a hierarchical clustering by their explanation 
similarity. This results in samples that have the same model output for the same reason getting grouped together 
(such as people with a high impact from capital gain in the plot below).

The output of the model is shown above the heatmap matrix (centered around the explaination’s .base_value), and 
the global importance of each model input shown as a bar plot on the right hand side of the plot (by default this 
is the shap.order.abs.mean measure of overall importance).
"""
shap.plots.heatmap(shap_values_1, max_display=23)
# Out:
# <Axes: xlabel='Instances'>

# %%
# for i in range(len(background_data_np_sample)):
#     shap.initjs()
#     shap.force_plot(explainer.expected_value, shap_values[i], background_data_np_sample[i], matplotlib=True, show=True)

# for i in range(14):
#     shap.dependence_plot(i, shap_values, background_data_np_sample)

# %%
# Parameter importance

# import eli5
# from eli5.sklearn import PermutationImportance

# val_X = df["observations"][0:100]
# val_y = df["actions"][0:100]

# perm = PermutationImportance(model_predict, random_state=1).fit(val_X, val_y)
# eli5.show_weights(perm, feature_names = val_X.columns.tolist())
